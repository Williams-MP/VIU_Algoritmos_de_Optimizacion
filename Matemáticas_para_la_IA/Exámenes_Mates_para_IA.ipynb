# %% [markdown]
# # Examen 1

# %% [markdown]
# ### Pregunta 1
# El enunciado $\,\neg(p \lor \neg q)\,$ es equivalente a:
# a) $p \lor q$
# b) $\neg p \land q$
# c) $\neg p \lor \neg q$
# d) $\neg p \land \neg q$
#
# ---
#
# ### Pregunta 2
# Sea $p(x)$ el predicado $\forall y \in A,\, \exists x \in A:\; y = x^2$. Entonces:
# a) $p(x)$ es cierto si $A=\mathbb{N}$.
# b) $p(x)$ es cierto si $A=\mathbb{Z}$.
# c) $p(x)$ es cierto si $A=\mathbb{R}$.
# d) $p(x)$ no se cumple en ninguna de las opciones anteriores.
#
# ---
#
# ### Pregunta 3
# Sean $A, B$ conjuntos tales que $|A|=20$, $|B|=10$ y $f: A \to B$ una aplicación. Entonces:
# a) $f$ puede ser inyectiva.
# b) $f$ puede ser sobreyectiva.
# c) $f$ puede ser biyectiva.
# d) $f$ puede tener inversa.
#
# ---
#
# ### Pregunta 4
# ¿Cuántas posibles contraseñas numéricas de 4 dígitos del “0” al “9” existen para desbloquear un teléfono móvil?
# (Escribid el resultado sin puntos ni comas)
#
# ---
#
# ### Pregunta 5
# Sea $f:\mathbb{R}\to\mathbb{R}$ dada por
# $$
# f(x)=
# \begin{cases}
# \sqrt{x^2+1}, & \text{si } x<0,\\
# 0, & \text{si } x=0,\\
# \ln(x+1)+e^x, & \text{si } x>0.
# \end{cases}
# $$
# Entonces:
# a) $\lim\limits_{x\to 0} f(x)=0$
# b) $\lim\limits_{x\to 0} f(x)=1$
# c) $f$ es continua en $x=0$.
# d) $f$ es derivable en $x=0$.
#
# ---

# %% [markdown]
# ### Pregunta 6
# Sean $A$ y $B$ dos sucesos independientes tales que $P(B)=0.6$ y $P(A\cap B)=0.3$. Obténgase $P(A\mid B)$.
# Debe indicarse el resultado exacto, escalado entre 0 y 1 y utilizando la coma "," en lugar del punto "." para indicar la parte decimal.
#
# ---
#
# ### Pregunta 7
# ¿Cuál es la complejidad computacional del siguiente algoritmo que muestra por consola todas las posibles combinaciones de dos vectores?
#
# **Algorithm** Print all combinations “(a,b)”, for $a\in A$ and $b\in B$. $|A|=n$, $|B|=m$.
#
# - for i ← 1 to length(A) do
#     - for j ← 1 to length(B) do
#         - print("(" + A_i + "," + B_j + ")")
#     - end for
# - end for
#
# a) $O(n^2)$
# b) $O(n\cdot m)$
# c) $O(n^2+m^2)$
# d) $O(n^2\cdot m^2)$
#
# ---
#
# ### Pregunta 8
# Sean $A, B$ conjuntos tales que $A\subseteq B$. Entonces:
# a) $A\cup B \subseteq A$
# b) $A\cap B \subseteq A$
# c) $B\setminus A \subseteq A$
# d) $A\times B \subseteq A\cup B$
#
# ---
#
# ### Pregunta 9
# Sea $v=(\alpha,-1)$ un vector de $\mathbb{R}^2$. ¿Para qué valor de $\alpha$ se cumple $\|v\|_2^2=\|v\|_1$?
# a) 1
# b) 2
# c) 3
# d) 4
#
# ---
#
# ### Pregunta 10
# Sea $A\in\mathbb{R}^{3\times 3}$ una matriz tal que $\det(A)=2$ y $B\in\mathbb{R}^{3\times 3}$ una matriz diagonalizable cuyos autovalores son $\lambda_1=2$, $\lambda_2=1$, $\lambda_3=3$. Obténgase $\det(2AB)$.

# %% [markdown]
# ### Pregunta 11
# Sea $A\in\mathbb{R}^{2\times 2}$ una matriz simétrica con determinante $\det(A)=-2$. Entonces:
# a) $A$ no es diagonalizable.
# b) $A$ es definida positiva.
# c) $A^2=Id$.
# d) Los autovalores de $A$ son $-\lambda$ y $\dfrac{2}{\lambda}$, $\lambda\in\mathbb{R}$.
#
# ---
#
# ### Pregunta 12
# Encuentra el valor de la siguiente integral:
# $$
# \int_{0}^{3} (x^2+1)\,dx
# $$
#
# ---
#
# ### Pregunta 13
# Un juego de apuestas consiste en lanzar un dado que toma valores $\{1,2,3,4,5,6\}$ con las siguientes condiciones:
# - Si sale un número impar $n$, el jugador paga $n$ euros.
# - Si sale un número par $n$, el jugador gana $n$ euros.
#
# Si el dado está trucado para que cada número impar tenga el triple de probabilidades de salir respecto a un número par, ¿cuál es el beneficio esperado del jugador por tirada?
# Debe indicarse el resultado exacto en formato numérico utilizando la coma "," en lugar del punto "." para indicar la parte decimal.
#
# ---
#
# ### Pregunta 14
# Sea $f:\mathbb{R}^2\to\mathbb{R}$ dada por $f(x,y)=1-x^2-y^2$. Entonces:
# a) $f$ no tiene puntos críticos.
# b) $(0,0)$ es un punto crítico de $f$ y se trata de un mínimo relativo.
# c) $(0,0)$ es un punto crítico de $f$ y se trata de un máximo relativo.
# d) $(0,0)$ es un punto crítico de $f$ y se trata de un punto de silla.
#
# ---
#
# ### Pregunta 15
# Sea $f:\mathbb{R}\to\mathbb{R}^2$ de la forma $f(t)=(f_1(t),f_2(t))$ y $g:\mathbb{R}^2\to\mathbb{R}$, tales que satisfacen:
# $$
# f(0)=(1,0),\quad f_1'(0)=-2,\quad f_2'(0)=1,
# $$
# $$
# \frac{\partial g}{\partial x}(1,0)=1,\quad \frac{\partial g}{\partial y}(1,0)=4.
# $$
# Obténgase el valor de $[g\circ f]'(0)$.
#
# ---

# %% [markdown]
# ### Pregunta 16
# ¿Cuánto debe restar una pregunta incorrecta en un examen tipo test con 5 respuestas posibles para que la puntuación esperada al elegir las respuestas al azar sea 0? Considérese que solo una respuesta (de 5 posibles) es verdadera por pregunta y que una pregunta correcta vale un punto.
#
# a) $\dfrac{1}{2}$
# b) $\dfrac{1}{3}$
# c) $\dfrac{1}{4}$
# d) $\dfrac{1}{5}$
#
# ---

# %% [markdown]
# ## Soluciones (todas juntas)
#
# **Solución 1:** b) $\neg p \land q$
# **Solución 2:** d) $p(x)$ no se cumple en ninguna de las opciones anteriores.
# **Solución 3:** b) $f$ puede ser sobreyectiva.
# **Solución 4:** $10000$
# **Solución 5:** b) $\lim\limits_{x\to 0} f(x)=1$
#
# **Solución 6:** $P(A\mid B)=0,5$
# **Solución 7:** b) $O(n\cdot m)$
# **Solución 8:** b) $A\cap B \subseteq A$
# **Solución 9:** a) $1$
# **Solución 10:** $96$
#
# **Solución 11:** d) Los autovalores de $A$ son $-\lambda$ y $\dfrac{2}{\lambda}$.
# **Solución 12:** $12$
# **Solución 13:** $-1,25$
# **Solución 14:** c) máximo relativo en $(0,0)$
# **Solución 15:** $2$
#
# **Solución 16:** c) $\dfrac{1}{4}$
#
# ---

# %% [markdown]
# # Examen 4

# %% [markdown]
# ### Pregunta 1
# El enunciado $\neg(\neg p \land \neg q)$ es equivalente a:
# a) $p \land q$
# b) $\neg p \land \neg q$
# c) $p \lor q$
# d) $\neg p \lor \neg q$
#
# ---
#
# ### Pregunta 2
# Sean $p, q$ proposiciones lógicas tales que $p \to q$ es falsa. Entonces:
# a) Siempre se cumple que $p \land q$ es verdadera.
# b) Siempre se cumple que $\neg p \land q$ es verdadera.
# c) Siempre se cumple que $p \land \neg q$ es verdadera.
# d) Siempre se cumple que $\neg p \land \neg q$ es verdadera.
#
# ---
#
# ### Pregunta 3
# Sea $p(x)$ el predicado $\exists y \in \mathbb{R}:\; xy = 1$. Entonces:
# a) Se cumple $p(0)$.
# b) Se cumple $p(4)$.
# c) Se cumple $p(-\pi)$.
# d) Se cumple $p(x)$, $\forall x \in \mathbb{R}\setminus\{0\}$.
#
# ---
#
# ### Pregunta 4
# Sean $A, B$ conjuntos finitos tales que $|A|=|B|$ y $f:A\to B$ una aplicación. Entonces:
# a) Necesariamente $f$ tiene que ser inyectiva.
# b) Necesariamente $f$ tiene que ser sobreyectiva.
# c) Necesariamente $f$ tiene que ser biyectiva.
# d) $f$ no necesariamente es inyectiva/sobreyectiva/biyectiva.
#
# ---
#
# ### Pregunta 5
# Se considera una red neuronal cuyas neuronas de su capa de salida únicamente pueden tomar tres valores: "0", "0,5" y "1".
# Si dicha capa está formada por 12 neuronas, ¿cuántos posibles outputs podemos obtener de forma que los valores de activación de la capa consistan en seis "0", cuatro "0,5" y dos "1"?
#
# ---

# %% [markdown]
# ### Pregunta 6
# Sea $f:]-2\pi,2\pi[\to\mathbb{R}$ dada por
# $$
# f(x)=
# \begin{cases}
# \dfrac{x^2}{1-\cos(x)}, & \text{si } x\neq 0,\\[6pt]
# 1, & \text{si } x=0.
# \end{cases}
# $$
# Entonces:
# a) $\lim\limits_{x\to 0} f(x)=1$
# b) $\lim\limits_{x\to 0} f(x)=2$
# c) $f$ es continua en $x=0$
# d) $f$ es derivable en $x=0$
#
# ---
#
# ### Pregunta 7
# Sean $A, B$ dos sucesos tales que $p(A)=0.7$, $p(B)=0.2$ y $p(A\cap B)=0.14$.
# Selecciónese el o los enunciados correctos:
# a) $A$ y $B$ son independientes.
# b) $p(A\cup B)=0.9$.
# c) $p(A\mid B)=0.7$.
# d) $p(B\mid A)=0.17$.
#
# ---
#
# ### Pregunta 8
# Sea un algoritmo de la forma:
# - Algorithm algorithm1(n)
#     - for i ← 1 to n do
#         - for j ← 1 to n do
#             - C_{i,j} ← algorithm2(i) + algorithm3(j)
#         - end for
#     - end for
#     - return C
#
# Si la complejidad computacional de $algorithm2(k)$ es $O(k^6)$ y la complejidad computacional de $algorithm3(k)$ es $O(k^9)$, ¿cuál es la complejidad computacional de $algorithm1(n)$?
# a) $O(n^5)$
# b) $O(n^9)$
# c) $O(n^{11})$
# d) $O(n^{14})$
#
# ---
#
# ### Pregunta 9
# Selecciónese el o los enunciados verdaderos:
# a) Un problema de decisión resoluble en tiempo polinomial es verificable en tiempo polinomial.
# b) Un problema de decisión no verificable en tiempo polinomial no puede ser resoluble en tiempo polinomial.
# c) Se conocen problemas en $P$ que no pertenecen a $NP$.
# d) Se conocen problemas en $NP$ que no pertenecen a $P$.
#
# ---
#
# ### Pregunta 10
# Sea $A\in\mathbb{R}^{2\times 2}$ simétrica tal que $\det(A)=3$. Selecciónese la o las respuestas correctas:
# a) $A$ es diagonalizable en $\mathbb{R}$ y todos sus autovalores son positivos.
# b) $A$ es diagonalizable en $\mathbb{R}$ y todos sus autovalores tienen el mismo signo.
# c) $A$ es diagonalizable en $\mathbb{R}$ y tiene algún autovalor nulo.
# d) $A$ no necesariamente es diagonalizable en $\mathbb{R}$.
#
# ---

# %% [markdown]
# ### Pregunta 11
# Sea $A\in\mathbb{R}^{n\times n}$ una matriz simétrica con todos sus autovalores positivos. Entonces:
# a) $A$ es definida positiva.
# b) $A$ es diagonalizable.
# c) $\det(A)>0$.
# d) $A$ es regular.
#
# ---
#
# ### Pregunta 12
# Sea $A\in\mathbb{R}^{4\times 4\times 4\times 4\times 4}$ un array multidimensional definido por
# $$
# A_{i,j,k,l,m}= i + jk + l - m,\quad \text{para } i,j,k,l,m\in\{1,2,3,4\}.
# $$
# Entonces $A$ representa…
# a) Un tensor de rango 5 y dimensión 4.
# b) Un tensor de rango 4 y dimensión 5.
# c) Un tensor de rango $5^4$ y dimensión $4^5$.
# d) Un tensor de rango $4^5$ y dimensión $5^4$.
#
# ---
#
# ### Pregunta 13
# Sea $f:\mathbb{R}\to\mathbb{R}$ dada por $f(x)=2x^3-3x^2$.
# Indíquese el punto al que converge el algoritmo de descenso de gradiente para $x_0=0.5$ y un ratio de aprendizaje lo suficientemente pequeño.
#
# ---
#
# ### Pregunta 14
# Sea $f:\mathbb{R}^2\to\mathbb{R}$ dada por $f(x,y)=e^x-y$. Entonces:
# a) $(0,1)$ es un punto crítico de $f$ y se trata de un mínimo relativo.
# b) $(0,1)$ es un punto crítico de $f$ y se trata de un máximo relativo.
# c) $(0,1)$ es un punto crítico de $f$ y se trata de un punto de silla.
# d) $f$ no tiene puntos críticos.
#
# ---
#
# ### Pregunta 15
# Sea $f:\mathbb{R}\to\mathbb{R}^2$ de la forma $f(t)=(f_1(t),f_2(t))$ y $g:\mathbb{R}^2\to\mathbb{R}$, tales que satisfacen:
# $$
# f(0)=(-3,4),\quad f_1'(0)=7,\quad f_2'(0)=-1,
# $$
# $$
# \frac{\partial g}{\partial x}(-3,4)=1,\quad \frac{\partial g}{\partial y}(-3,4)=-2.
# $$
# Obténgase el valor de $[g\circ f]'(0)$.
#
# ---

# %% [markdown]
# ### Pregunta 16
# Un juego de apuestas consiste lanzar un dado con el criterio siguiente:
#
# - Si sale un uno en el dado, el jugador gana 5 euros como premio.
# - Si sale un dos en el dado, el jugador gana 10 euros como premio.
# - Si sale un tres en el dado, el jugador gana 15 euros como premio.
# - Si sale un cuatro en el dado, el jugador gana 20 euros como premio.
# - Si sale un cinco en el dado, el jugador gana 20 euros como premio.
# - Si sale un seis en el dado, el jugador pierde 100 euros.
#
# Obténgase el beneficio esperado del jugador por tirada.
#
# ---

# %% [markdown]
# ## Soluciones (todas juntas)
#
# **Solución 1:** c) $p \lor q$
#
# **Solución 2:** c) $p \land \neg q$
#
# **Solución 3:** b), c) y d)
#
# **Solución 4:** d) $f$ no necesariamente es inyectiva/sobreyectiva/biyectiva.
#
# **Solución 5:** $13860$
#
# **Solución 6:** b) $\lim\limits_{x\to 0} f(x)=2$
#
# **Solución 7:** a) y c)
#
# **Solución 8:** c) $O(n^{11})$
#
# **Solución 9:** a) y b)
#
# **Solución 10:** b)
#
# **Solución 11:** a), b), c) y d)
#
# **Solución 12:** a) Un tensor de rango 5 y dimensión 4.
#
# **Solución 13:** $1$
#
# **Solución 14:** d) $f$ no tiene puntos críticos.
#
# **Solución 15:** $9$
#
# **Solución 16:** $-5$
#
# ---

# %% [markdown]
# # Examen 7

# %% [markdown]
# ### Pregunta 1
# Si la proposición:
# $$
# [(\neg p \lor q)\to(q\leftrightarrow r)] \lor (q\land s)
# $$
# es falsa, siendo $p$ una proposición verdadera. Determine los valores de verdad (V) o falsedad (F) de $\neg q$, $r$ y $\neg s$ en ese orden.
#
# Respuestas:
# - V V V
# - V F V
# - F F V
# - F F F
# - V F F
#
# ---
#
# ### Pregunta 2
# Sea $A\in\mathbb{R}^{n\times n}$ una matriz regular. Selecciónese la opción correcta:
# A) $A$ siempre es simétrica.
# B) $A$ puede ser o no ser diagonalizable.
# C) El signo de los autovalores de $A$ siempre es el mismo.
# D) $\det(A)$ siempre es un número entero.
#
# ---
#
# ### Pregunta 3
# Sea $f:(0,+\infty)\to\mathbb{R}$ dada por $f(x)=\sqrt{x}+3$ y $g:(1,+\infty)\to\mathbb{R}$ dada por $g(x)=\ln(x)$.
# Entonces la expresión de $[f\circ g]'(x)$ para $x>0$ es:
# A) $\ln(\sqrt{x}+3)$
# B) $\dfrac{1}{\sqrt{x}+3}$
# C) $\dfrac{1}{2x+6\sqrt{x}}$
# D) $\dfrac{1}{2x\sqrt{\ln(x)}}$
# E) Ninguna de las otras son correctas.
#
# ---
#
# ### Pregunta 4
# Si $p$ y $q$ son dos proposiciones simples, entonces
# $$
# \neg\big[((\neg p\lor q)\land \neg q)\to \neg p\big]
# $$
# es:
# - Es una contradicción
# - Es una tautología
# - Es contingente
#
# ---
#
# ### Pregunta 5
# Escoja la negación correcta del siguiente enunciado: **Todo el mundo es alto y delgado**.
# Respuestas:
# - Hay alguna persona que es baja y gorda
# - Hay alguna persona que es baja o gorda
# - Nadie es alto y delgado
# - Algunas personas son bajas y gordas
#
# ---

# %% [markdown]
# ### Pregunta 6
# ¿Cuántas letras de 5 signos con 3 rayas y 2 puntos podría tener el alfabeto Morse?
#
# ---
#
# ### Pregunta 7
# Al simplificar
# $$
# [(\neg q\to \neg p)\land \neg(\neg p\to \neg q)]\lor(p\to \neg q)
# $$
# se obtiene:
# A) $p\lor q$
# B) $p\lor \neg q$
# C) $\neg p\lor q$
# D) $\neg(p\land q)$
# E) $p\land q$
#
# ---
#
# ### Pregunta 8
# Sea $A\in\mathbb{R}^{2\times 2}$ una matriz diagonalizable y tal que $\det(A)<0$. Selecciónese la respuesta correcta:
# A) $A$ es definida positiva.
# B) $A$ es definida negativa.
# C) $A$ es simétrica.
# D) Ninguna de las anteriores es correcta.
#
# ---
#
# ### Pregunta 9
# Sea un algoritmo de la forma:
#
# - Algorithm algoritmo1(n)
#     - for i ← 1 to n do
#         - C_i ← algoritmo2(n)
#     - end for
#     - return C
#
#
# Si el coste computacional de ejecutar $algoritmo2(k)$ es
# $$
# c(k)=2^k+k^8+3,
# $$
# ¿cuál es la complejidad computacional de $algoritmo1(n)$?
# A) $O(n^8)$
# B) $O(n^9)$
# C) $O(n2^n)$
# D) Ninguna de las otras opciones.
#
# ---
#
# ### Pregunta 10
# Sea $f:\mathbb{R}^2\to\mathbb{R}$ la función dada por $f(x,y)=2x^3+y+1$. Entonces:
# A) $(0,0)$ es un punto crítico de $f$ y se trata de un mínimo relativo.
# B) $(0,0)$ es un punto crítico de $f$ y se trata de un máximo relativo.
# C) $(0,0)$ es un punto crítico de $f$ y se trata de un punto de silla.
# D) $f$ no tiene puntos críticos.
#
# ---

# %% [markdown]
# ### Pregunta 11
# Dada la función $f:\mathbb{R}\to\mathbb{R}$ cuya gráfica se muestra,
# para un ratio de aprendizaje lo suficientemente pequeño, el algoritmo de descenso de gradiente converge para $x_0$, con:
# A) $x_0\in(-4,+\infty)$
# B) $x_0\in\mathbb{R}$
# C) $x_0\in(-4,5)\cup(5,+\infty)$
# D) $x_0\in(-4,+\infty)$
# E) Todas las anteriores son falsas.
#
# ![image.png](attachment:769e577a-b1a9-4aa2-89aa-7009386c8d8d.png)
# ---
#
# ### Pregunta 12
# Sea $f:\mathbb{R}\to\mathbb{R}^2$ de la forma $f(t)=(f_1(t),f_2(t))$ y $g:\mathbb{R}^2\to\mathbb{R}$ tales que satisfacen:
# $$
# f(0)=(7,-2),\quad f_1'(0)=-5,\quad f_2'(0)=2,
# $$
# $$
# \frac{\partial g}{\partial x}(7,-2)=-1,\quad \frac{\partial g}{\partial y}(7,-2)=3.
# $$
# Obténgase el valor de $[g\circ f]'(1)$.
#
# ---
#
# ### Pregunta 13
# Sean $A$ y $B$ dos conjuntos tales que $|A|=7$ y $|B|=5$. Entonces:
# A) Siempre se cumple que $|A\cup B|=7$.
# B) Necesariamente se cumple que $|A\cup B|\le 7$.
# C) Necesariamente se cumple que $|A\cup B|\ge 13$.
# D) Siempre se cumple que $|A\cup B|=13$.
# E) Ninguna de las otras opciones (pues falta información).
#
# ---
#
# ### Pregunta 14
# Sea $f:\mathbb{R}\to\mathbb{R}$ dada por
# $$
# f(x)=
# \begin{cases}
# x+3\cos(x), & \text{si } x<0,\\
# 1, & \text{si } x=0,\\
# e^x-\cos(x)+2, & \text{si } x>0.
# \end{cases}
# $$
# Marque la opción correcta:
# A) $\lim\limits_{x\to 0} f(x)=1$.
# B) $f$ es discontinua.
# C) $f$ es continua en $x=0$.
# D) $f$ es derivable en $x=0$.
# E) Todas las anteriores son falsas.
#
# ---
#
# ### Pregunta 15
# Sea $p(x)$ la función proposicional $4x^2=2x$, donde el universo $U$ comprende todos los enteros. Selecciona la proposición verdadera:
# A) $p(1)$
# B) $p\!\left(\dfrac{1}{2}\right)$
# C) $p(-2)$
# D) $\exists x\in U,\; p(x)$
# E) $\forall x\in U,\; p(x)$
#
# ---
#
# ## Pregunta 16 hasta el final
#
# ### Pregunta 16
# Sea $f:\mathbb{R}\to\mathbb{R}$ dada por
# $$
# f(x)=x^4-8x^2.
# $$
# Indíquese el valor $x$ de la abscisa al que converge el algoritmo de descenso de gradiente para $x_0=-1$ y un ratio de aprendizaje lo suficientemente pequeño.
#
# ---

# %% [markdown]
# ## Soluciones (todas juntas)
#
# **Solución 1:** F F V (para $\neg q$, $r$, $\neg s$)
# **Solución 2:** B) $A$ puede ser o no ser diagonalizable.
# **Solución 3:** D) $\dfrac{1}{2x\sqrt{x}}$  *(opción D en el test)*
# **Solución 4:** Es una contradicción.
# **Solución 5:** Hay alguna persona que es baja o gorda.
#
# **Solución 6:** $10$
# **Solución 7:** D) $\neg(p\land q)$
# **Solución 8:** D) Ninguna de las anteriores es correcta.
# **Solución 9:** C) $O(n2^n)$
# **Solución 10:** D) $f$ no tiene puntos críticos.
#
# **Solución 11:** C) $x_0\in(-4,5)\cup(5,+\infty)$
# **Solución 12:** $11$
# **Solución 13:** E) Ninguna de las otras opciones (falta información).
# **Solución 14:** B) $f$ es discontinua.
# **Solución 15:** D) $\exists x\in U,\; p(x)$
#
# **Solución 16:** $-2$
#
# ---

# %% [markdown]
# # Examen 8

# %% [markdown]
# ### Pregunta 1
# El enunciado $\neg(p \lor \neg q)$ es equivalente a:
# a) $p \lor q$
# b) $\neg p \land q$
# c) $\neg p \lor \neg q$
# d) $\neg p \land \neg q$
#
# ---
#
# ### Pregunta 2
# Sea $p(x)$ el predicado $\forall y \in A,\, \exists x \in A:\; y = x^2$. Entonces:
# a) $p(x)$ es cierto si $A=\mathbb{N}$.
# b) $p(x)$ es cierto si $A=\mathbb{Z}$.
# c) $p(x)$ es cierto si $A=\mathbb{R}$.
# d) $p(x)$ no se cumple en ninguna de las opciones anteriores.
#
# ---
#
# ### Pregunta 3
# Sean $A, B$ conjuntos tales que $|A|=20$, $|B|=10$ y $f: A \to B$ una aplicación. Entonces:
# a) $f$ puede ser inyectiva.
# b) $f$ puede ser sobreyectiva.
# c) $f$ puede ser biyectiva.
# d) $f$ puede tener inversa.
#
# ---
#
# ### Pregunta 4
# ¿Cuántas posibles contraseñas numéricas de 4 dígitos del “0” al “9” existen para desbloquear un teléfono móvil?
# (Escribid el resultado sin puntos ni comas)
#
# ---
#
# ### Pregunta 5
# Sea $f:\mathbb{R}\to\mathbb{R}$ dada por
# $$
# f(x)=
# \begin{cases}
# \sqrt{x^2+1}, & \text{si } x<0,\\
# 0, & \text{si } x=0,\\
# \ln(x+1)+e^x, & \text{si } x>0.
# \end{cases}
# $$
# Entonces:
# a) $\lim\limits_{x\to 0} f(x)=0$
# b) $\lim\limits_{x\to 0} f(x)=1$
# c) $f$ es continua en $x=0$.
# d) $f$ es derivable en $x=0$.
#
# ---

# %% [markdown]
# ### Pregunta 6
# Sean $A$ y $B$ dos sucesos independientes tales que $P(B)=0.6$ y $P(A\cap B)=0.3$. Obténgase $P(A\mid B)$.
# Debe indicarse el resultado exacto, escalado entre 0 y 1 y utilizando la coma "," en lugar del punto "." para indicar la parte decimal.
#
# ---
#
# ### Pregunta 7
# ¿Cuál es la complejidad computacional del siguiente algoritmo que muestra por consola todas las posibles combinaciones de dos vectores?
#
# **Algorithm** Print all combinations “(a,b)”, for $a\in A$ and $b\in B$. $|A|=n$, $|B|=m$.
#
# -for i ← 1 to length(A) do
#     -for j ← 1 to length(B) do
#         -print("(" + A_i + "," + B_j + ")")
#     -end for
# end for
#
# a) $O(n^2)$
# b) $O(n\cdot m)$
# c) $O(n^2+m^2)$
# d) $O(n^2\cdot m^2)$
#
# ---
#
# ### Pregunta 8
# Sean $A, B$ conjuntos tales que $A\subseteq B$. Entonces:
# a) $A\cup B \subseteq A$
# b) $A\cap B \subseteq A$
# c) $B\setminus A \subseteq A$
# d) $A\times B \subseteq A\cup B$
#
# ---
#
# ### Pregunta 9
# Sea $v=(\alpha,-1)$ un vector de $\mathbb{R}^2$. ¿Para qué valor de $\alpha$ se cumple $\|v\|_2^2=\|v\|_1$?
# a) 1
# b) 2
# c) 3
# d) 4
#
# ---
#
# ### Pregunta 10
# Sea $A\in\mathbb{R}^{3\times 3}$ una matriz tal que $\det(A)=2$ y $B\in\mathbb{R}^{3\times 3}$ una matriz diagonalizable cuyos autovalores son $\lambda_1=2$, $\lambda_2=1$, $\lambda_3=3$. Obténgase $\det(2AB)$.
#
# ---

# %% [markdown]
# ### Pregunta 11
# Sea $A\in\mathbb{R}^{2\times 2}$ una matriz simétrica con determinante $\det(A)=-2$. Entonces:
# a) $A$ no es diagonalizable.
# b) $A$ es definida positiva.
# c) $A^2=Id$.
# d) Los autovalores de $A$ son $-\lambda$ y $\dfrac{2}{\lambda}$, $\lambda\in\mathbb{R}$.
#
# ---
#
# ### Pregunta 12
# Encuentra el valor de la siguiente integral:
# $$
# \int_{0}^{3} (x^2+1)\,dx
# $$
#
# ---
#
# ### Pregunta 13
# Un juego de apuestas consiste en lanzar un dado que toma valores $\{1,2,3,4,5,6\}$ con las siguientes condiciones:
# - Si sale un número impar $n$, el jugador paga $n$ euros.
# - Si sale un número par $n$, el jugador gana $n$ euros.
#
# Si el dado está trucado para que cada número impar tenga el triple de probabilidades de salir respecto a un número par, ¿cuál es el beneficio esperado del jugador por tirada?
# Debe indicarse el resultado exacto en formato numérico utilizando la coma "," en lugar del punto "." para indicar la parte decimal.
#
# ---
#
# ### Pregunta 14
# Sea $f:\mathbb{R}^2\to\mathbb{R}$ dada por $f(x,y)=1-x^2-y^2$. Entonces:
# a) $f$ no tiene puntos críticos.
# b) $(0,0)$ es un punto crítico de $f$ y se trata de un mínimo relativo.
# c) $(0,0)$ es un punto crítico de $f$ y se trata de un máximo relativo.
# d) $(0,0)$ es un punto crítico de $f$ y se trata de un punto de silla.
#
# ---
#
# ### Pregunta 15
# Sea $f:\mathbb{R}\to\mathbb{R}^2$ de la forma $f(t)=(f_1(t),f_2(t))$ y $g:\mathbb{R}^2\to\mathbb{R}$, tales que satisfacen:
# $$
# f(0)=(1,0),\quad f_1'(0)=-2,\quad f_2'(0)=1,
# $$
# $$
# \frac{\partial g}{\partial x}(1,0)=1,\quad \frac{\partial g}{\partial y}(1,0)=4.
# $$
# Obténgase el valor de $[g\circ f]'(0)$.
#
# ---

# %% [markdown]
# ### Pregunta 16
# ¿Cuánto debe restar una pregunta incorrecta en un examen tipo test con 5 respuestas posibles para que la puntuación esperada al elegir las respuestas al azar sea 0? Considérese que solo una respuesta (de 5 posibles) es verdadera por pregunta y que una pregunta correcta vale un punto.
#
# a) $\dfrac{1}{2}$
# b) $\dfrac{1}{3}$
# c) $\dfrac{1}{4}$
# d) $\dfrac{1}{5}$
#
# ---

# %% [markdown]
# ## Soluciones (todas juntas)
#
# **Solución 1:** b) $\neg p \land q$
# **Solución 2:** d) $p(x)$ no se cumple en ninguna de las opciones anteriores.
# **Solución 3:** b) $f$ puede ser sobreyectiva.
# **Solución 4:** $10000$
# **Solución 5:** b) $\lim\limits_{x\to 0} f(x)=1$
#
# **Solución 6:** $0,5$
# **Solución 7:** b) $O(n\cdot m)$
# **Solución 8:** b) $A\cap B \subseteq A$
# **Solución 9:** a) $1$
# **Solución 10:** $96$
#
# **Solución 11:** d) Los autovalores de $A$ son $-\lambda$ y $\dfrac{2}{\lambda}$.
# **Solución 12:** $12$
# **Solución 13:** $-1,25$
# **Solución 14:** c) máximo relativo en $(0,0)$
# **Solución 15:** $2$
#
# **Solución 16:** c) $\dfrac{1}{4}$

# %% [markdown]
# # Examen 9

# %% [markdown]
# ### Pregunta 1
# El enunciado $p \lor \neg q$ es equivalente a:
# a) $\neg(\neg p \lor q)$.
# b) $\neg(p \land \neg q)$.
# c) $p \to \neg q$.
# d) $q \to p$.
#
# ---
#
# ### Pregunta 2
# Sea $p(x)$ el predicado $\forall x\in A,\ \exists y\in A:\ x=y^2$. Entonces:
# a) $p(x)$ es cierto si $A=\mathbb{N}$.
# b) $p(x)$ es cierto si $A=\mathbb{Z}$.
# c) $p(x)$ es cierto si $A=\mathbb{Q}$.
# d) $p(x)$ es cierto si $A=\mathbb{R}$.
#
# ---
#
# ### Pregunta 3
# Sean $A,B$ conjuntos tales que $|A|=30$, $|B|=30$ y $f:A\to B$ una aplicación. Entonces:
# a) $f$ puede ser inyectiva.
# b) $f$ puede ser biyectiva.
# c) $f$ puede tener inversa.
# d) Todas las anteriores.
#
# ---
#
# ### Pregunta 4
# ¿Cuántas posibles contraseñas numéricas **sin dígitos repetidos**, de 4 dígitos del “0” al “9” existen para desbloquear un teléfono móvil?
# (Escribid el resultado sin puntos ni comas)
#
# ---
#
# ### Pregunta 5
# Sea $f:\mathbb{R}\to\mathbb{R}$ dada por
# $$
# f(x)=
# \begin{cases}
# \sqrt{x^2}, & \text{si } x>0,\\
# x^2, & \text{si } x\le 0.
# \end{cases}
# $$
# ¿Cuál de las siguientes opciones es falsa?
# a) $\lim\limits_{x\to 0^+} f(x)=0$
# b) $\lim\limits_{x\to 0^-} f(x)=0$
# c) $f$ es continua en $x=0$.
# d) $f$ es derivable en $x=0$.

# %% [markdown]
# ### Pregunta 6
# Si los sucesos $A$ y $B$ forman una partición del espacio muestral $\Omega$, i.e., $\Omega=A\cup B$ y $A\cap B=\varnothing$.
# Calcule la probabilidad del suceso $C$ si $P(A)=0.6$, $P(C\mid A)=0.5$, $P(C\mid B)=\dfrac14$.
# Debe indicar el resultado exacto, escalado entre 0 y 1 y utilizando la coma “,” en lugar del punto “.” para indicar la parte decimal.
#
# ---
#
# ### Pregunta 7
# ¿Cuál es la complejidad computacional del siguiente algoritmo que muestra por consola todas las posibles combinaciones de dos vectores?
#
# **Algorithm** Print all products “$a\cdot b$”, for $a\in A$ and $b\in B$. $|A|=m$, $|B|=n$.
#
# - for i ← 1 to length(A) do
#     - for j ← 1 to length(B) do
#         - print(A_i · B_j)
#     - end for
# - end for
#
# a) $O(m^2)$.
# b) $O(m\cdot n)$.
# c) $O(m^2+n^2)$.
# d) $O(m^2\cdot n^2)$.
#
# ---
#
# ### Pregunta 8
# Sean $A,B$ conjuntos tales que $\varnothing\ne A\subseteq B$. ¿Cuál de las siguientes afirmaciones es siempre falsa?
# a) $A\cup B \subseteq A$.
# b) $A\cap B \subseteq A$.
# c) $B\setminus A \subseteq A$.
# d) $A\times B \subseteq A\cup B$.
#
# ---
#
# ### Pregunta 9
# Sea $v=(\alpha,-2)$ un vector de $\mathbb{R}^2$. ¿Para cuántos valores **no negativos** de $\alpha$ se cumple
# $$
# \|v\|_2^2=2\|v\|_1?
# $$
# a) 1
# b) 2
# c) 3
# d) 0
#
# ---
#
# ### Pregunta 10
# Sea $A=(a_{ij})\in\mathbb{R}^{3\times 3}$ una matriz de ceros excepto los valores $a_{13}=a_{22}=a_{31}=1$ y $B\in\mathbb{R}^{3\times 3}$ una matriz diagonalizable cuyos autovalores son $\lambda_1=-1$, $\lambda_2=1$, $\lambda_3=3$.
# Calcule $\det(-2AB)$.
#
# ---

# %% [markdown]
# ### Pregunta 11
# Sea $A\in\mathbb{R}^{2\times 2}$ una matriz simétrica con determinante $\det(A)=-1$. Entonces:
# a) $A$ no es diagonalizable.
# b) $A$ es definida negativa.
# c) $A^2=Id$.
# d) Los autovalores de $A$ son $\lambda$ y $-\dfrac{1}{\lambda}$, para algún $\lambda\in\mathbb{R}\setminus\{0\}$.
#
# ---
#
# ### Pregunta 12
# Encuentra el valor de la siguiente integral:
# $$
# \int_{0}^{2} (5x^4+1)\,dx
# $$
#
# ---
#
# ### Pregunta 13
# Un juego de apuestas consiste en lanzar un dado que toma valores $\{1,2,3,4,5,6\}$ con las siguientes condiciones:
# - Si sale un número impar $n$, el jugador paga $n$ euros.
# - Si sale un número par $n$, el jugador gana $n$ euros.
#
# Si el dado está trucado de modo que la probabilidad de que salga un número impar es el doble de la probabilidad de que salga un número par, ¿cuál es el beneficio esperado del jugador por tirada?
# Debe indicarse el resultado exacto en formato numérico utilizando la coma “,” en lugar del punto “.” para indicar la parte decimal.
#
# ---
#
# ### Pregunta 14
# (No disponible)
#
# ---
#
# ### Pregunta 15
# Sean $f:\mathbb{R}^2\to\mathbb{R}$ y $g:\mathbb{R}\to\mathbb{R}^2$ de la forma $g(t)=(g_1(t),g_2(t))$, tales que
# $$
# g(0)=(1,0),\quad \frac{\partial f}{\partial x}(1,0)=1,\quad \frac{\partial f}{\partial y}(1,0)=4,\quad g_1'(0)=-2,\quad g_2'(0)=1.
# $$
# Obténgase el valor de $[f\circ g]'(0)$.
#
# ---
#
# ## Pregunta 16 hasta el final
#
# ### Pregunta 16
# ¿Cuánto restaría una pregunta incorrecta en un examen tipo test con 5 opciones posibles de respuesta para que la puntuación esperada al elegir las respuestas al azar sea $-1/5$?
# Supongamos que cada pregunta tiene sólo una respuesta correcta y que una pregunta correcta vale un punto.
#
# a) $\dfrac12$
# b) $\dfrac13$
# c) $\dfrac14$
# d) $\dfrac15$
#
# ---

# %% [markdown]
# ## Soluciones (todas juntas)
#
# **Solución 1:** (No disponible)
# **Solución 2:** (No disponible)
# **Solución 3:** (No disponible)
# **Solución 4:** (No disponible)
# **Solución 5:** (No disponible)
#
# **Solución 6:** (No disponible)
# **Solución 7:** (No disponible)
# **Solución 8:** (No disponible)
# **Solución 9:** (No disponible)
# **Solución 10:** (No disponible)
#
# **Solución 11:** (No disponible)
# **Solución 12:** (No disponible)
# **Solución 13:** (No disponible)
# **Solución 14:** (No disponible)
# **Solución 15:** (No disponible)
#
# **Solución 16:** (No disponible)
#
# ---

# %% [markdown]
# # Examen 10

# %% [markdown]
# ### Pregunta 1
# El enunciado $\neg(\neg p \land \neg q)$ es equivalente a:
# a) $p \land q$
# b) $\neg p \land \neg q$
# c) $p \lor q$
# d) $\neg p \lor \neg q$
#
# ---
#
# ### Pregunta 2
# Sean $p, q$ proposiciones lógicas tales que $p \to q$ es falsa. Entonces:
# a) Siempre se cumple que $p \land q$ es verdadera.
# b) Siempre se cumple que $\neg p \land q$ es verdadera.
# c) Siempre se cumple que $p \land \neg q$ es verdadera.
# d) Siempre se cumple que $\neg p \land \neg q$ es verdadera.
#
# ---
#
# ### Pregunta 3
# Sea $p(x)$ el predicado $\exists y \in \mathbb{R}:\; xy = 1$. Entonces:
# a) Se cumple $p(0)$.
# b) Se cumple $p(4)$.
# c) Se cumple $p(-\pi)$.
# d) Se cumple $p(x)$, $\forall x \in \mathbb{R}\setminus\{0\}$.
#
# ---
#
# ### Pregunta 4
# Sean $A, B$ conjuntos finitos tales que $|A|=|B|$ y $f:A\to B$ una aplicación. Entonces:
# a) Necesariamente $f$ tiene que ser inyectiva.
# b) Necesariamente $f$ tiene que ser sobreyectiva.
# c) Necesariamente $f$ tiene que ser biyectiva.
# d) $f$ no necesariamente es inyectiva/sobreyectiva/biyectiva.
#
# ---
#
# ### Pregunta 5
# Se considera una red neuronal cuyas neuronas de su capa de salida únicamente pueden tomar tres valores: "0", "0,5" y "1".
# Si dicha capa está formada por 12 neuronas, ¿cuántos posibles outputs podemos obtener de forma que los valores de activación de la capa consistan en seis "0", cuatro "0,5" y dos "1"?
#
# ---

# %% [markdown]
# ### Pregunta 6
# Sea $f:]-2\pi,2\pi[\to\mathbb{R}$ dada por
# $$
# f(x)=
# \begin{cases}
# \dfrac{x^2}{1-\cos(x)}, & \text{si } x\neq 0,\\[6pt]
# 1, & \text{si } x=0.
# \end{cases}
# $$
# Entonces:
# a) $\lim\limits_{x\to 0} f(x)=1$
# b) $\lim\limits_{x\to 0} f(x)=2$
# c) $f$ es continua en $x=0$
# d) $f$ es derivable en $x=0$
#
# ---
#
# ### Pregunta 7
# Sean $A, B$ dos sucesos tales que $p(A)=0.7$, $p(B)=0.2$ y $p(A\cap B)=0.14$.
# Selecciónese el o los enunciados correctos:
# a) $A$ y $B$ son independientes.
# b) $p(A\cup B)=0.9$.
# c) $p(A\mid B)=0.7$.
# d) $p(B\mid A)=0.17$.
#
# ---
#
# ### Pregunta 8
# Sea un algoritmo de la forma:
#
# - Algorithm algorithm1(n)
#     - for i ← 1 to n do
#         - for j ← 1 to n do
#             - C_{i,j} ← algorithm2(i) + algorithm3(j)
#         - end for
#     - end for
#     - return C
#
# Si la complejidad computacional de $algorithm2(k)$ es $O(k^6)$ y la complejidad computacional de $algorithm3(k)$ es $O(k^9)$, ¿cuál es la complejidad computacional de $algorithm1(n)$?
# a) $O(n^5)$
# b) $O(n^9)$
# c) $O(n^{11})$
# d) $O(n^{14})$
#
# ---
#
# ### Pregunta 9
# Selecciónese el o los enunciados verdaderos:
# a) Un problema de decisión resoluble en tiempo polinomial es verificable en tiempo polinomial.
# b) Un problema de decisión no verificable en tiempo polinomial no puede ser resoluble en tiempo polinomial.
# c) Se conocen problemas en $P$ que no pertenecen a $NP$.
# d) Se conocen problemas en $NP$ que no pertenecen a $P$.
#
# ---
#
# ### Pregunta 10
# Sea $A\in\mathbb{R}^{2\times 2}$ simétrica tal que $\det(A)=3$. Selecciónese la o las respuestas correctas:
# a) $A$ es diagonalizable en $\mathbb{R}$ y todos sus autovalores son positivos.
# b) $A$ es diagonalizable en $\mathbb{R}$ y todos sus autovalores tienen el mismo signo.
# c) $A$ es diagonalizable en $\mathbb{R}$ y tiene algún autovalor nulo.
# d) $A$ no necesariamente es diagonalizable en $\mathbb{R}$.
#
# ---

# %% [markdown]
# ### Pregunta 11
# Sea $A\in\mathbb{R}^{n\times n}$ una matriz simétrica con todos sus autovalores positivos. Entonces:
# a) $A$ es definida positiva.
# b) $A$ es diagonalizable.
# c) $\det(A)>0$.
# d) $A$ es regular.
#
# ---
#
# ### Pregunta 12
# Sea $A\in\mathbb{R}^{4\times 4\times 4\times 4\times 4}$ un array multidimensional definido por
# $$
# A_{i,j,k,l,m}= i + jk + l - m,\quad \text{para } i,j,k,l,m\in\{1,2,3,4\}.
# $$
# Entonces $A$ representa…
# a) Un tensor de rango 5 y dimensión 4.
# b) Un tensor de rango 4 y dimensión 5.
# c) Un tensor de rango $5^4$ y dimensión $4^5$.
# d) Un tensor de rango $4^5$ y dimensión $5^4$.
#
# ---
#
# ### Pregunta 13
# Sea $f:\mathbb{R}\to\mathbb{R}$ dada por $f(x)=2x^3-3x^2$.
# Indíquese el punto al que converge el algoritmo de descenso de gradiente para $x_0=0.5$ y un ratio de aprendizaje lo suficientemente pequeño.
#
# ---
#
# ### Pregunta 14
# Sea $f:\mathbb{R}^2\to\mathbb{R}$ dada por $f(x,y)=e^x-y$. Entonces:
# a) $(0,1)$ es un punto crítico de $f$ y se trata de un mínimo relativo.
# b) $(0,1)$ es un punto crítico de $f$ y se trata de un máximo relativo.
# c) $(0,1)$ es un punto crítico de $f$ y se trata de un punto de silla.
# d) $f$ no tiene puntos críticos.
#
# ---
#
# ### Pregunta 15
# Sea $f:\mathbb{R}\to\mathbb{R}^2$ de la forma $f(t)=(f_1(t),f_2(t))$ y $g:\mathbb{R}^2\to\mathbb{R}$, tales que satisfacen:
# $$
# f(0)=(-3,4),\quad f_1'(0)=7,\quad f_2'(0)=-1,
# $$
# $$
# \frac{\partial g}{\partial x}(-3,4)=1,\quad \frac{\partial g}{\partial y}(-3,4)=-2.
# $$
# Obténgase el valor de $[g\circ f]'(0)$.
#
# ---
#
# ### Pregunta 16
# Un juego de apuestas consiste lanzar un dado con el criterio siguiente:
#
# - Si sale un uno en el dado, el jugador gana 5 euros como premio.
# - Si sale un dos en el dado, el jugador gana 10 euros como premio.
# - Si sale un tres en el dado, el jugador gana 15 euros como premio.
# - Si sale un cuatro en el dado, el jugador gana 20 euros como premio.
# - Si sale un cinco en el dado, el jugador gana 20 euros como premio.
# - Si sale un seis en el dado, el jugador pierde 100 euros.
#
# Obténgase el beneficio esperado del jugador por tirada.
#
# ---

# %% [markdown]
# ## Soluciones (todas juntas)
#
# **Solución 1:** c) $p \lor q$
# **Solución 2:** c) $p \land \neg q$
# **Solución 3:** b), c) y d)
# **Solución 4:** d) $f$ no necesariamente es inyectiva/sobreyectiva/biyectiva.
# **Solución 5:** $13860$
#
# **Solución 6:** b) $\lim\limits_{x\to 0} f(x)=2$
# **Solución 7:** a) y c)
# **Solución 8:** c) $O(n^{11})$
# **Solución 9:** a) y b)
# **Solución 10:** b)
#
# **Solución 11:** a), b), c) y d)
# **Solución 12:** a) Un tensor de rango 5 y dimensión 4.
# **Solución 13:** $1$
# **Solución 14:** d) $f$ no tiene puntos críticos.
# **Solución 15:** $9$
#
# **Solución 16:** $-5$
#
# ---

# %% [markdown]
# # Examen 11

# %% [markdown]
# ### Pregunta 1
# Dada la función $f:\mathbb{R}\to\mathbb{R}$ cuya gráfica es (ver figura).
# Para un ratio de aprendizaje lo suficientemente pequeño, el algoritmo de descenso de gradiente converge para $x_0$, con:
# **(Opciones: No disponible)**
#
# ---
#
# ### Pregunta 2
# Sean $p$ y $q$ dos proposiciones. Clasifica la fórmula lógica
# $$
# ((p\to q)\land \neg q)\to \neg p
# $$
#
# ---
#
# ### Pregunta 3
# Una profesora quiere poner un examen con siete preguntas. Si tiene un banco con diez preguntas diferentes creadas, ¿cuántos modelos de exámenes puede crearse donde se presenten las siete preguntas a la vez?
# (La respuesta debe ser solo un número.)
#
# ---
#
# ### Pregunta 4
# Sea $A\in\mathbb{R}^{n\times n}$ una matriz simétrica. Selecciónese la o las respuestas correctas:
# **(Opciones: No disponible)**
#
# ---
#
# ### Pregunta 5
# Sea $f:\mathbb{R}\to\mathbb{R}$ dada por
# $$
# f(x)=
# \begin{cases}
# x\,e^{x-2}, & \text{si } x\neq 2,\\
# 1, & \text{si } x=2.
# \end{cases}
# $$
# **(Enunciado incompleto en el documento: No disponible)**
#
# ---

# %% [markdown]
# ### Pregunta 6
# Sean $A$ y $B$ dos conjuntos tales que $|A|=7$ y $|B|=5$. Entonces:
# **(Opciones/continuación: No disponible)**
#
# ---
#
# ### Pregunta 7
# Sea $A\in\mathbb{R}^{2\times 2}$ una matriz diagonalizable y tal que $\det(A)>0$. Selecciónese la o las respuestas correctas:
# **(Opciones: No disponible)**
#
# ---
#
# ### Pregunta 8
# Sean $f:(0,+\infty)\to\mathbb{R}$ dada por $f(x)=\sqrt{x}+3$ y $g:(0,+\infty)\to\mathbb{R}$ dada por $g(x)=\ln(x)$.
# Entonces, la expresión de $[g\circ f]'(x)$ para $x>0$ es:
# **(Opciones: No disponible)**
#
# ---
#
# ### Pregunta 9
# Sea $f:\mathbb{R}^2\to\mathbb{R}$ la función dada por
# $$
# f(x,y)=2e^x+y^4+1.
# $$
# Entonces:
# **(Opciones/continuación: No disponible)**
#
# ---
#
# ### Pregunta 10
# Sean $p,q,r$ las proposiciones siguientes:
# - $p$: Obtener un sobresaliente en el examen final.
# - $q$: Hacer todos los ejercicios de este libro.
# - $r$: Tener un sobresaliente en esta asignatura.
#
# Escribe, utilizando las anteriores proposiciones y los conectivos lógicos pertinentes, la siguiente proposición:
#
# “Conseguir un sobresaliente en el examen final y realizar todos los ejercicios de este libro es suficiente para obtener un sobresaliente en esta asignatura.”
#
# ---

# %% [markdown]
# ## Preguntas 11–15
#
# ### Pregunta 11
# Sea un algoritmo de la forma:
#
# - Algorithm algoritmo1(n)
#     - for i ← 1 to n do
#         - C_i ← algoritmo2(n)
#     - end for
# - return C
#
# Si el coste computacional de ejecutar $algoritmo2(k)$ es
# $$
# c(k)=k^2+2k+3,
# $$
# ¿cuál es la complejidad computacional de $algoritmo1(n)$?
#
# ---
#
# ### Pregunta 12
# Sea el universo consistente en el conjunto formado por los números enteros, $\mathbb{Z}$,
# y sobre dicho universo definimos el predicado $p(x,y)$ como
# $$
# \exists k\in\mathbb{Z}:\ y=k\cdot x.
# $$
# Entonces:
# **(Opciones/continuación: No disponible)**
#
# ---
#
# ### Pregunta 13
# Escoja la negación correcta del siguiente enunciado:
#
# “A algunas personas le gustan las Matemáticas”.
#
# ---
#
# ### Pregunta 14
# Sea $f:\mathbb{R}^2\to\mathbb{R}^2$ dada por
# $$
# f(x,y)=(3x^2+y,\;xy+1)
# $$
# y sea $g:\mathbb{R}^2\to\mathbb{R}$ una función cuyo gradiente en el punto $(2,0)$ es $(0,8)$. Entonces,
# $$
# \frac{\partial[g\circ f]}{\partial x}(1,-1)+\frac{\partial[g\circ f]}{\partial y}(1,-1)
# $$
# es igual a
#
# ---
#
# ### Pregunta 15
# (No disponible)
#
# ---

# %% [markdown]
# ## Soluciones (todas juntas)
#
# **Solución 1:** (No disponible)
#
# **Solución 2:** (No disponible)
#
# **Solución 3:** (No disponible)
#
# **Solución 4:** (No disponible)
#
# **Solución 5:** (No disponible)
#
# **Solución 6:** (No disponible)
#
# **Solución 7:** (No disponible)
#
# **Solución 8:** (No disponible)
#
# **Solución 9:** (No disponible)
#
# **Solución 10:**
# $$
# (p\land q)\to r
# $$
#
# **Solución 11:**
# $$
# O\big(n\cdot (n^2+2n+3)\big)=O(n^3)
# $$
#
# **Solución 12:** (No disponible)
#
# **Solución 13:** “A nadie le gustan las Mat

# %% [markdown]
# # Examen 12

# %% [markdown]
# ### Pregunta 1
# Si la proposición:
# $$
# [(\neg p \lor q)\to(q\leftrightarrow r)] \lor (q\land s)
# $$
# es falsa, siendo $p$ una proposición verdadera. Determine los valores de verdad (V) o falsedad (F) de $\neg q$, $r$ y $\neg s$ en ese orden.
#
# Respuestas:
# - V V V
# - V F V
# - F F V
# - F F F
# - V F F
#
# ---
#
# ### Pregunta 2
# Sea $A\in\mathbb{R}^{n\times n}$ una matriz regular. Selecciónese la opción correcta:
# A) $A$ siempre es simétrica.
# B) $A$ puede ser o no ser diagonalizable.
# C) El signo de los autovalores de $A$ siempre es el mismo.
# D) $\det(A)$ siempre es un número entero.
#
# ---
#
# ### Pregunta 3
# Sea $f:(0,+\infty)\to\mathbb{R}$ dada por $f(x)=\sqrt{x}+3$ y $g:(1,+\infty)\to\mathbb{R}$ dada por $g(x)=\ln(x)$.
# Entonces la expresión de $[f\circ g]'(x)$ para $x>0$ es:
# A) $\ln(\sqrt{x}+3)$
# B) $\dfrac{1}{\sqrt{x}+3}$
# C) $\dfrac{1}{2x+6\sqrt{x}}$
# D) $\dfrac{1}{2x\sqrt{\ln(x)}}$
# E) Ninguna de las otras son correctas.
#
# ---
#
# ### Pregunta 4
# Si $p$ y $q$ son dos proposiciones simples, entonces
# $$
# \neg\big[((\neg p\lor q)\land \neg q)\to \neg p\big]
# $$
# es:
# - Es una contradicción
# - Es una tautología
# - Es contingente
#
# ---
#
# ### Pregunta 5
# Escoja la negación correcta del siguiente enunciado: **Todo el mundo es alto y delgado**.
# Respuestas:
# - Hay alguna persona que es baja y gorda
# - Hay alguna persona que es baja o gorda
# - Nadie es alto y delgado
# - Algunas personas son bajas y gordas
#
# ---

# %% [markdown]
# ### Pregunta 6
# ¿Cuántas letras de 5 signos con 3 rayas y 2 puntos podría tener el alfabeto Morse?
#
# ---
#
# ### Pregunta 7
# Al simplificar
# $$
# [(\neg q\to \neg p)\land \neg(\neg p\to \neg q)]\lor(p\to \neg q)
# $$
# se obtiene:
# A) $p\lor q$
# B) $p\lor \neg q$
# C) $\neg p\lor q$
# D) $\neg(p\land q)$
# E) $p\land q$
#
# ---
#
# ### Pregunta 8
# Sea $A\in\mathbb{R}^{2\times 2}$ una matriz diagonalizable y tal que $\det(A)<0$. Selecciónese la respuesta correcta:
# A) $A$ es definida positiva.
# B) $A$ es definida negativa.
# C) $A$ es simétrica.
# D) Ninguna de las anteriores es correcta.
#
# ---
#
# ### Pregunta 9
# Sea un algoritmo de la forma:
#
# - Algorithm algoritmo1(n)
#     - for i ← 1 to n do
#         - C_i ← algoritmo2(n)
#     - end for
#     - return C
#
#
# Si el coste computacional de ejecutar $algoritmo2(k)$ es
# $$
# c(k)=2^k+k^8+3,
# $$
# ¿cuál es la complejidad computacional de $algoritmo1(n)$?
# A) $O(n^8)$
# B) $O(n^9)$
# C) $O(n2^n)$
# D) Ninguna de las otras opciones.
#
# ---
#
# ### Pregunta 10
# Sea $f:\mathbb{R}^2\to\mathbb{R}$ la función dada por $f(x,y)=2x^3+y+1$. Entonces:
# A) $(0,0)$ es un punto crítico de $f$ y se trata de un mínimo relativo.
# B) $(0,0)$ es un punto crítico de $f$ y se trata de un máximo relativo.
# C) $(0,0)$ es un punto crítico de $f$ y se trata de un punto de silla.
# D) $f$ no tiene puntos críticos.
#
# ---

# %% [markdown]
# ### Pregunta 11
# Dada la función $f:\mathbb{R}\to\mathbb{R}$ cuya gráfica se muestra,
# para un ratio de aprendizaje lo suficientemente pequeño, el algoritmo de descenso de gradiente converge para $x_0$, con:
# A) $x_0\in(-4,+\infty)$
# B) $x_0\in\mathbb{R}$
# C) $x_0\in(-4,5)\cup(5,+\infty)$
# D) $x_0\in(-4,+\infty)$
# E) Todas las anteriores son falsas.
#
# ---
#
# ### Pregunta 12
# Sea $f:\mathbb{R}\to\mathbb{R}^2$ de la forma $f(t)=(f_1(t),f_2(t))$ y $g:\mathbb{R}^2\to\mathbb{R}$, tales que satisfacen:
# $$
# f(0)=(7,-2),\quad f_1'(0)=-5,\quad f_2'(0)=2,
# $$
# $$
# \frac{\partial g}{\partial x}(7,-2)=-1,\quad \frac{\partial g}{\partial y}(7,-2)=3.
# $$
# Obténgase el valor de $[g\circ f]'(1)$.
#
# ---
#
# ### Pregunta 13
# Sean $A$ y $B$ dos conjuntos tales que $|A|=7$ y $|B|=5$. Entonces:
# A) Siempre se cumple que $|A\cup B|=7$.
# B) Necesariamente se cumple que $|A\cup B|\le 7$.
# C) Necesariamente se cumple que $|A\cup B|\ge 13$.
# D) Siempre se cumple que $|A\cup B|=13$.
# E) Ninguna de las otras opciones (pues falta información).
#
# ---
#
# ### Pregunta 14
# Sea $f:\mathbb{R}\to\mathbb{R}$ dada por
# $$
# f(x)=
# \begin{cases}
# x+3\cos(x), & \text{si } x<0,\\
# 1, & \text{si } x=0,\\
# e^x-\cos(x)+2, & \text{si } x>0.
# \end{cases}
# $$
# Marque la opción correcta:
# A) $\lim\limits_{x\to 0} f(x)=1$.
# B) $f$ es discontinua.
# C) $f$ es continua en $x=0$.
# D) $f$ es derivable en $x=0$.
# E) Todas las anteriores son falsas.
#
# ---
#
# ### Pregunta 15
# Sea $p(x)$ la función proposicional $4x^2=2x$, donde el universo $U$ comprende todos los enteros. Selecciona la proposición verdadera:
# A) $p(1)$
# B) $p\!\left(\dfrac{1}{2}\right)$
# C) $p(-2)$
# D) $\exists x\in U,\; p(x)$
# E) $\forall x\in U,\; p(x)$
#
# ---
#
# ### Pregunta 16
# Sea $f:\mathbb{R}\to\mathbb{R}$ dada por
# $$
# f(x)=x^4-8x^2.
# $$
# Indíquese el valor $x$ de la abscisa al que converge el algoritmo de descenso de gradiente para $x_0=-1$ y un ratio de aprendizaje lo suficientemente pequeño.
#
# ---

# %% [markdown]
# ## Soluciones (todas juntas)
#
# **Solución 1:** F F V (para $\neg q$, $r$, $\neg s$)
# **Solución 2:** Opción B
# **Solución 3:** Opción D, $\dfrac{1}{2x\sqrt{\ln(x)}}$
# **Solución 4:** Es una contradicción
# **Solución 5:** Hay alguna persona que es baja o gorda
#
# **Solución 6:** $10$
# **Solución 7:** Opción D, $\neg(p\land q)$
# **Solución 8:** Opción D
# **Solución 9:** Opción C, $O(n2^n)$
# **Solución 10:** Opción D
#
# **Solución 11:** Opción C
# **Solución 12:** $11$
# **Solución 13:** Opción E
# **Solución 14:** (Según las marcas del documento) B, C, D y E
# **Solución 15:** Opción A
#
# **Solución 16:** $-2$
#
# ---

# %% [markdown]
# # Examen 13

# %% [markdown]
# ### Pregunta 1
# Dada la función $f:\mathbb{R}\to\mathbb{R}$ cuya gráfica es (ver figura).
# Para un ratio de aprendizaje lo suficientemente pequeño, el algoritmo de descenso de gradiente converge para $x_0$, con:
# **(Opciones: No disponible)**
#
# ---
#
# ### Pregunta 2
# Sean $p$ y $q$ dos proposiciones. Clasifica la fórmula lógica:
# $$
# ((p\to q)\land \neg q)\to \neg p
# $$
#
# ---
#
# ### Pregunta 3
# Una profesora quiere poner un examen con siete preguntas. Si tiene un banco con diez preguntas diferentes creadas, ¿cuántos modelos de exámenes puede crearse donde se presenten las siete preguntas a la vez?
# (La respuesta debe ser solo un número.)
#
# ---
#
# ### Pregunta 4
# Sea $A\in\mathbb{R}^{n\times n}$ una matriz simétrica. Selecciónese la o las respuestas correctas:
# **(Opciones: No disponible)**
#
# ---
#
# ### Pregunta 5
# Sea $f:\mathbb{R}\to\mathbb{R}$ dada por
# $$
# f(x)=
# \begin{cases}
# x\,e^{x-2}, & \text{si } x\neq 2,\\
# 1, & \text{si } x=2.
# \end{cases}
# $$
# **(Enunciado/opciones incompletos en el documento: No disponible)**
#
# ---

# %% [markdown]
# ### Pregunta 6
# Sean $A$ y $B$ dos conjuntos tales que $|A|=7$ y $|B|=5$. Entonces:
# **(Opciones: No disponible)**
#
# ---
#
# ### Pregunta 7
# Sea $A\in\mathbb{R}^{2\times 2}$ una matriz diagonalizable y tal que $\det(A)>0$. Selecciónese la o las respuestas correctas:
# **(Opciones: No disponible)**
#
# ---
#
# ### Pregunta 8
# Sean $f:(0,+\infty)\to\mathbb{R}$ dada por $f(x)=\sqrt{x}+3$ y $g:(0,+\infty)\to\mathbb{R}$ dada por $g(x)=\ln(x)$.
# Entonces, la expresión de $[g\circ f]'(x)$ para $x>0$ es:
# **(Opciones: No disponible)**
#
# ---
#
# ### Pregunta 9
# Sea $f:\mathbb{R}^2\to\mathbb{R}$ la función dada por
# $$
# f(x,y)=2e^x+y^4+1.
# $$
# Entonces:
# **(Opciones: No disponible)**
#
# ---
#
# ### Pregunta 10
# Sean $p,q,r$ las proposiciones siguientes:
# - $p$: Obtener un sobresaliente en el examen final.
# - $q$: Hacer todos los ejercicios de este libro.
# - $r$: Tener un sobresaliente en esta asignatura.
#
# Escribe, utilizando las anteriores proposiciones y los conectivos lógicos pertinentes, la siguiente proposición:
#
# “Conseguir un sobresaliente en el examen final y realizar todos los ejercicios de este libro es suficiente para obtener un sobresaliente en esta asignatura.”
#
# ---

# %% [markdown]
# ### Pregunta 11
# Sea un algoritmo de la forma:
#
# - Algorithm algoritmo1(n)
#     - for i ← 1 to n do
#         - C_i ← algoritmo2(n)
#     - end for
#     - return C
#
# Si el coste computacional de ejecutar $algoritmo2(k)$ es
# $$
# c(k)=k^2+2k+3,
# $$
# ¿cuál es la complejidad computacional de $algoritmo1(n)$?
#
# ---
#
# ### Pregunta 12
# Sea el universo consistente en el conjunto formado por los números enteros, $\mathbb{Z}$,
# y sobre dicho universo definimos el predicado $p(x,y)$ como
# $$
# \exists k\in\mathbb{Z}:\ y=k\cdot x.
# $$
# Entonces:
# **(Opciones: No disponible)**
#
# ---
#
# ### Pregunta 13
# Escoja la negación correcta del siguiente enunciado:
#
# “A algunas personas le gustan las Matemáticas”.
#
# ---
#
# ### Pregunta 14
# Sea $f:\mathbb{R}^2\to\mathbb{R}^2$ dada por
# $$
# f(x,y)=(3x^2+y,\;xy+1)
# $$
# y sea $g:\mathbb{R}^2\to\mathbb{R}$ una función cuyo gradiente en el punto $(2,0)$ es $(0,8)$. Entonces,
# $$
# \frac{\partial[g\circ f]}{\partial x}(1,-1)+\frac{\partial[g\circ f]}{\partial y}(1,-1)
# $$
# es igual a
#
# ---
#
# ### Pregunta 15
# (No disponible)
#
# ---

# %% [markdown]
# ## Soluciones (todas juntas)
#
# **Solución 1:** (No disponible)
#
# **Solución 2:** Es una **tautología** (modus tollens):
# $$
# ((p\to q)\land \neg q)\to \neg p
# $$
#
# **Solución 3:** $120$
#
# **Solución 4:** (No disponible)
#
# **Solución 5:** (No disponible)
#
# **Solución 6:** (No disponible)
#
# **Solución 7:** (No disponible)
#
# **Solución 8:**
# $$
# [g\circ f]'(x)=\frac{1}{2\sqrt{x}\,(\sqrt{x}+3)}=\frac{1}{2x+6\sqrt{x}}
# $$
#
# **Solución 9:** $f$ **no tiene puntos críticos** (no existe $x$ tal que $2e^x=0$).
#
# **Solución 10:**
# $$
# (p\land q)\to r
# $$
#
# **Solución 11:**
# $$
# O\big(n\cdot (n^2+2n+3)\big)=O(n^3)
# $$
#
# **Solución 12:** (No disponible)
#
# **Solución 13:** “A nadie le gustan las Matemáticas”.
#
# **Solución 14:** $0$
#
# **Solución 15:** (No disponible)
#
# **Solución 16:** (No disponible)
#
# ---
