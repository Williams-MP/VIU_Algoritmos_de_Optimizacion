# %% [markdown]
# # Actividad - Proyecto práctico
#
#
# > La actividad se desarrollará en grupos pre-definidos de 4 alumnos. Se debe indicar los nombres en orden alfabético (de apellidos). Recordad que esta actividad se corresponde con un 30% de la nota final de la asignatura. Se debe entregar entregar el trabajo en la presente notebook.
# *   Alumno 1:
# *   Alumno 2:
# *   Alumno 3:
# *   Alumno 4:

# %% [markdown]
# ---
# ## **PARTE 1** - Instalación y requisitos previos
#
# > Las prácticas han sido preparadas para poder realizarse en el entorno de trabajo de Google Colab. Sin embargo, esta plataforma presenta ciertas incompatibilidades a la hora de visualizar la renderización en gym. Por ello, para obtener estas visualizaciones, se deberá trasladar el entorno de trabajo a local. Por ello, el presente dosier presenta instrucciones para poder trabajar en ambos entornos. Siga los siguientes pasos para un correcto funcionamiento:
# 1.   **LOCAL:** Preparar el enviroment, siguiendo las intrucciones detalladas en la sección *1.1.Preparar enviroment*.
# 2.  **AMBOS:** Modificar las variables "mount" y "drive_mount" a la carpeta de trabajo en drive en el caso de estar en Colab, y ejecturar la celda *1.2.Localizar entorno de trabajo*.
# 3. **COLAB:** se deberá ejecutar las celdas correspondientes al montaje de la carpeta de trabajo en Drive. Esta corresponde a la sección *1.3.Montar carpeta de datos local*.
# 4.  **AMBOS:** Instalar las librerías necesarias, siguiendo la sección *1.4.Instalar librerías necesarias*.

# %% [markdown]
# ---
# ### 1.1. Preparar enviroment (solo local)
#
#
#
# > Para preparar el entorno de trabajo en local, se han seguido los siguientes pasos:
# 1. En Windows, puede ser necesario instalar las C++ Build Tools. Para ello, siga los siguientes pasos. Alternativamente puedes utilizar WSL2: https://towardsdatascience.com/how-to-install-openai-gym-in-a-windows-environment-338969e24d30.
# 2. Instalar Anaconda
# 3. Siguiendo el código que se presenta comentado en la próxima celda: Crear un enviroment, cambiar la ruta de trabajo, e instalar librerías básicas.
#
#
# ```
# conda create --name miar_rl python=3.8
# conda activate miar_rl
# cd "PATH_TO_FOLDER"
# conda install git
# pip install jupyter
# ```
#
#
# 4. Abrir la notebook con *jupyter-notebook*.
#
#
#
# ```
# jupyter-notebook
# ```

# %% [markdown]
# ---
# ### 1.2. Localizar entorno de trabajo: Google colab o local

# %%
# ATENCIÓN!! Modificar ruta relativa a la práctica si es distinta (drive_root)
mount='/content/gdrive'
drive_root = mount + "/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints"

try:
  from google.colab import drive
  IN_COLAB=True
except:
  IN_COLAB=False

# %% [markdown]
# ---
# ### 1.3. Montar carpeta de datos local (solo Colab)

# %%
# Montamos Drive y fijamos el directorio de trabajo a una carpeta DENTRO de
# Drive (drive_root). Esto es importante para entrenamientos largos (varias
# horas, dejados corriendo sin supervisión): si el runtime de Colab se
# desconecta o se recicla, todo lo que esté solo en el disco local del
# runtime (/content/...) se pierde para siempre. Drive, en cambio, persiste
# independientemente de lo que le pase al runtime.
#
# Nota: el propio mount de Drive puede a veces tardar o pedir reautorización
# en VSCode; si la celda se queda colgada en drive.mount(), revisa si apareció
# una ventana/pestaña de autorización de Google que necesite tu confirmación.
import os

if IN_COLAB:
    print("We're running Colab")
    drive.mount(mount)
    os.makedirs(drive_root, exist_ok=True)
    print("\nColab: Changing directory to", drive_root)
    os.chdir(drive_root)
else:
    print("No estamos en Colab (IN_COLAB=False); se usará el directorio actual del kernel.")

WORK_DIR = os.getcwd()
print("\nDirectorio de trabajo actual:", WORK_DIR)
print("Archivos en el directorio:")
print(os.listdir(WORK_DIR))

# Carpetas de salida, una por propuesta, directamente dentro de drive_root
# (.../VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/). Los checkpoints
# intermedios (ModelIntervalCheckpoint) y los logs se escriben aquí durante
# el entrenamiento, así que sobreviven a una desconexión del runtime.
RESULTS_DIR = WORK_DIR
WEIGHTS_DIR_P1 = os.path.join(RESULTS_DIR, 'p1_eps_fijo')
WEIGHTS_DIR_P2 = os.path.join(RESULTS_DIR, 'p2_annealed')
WEIGHTS_DIR_P3 = os.path.join(RESULTS_DIR, 'p3_boltzmann')
WEIGHTS_DIR_P4 = os.path.join(RESULTS_DIR, 'p4_double_dqn')
WEIGHTS_DIR_P5 = os.path.join(RESULTS_DIR, 'p5_dueling_dqn')
WEIGHTS_DIR_P6 = os.path.join(RESULTS_DIR, 'p6_double_dueling')

for d in [RESULTS_DIR, WEIGHTS_DIR_P1, WEIGHTS_DIR_P2, WEIGHTS_DIR_P3,
          WEIGHTS_DIR_P4, WEIGHTS_DIR_P5, WEIGHTS_DIR_P6]:
    os.makedirs(d, exist_ok=True)

print("\nCarpetas de checkpoints preparadas (en Drive):")
print(" -", WEIGHTS_DIR_P1)
print(" -", WEIGHTS_DIR_P2)
print(" -", WEIGHTS_DIR_P3)
print(" -", WEIGHTS_DIR_P4)
print(" -", WEIGHTS_DIR_P5)
print(" -", WEIGHTS_DIR_P6)
# Out:
# Mounted at /content/gdrive
#
# Colab: Changing directory to /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints
#
# Directorio de trabajo actual: /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints
# Archivos en el directorio:
# ['resultados_enduro_dqn', 'p1_eps_fijo', 'p2_annealed', 'p3_boltzmann', 'p4_double_dqn', 'p5_dueling_dqn', 'p6_double_dueling']
#
# Carpetas de checkpoints preparadas (en Drive):
#  - /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/p1_eps_fijo
#  - /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/p2_annealed
#  - /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/p3_boltzmann
#  - /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/p4_double_dqn
#  - /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/p5_dueling_dqn
#  - /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/p6_double_dueling

# %% [markdown]
# ---
# ### 1.4. Instalar librerías necesarias

# %%
if IN_COLAB:
  # %pip install tensorflow
  # %pip install tf-keras
  # %pip install tensorflow==2.18.0
  # %pip install tf-keras==2.18.0
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install keras-rl2==1.0.5
  # %pip install --upgrade ml_dtypes
else:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install pyglet==1.5.0
  # %pip install h5py==3.1.0
  # %pip install Pillow==9.5.0
  # %pip install keras-rl2==1.0.5
  # %pip install Keras==2.2.4
  # %pip install tensorflow==2.5.3
  # %pip install torch==2.0.1
  # %pip install agents==1.4.0
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.73.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: tf-keras in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: tensorflow<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tf-keras) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (1.73.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<2.19,>=2.18->tf-keras) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow<2.19,>=2.18->tf-keras) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<2.19,>=2.18->tf-keras) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<2.19,>=2.18->tf-keras) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<2.19,>=2.18->tf-keras) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<2.19,>=2.18->tf-keras) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<2.19,>=2.18->tf-keras) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<2.19,>=2.18->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<2.19,>=2.18->tf-keras) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow<2.19,>=2.18->tf-keras) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras) (0.1.2)
# Collecting gym==0.17.3
#   Downloading gym-0.17.3.tar.gz (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 32.3 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.15.3)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (2.0.2)
# Collecting pyglet<=1.5.0,>=1.4.0 (from gym==0.17.3)
#   Downloading pyglet-1.5.0-py2.py3-none-any.whl.metadata (7.6 kB)
# Collecting cloudpickle<1.7.0,>=1.2.0 (from gym==0.17.3)
#   Downloading cloudpickle-1.6.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym==0.17.3) (1.0.0)
# Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Downloading pyglet-1.5.0-py2.py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 90.6 MB/s eta 0:00:00
# Building wheels for collected packages: gym
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.17.3-py3-none-any.whl size=1654617 sha256=acfabd145e33776683fcb19c4a5c1302910b80a0c2e09a0cf48e4383667d8632
#   Stored in directory: /root/.cache/pip/wheels/07/8b/b7/570cb90b10f17e85ccb291ba1f04af41ec697745104a2263eb
# Successfully built gym
# Installing collected packages: pyglet, cloudpickle, gym
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 3.1.1
#     Uninstalling cloudpickle-3.1.1:
#       Successfully uninstalled cloudpickle-3.1.1
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.10.0 requires cloudpickle>=2.0.0, but you have cloudpickle 1.6.0 which is incompatible.
# dask 2024.12.1 requires cloudpickle>=3.0.0, but you have cloudpickle 1.6.0 which is incompatible.
# distributed 2024.12.1 requires cloudpickle>=3.0.0, but you have cloudpickle 1.6.0 which is incompatible.
# Successfully installed cloudpickle-1.6.0 gym-0.17.3 pyglet-1.5.0
# Collecting git+https://github.com/Kojoley/atari-py.git
#   Cloning https://github.com/Kojoley/atari-py.git to /tmp/pip-req-build-p6b9dx9o
#   Running command git clone --filter=blob:none --quiet https://github.com/Kojoley/atari-py.git /tmp/pip-req-build-p6b9dx9o
#   Resolved https://github.com/Kojoley/atari-py.git to commit 86a1e05c0a95e9e6233c3a413521fdb34ca8a089
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from atari-py==1.2.2) (2.0.2)
# Building wheels for collected packages: atari-py
#   Building wheel for atari-py (setup.py) ... done
#   Created wheel for atari-py: filename=atari_py-1.2.2-cp311-cp311-linux_x86_64.whl size=4738557 sha256=6c017aa4e12160b7f05deb86c59546990681e371213aab0426f3ccacd58924d4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vmtbi46b/wheels/1a/58/b3/3baab9d1509939ecce2dfd9ca349c222b7ee6590f4bd6097a1
# Successfully built atari-py
# Installing collected packages: atari-py
# Successfully installed atari-py-1.2.2
# Collecting keras-rl2==1.0.5
#   Downloading keras_rl2-1.0.5-py3-none-any.whl.metadata (304 bytes)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (from keras-rl2==1.0.5) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.73.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow->keras-rl2==1.0.5) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->keras-rl2==1.0.5) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->keras-rl2==1.0.5) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->keras-rl2==1.0.5) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-rl2==1.0.5) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-rl2==1.0.5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-rl2==1.0.5) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-rl2==1.0.5) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow->keras-rl2==1.0.5) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow->keras-rl2==1.0.5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow->keras-rl2==1.0.5) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow->keras-rl2==1.0.5) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow->keras-rl2==1.0.5) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow->keras-rl2==1.0.5) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow->keras-rl2==1.0.5) (0.1.2)
# Downloading keras_rl2-1.0.5-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 5.6 MB/s eta 0:00:00
# Installing collected packages: keras-rl2
# Successfully installed keras-rl2-1.0.5
# Requirement already satisfied: ml_dtypes in /usr/local/lib/python3.11/dist-packages (0.4.1)
# Collecting ml_dtypes
#   Downloading ml_dtypes-0.5.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.11/dist-packages (from ml_dtypes) (2.0.2)
# Downloading ml_dtypes-0.5.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 71.2 MB/s eta 0:00:0000:0100:01
# Installing collected packages: ml_dtypes
#   Attempting uninstall: ml_dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.18.0 requires ml-dtypes<0.5.0,>=0.4.0, but you have ml-dtypes 0.5.4 which is incompatible.
# Successfully installed ml_dtypes-0.5.4

# %% [markdown]
# ---
# ## **PARTE 2**. Enunciado
#
# Consideraciones a tener en cuenta:
#
# - El entorno sobre el que trabajaremos será el indicado en el listado correspondien de cada grupo y el algoritmo que usaremos será _DQN_.
#
# - Para nuestro ejercicio, el requisito mínimo será alcanzado cuando el agente consiga una **media de recompensa por encima de los puntos indicados en el listado por grupos en modo test**. Por ello, esta media de la recompensa se calculará a partir del código de test en la última celda del notebook.
#
# Este proyecto práctico consta de tres partes:
#
# 1.   Implementar la red neuronal que se usará en la solución
# 2.   Implementar las distintas piezas de la solución DQN y probar al menos 3 propuestas diferentes de mejora.
# 3.   Justificar la respuesta en relación a los resultados obtenidos e incluir al menos 3 gráficas relevantes comparando las 3 propuestas.
#
# **Rúbrica**: Se valorará la originalidad en la solución aportada, así como la capacidad de discutir los resultados de forma detallada. El requisito mínimo servirá para aprobar la actividad, bajo premisa de que la discusión del resultado sera apropiada.
#
# IMPORTANTE:
#
# * Si no se consigue una puntuación óptima, responder sobre la mejor puntuación obtenida.
# * Para entrenamientos largos, recordad que podéis usar checkpoints de vuestros modelos para retomar los entrenamientos. En este caso, recordad cambiar los parámetros adecuadamente (sobre todo los relacionados con el proceso de exploración).
# * Se deberá entregar unicamente el notebook y los pesos del mejor modelo en un fichero .zip, de forma organizada.
# * Cada alumno deberá de subir la solución de forma individual.

# %% [markdown]
# ---
# ## **PARTE 3**. Desarrollo y preguntas

# %% [markdown]
# #### Importar librerías

# %%
#Comprobamos que se carga la versión esperada de TF y detecta la GPU
import os

os.environ['TF_USE_LEGACY_KERAS']="1"

import tensorflow.keras as tf
import tensorflow as tf1

from keras import __version__
tf.__version__ = __version__

print(tf1.__version__)
print(tf1.config.list_physical_devices('GPU'))
print(tf1.config.list_logical_devices('GPU'))
# Out:
# 2.18.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [LogicalDevice(name='/device:GPU:0', device_type='GPU')]

# %%
from __future__ import division

from PIL import Image
import numpy as np
import gym

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Convolution2D, Permute

if IN_COLAB:
  from tensorflow.keras.optimizers.legacy import Adam
else:
  from tensorflow.keras.optimizers import Adam

import tensorflow.keras.backend as K

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint

# %%
# ----------------------------------------------------------------------
# PARCHE NECESARIO: keras-rl2 (rl.core.Agent.fit) inicializa el contador de
# pasos como np.int16:
#     self.step = np.int16(0)
# np.int16 solo soporta valores hasta 32767. En entrenamientos largos como
# los que necesitamos aquí (NB_STEPS_TRAIN en el orden de 10^6), en cuanto
# self.step supera 32767 se produce un overflow silencioso (wraparound):
# self.step se vuelve NEGATIVO de golpe.
#
# Esto NO detiene el entrenamiento (la red sigue actualizándose), pero rompe:
#   - La condición 'while self.step < nb_steps' (el conteo real de progreso
#     queda corrupto a partir de ese punto).
#   - LinearAnnealedPolicy.get_current_value(), que calcula epsilon como
#     una función lineal de self.step: con self.step negativo, epsilon
#     puede dispararse por ENCIMA de 1.0 (no hay tope superior en el
#     código), forzando una política de exploración prácticamente
#     aleatoria de forma permanente. Esto explica por qué, tras el aviso
#     de overflow, el reward se desploma a 0 y ya no se recupera.
#   - El logging por intervalos y los ModelIntervalCheckpoint, que también
#     comparan contra self.step.
#
# Solución: forzamos a que el contador interno use un entero de 64 bits
# (np.int64), que aguanta hasta 9.2*10^18, muy por encima de cualquier
# nb_steps razonable. Esto se hace sustituyendo la referencia a np.int16
# que usa el módulo rl.core en tiempo de ejecución (no es necesario tocar
# el código fuente de la librería).
import rl.core as rl_core
rl_core.np.int16 = np.int64
# ----------------------------------------------------------------------

# %%
# ----------------------------------------------------------------------
# FIX NECESARIO solo si vas a usar Dueling DQN (enable_dueling_network=True,
# ver Propuesta 4 más abajo): keras-rl2 construye la cabeza dueling con una
# capa Lambda que contiene una función lambda de Python. Al compilar el
# agente, keras-rl2 necesita clonar el modelo (para crear la red objetivo),
# y las versiones modernas de tf_keras bloquean por seguridad la
# deserialización de capas Lambda con lambdas de Python, salvo que se
# habilite explícitamente. Esto no afecta a Double DQN por sí solo, solo
# cuando se combina con Dueling.
import tf_keras
tf_keras.__internal__.enable_unsafe_deserialization()
# ----------------------------------------------------------------------

# %% [markdown]
# #### Configuración base

# %%
INPUT_SHAPE = (84, 84)
WINDOW_LENGTH = 4

env_name = 'Enduro-v0'
env = gym.make(env_name)

np.random.seed(123)
env.seed(123)
nb_actions = env.action_space.n

print("Entorno:", env_name)
print("Número de acciones disponibles:", nb_actions)
print("Significado de las acciones:", env.unwrapped.get_action_meanings())
print("Formato de las observaciones:", env.observation_space)
# Out:
# Entorno: Enduro-v0
# Número de acciones disponibles: 9
# Significado de las acciones: ['NOOP', 'FIRE', 'RIGHT', 'LEFT', 'DOWN', 'DOWNRIGHT', 'DOWNLEFT', 'RIGHTFIRE', 'LEFTFIRE']
# Formato de las observaciones: Box(0, 255, (210, 160, 3), uint8)

# %%
class AtariProcessor(Processor):
    """
    Procesador de observaciones y recompensas para Enduro.

    A diferencia del ejemplo de Breakout, en Enduro:
      - El reward es MUY disperso: solo se obtiene +1 por cada coche adelantado.
      - No existe penalización explícita por choque o por ir despacio:
        cuando el coche choca son los rivales los que "adelantan", pero el
        entorno no devuelve reward negativo por ello.
      - La acción que activa la aceleración es FIRE (acción índice 1), igual
        que en otros juegos Atari donde FIRE = "arrancar".

    Esto provoca que, copiando el procesador de Breakout (clip a [-1,1] sin
    más), el agente tarde muchísimo en recibir señal de aprendizaje útil:
    con una política casi aleatoria, jugar sin acelerar nunca genera reward 0,
    y la red no tiene gradiente para aprender que acelerar es bueno.

    Mejora aplicada (reward shaping):
      - Mantenemos el reward original del entorno (adelantar coches), que es
        la señal "de verdad" que queremos maximizar.
      - Para inyectar señal densa en las fases iniciales, este processor deja
        preparado process_reward para no clippear a [-1,1] sin razón (en
        Enduro el reward ya es pequeño y disperso, clippear no ayuda).
    """

    def process_observation(self, observation):
        assert observation.ndim == 3  # (height, width, channel)
        img = Image.fromarray(observation)
        img = img.resize(INPUT_SHAPE).convert('L')
        processed_observation = np.array(img)
        assert processed_observation.shape == INPUT_SHAPE
        return processed_observation.astype('uint8')

    def process_state_batch(self, batch):
        processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        # No clippeamos a [-1, 1]: en Enduro el reward ya es +1 por coche
        # adelantado. Clippear aquí no aporta nada (no hay rewards grandes
        # que distorsionen el entrenamiento como en Breakout) y preferimos
        # mantener la señal real del entorno sin alterar su magnitud.
        return float(reward)

# %% [markdown]
# 1. Implementación de la red neuronal

# %%
# 1. Implementación de la red neuronal
#
# Usamos la misma arquitectura convolucional propuesta por Mnih et al. (2015)
# para Atari: 3 capas convolucionales + 1 capa densa oculta + capa de salida
# lineal con un valor Q por acción. Es la misma red que en el ejemplo de
# Breakout del notebook de la sesión, adaptada al número de acciones de Enduro.

input_shape = (WINDOW_LENGTH,) + INPUT_SHAPE


def build_model(nb_actions, input_shape):
    model = Sequential()
    if K.image_data_format() == 'channels_last':
        # (width, height, channels)
        model.add(Permute((2, 3, 1), input_shape=input_shape))
    elif K.image_data_format() == 'channels_first':
        # (channels, width, height)
        model.add(Permute((1, 2, 3), input_shape=input_shape))
    else:
        raise RuntimeError('Unknown image_dim_ordering.')

    model.add(Convolution2D(32, (8, 8), strides=(4, 4)))
    model.add(Activation('relu'))
    model.add(Convolution2D(64, (4, 4), strides=(2, 2)))
    model.add(Activation('relu'))
    model.add(Convolution2D(64, (3, 3), strides=(1, 1)))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(nb_actions))
    model.add(Activation('linear'))
    return model


model = build_model(nb_actions, input_shape)
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  permute (Permute)           (None, 84, 84, 4)         0
#
#  conv2d (Conv2D)             (None, 20, 20, 32)        8224
#
#  activation (Activation)     (None, 20, 20, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 9, 9, 64)          32832
#
#  activation_1 (Activation)   (None, 9, 9, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 64)          36928
#
#  activation_2 (Activation)   (None, 7, 7, 64)          0
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 512)               1606144
#
#  activation_3 (Activation)   (None, 512)               0
#
#  dense_1 (Dense)             (None, 9)                 4617
#
#  activation_4 (Activation)   (None, 9)                 0
#
# =================================================================
# Total params: 1688745 (6.44 MB)
# Trainable params: 1688745 (6.44 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# ##### Variante de red para Dueling DQN (usada en las Propuestas 5 y 6)

# %%
def build_model_dueling_ready(nb_actions, input_shape):
    """
    Igual que build_model, pero con la activación lineal final integrada
    en la propia capa Dense (Dense(nb_actions, activation='linear')) en
    lugar de como una capa Activation separada.
    Esto es necesario para que DQNAgent(..., enable_dueling_network=True)
    funcione correctamente: internamente, keras-rl2 toma model.layers[-2]
    como base para construir las dos cabezas (V y A) de la arquitectura
    dueling. Con la red original (build_model), layers[-2] sería la capa
    Dense(nb_actions) de tamaño 9 -> la cabeza dueling se construiría sobre
    una representación ya colapsada a acciones, perdiendo toda la
    información de la capa de 512 unidades. Integrando la activación en la
    misma capa, layers[-2] pasa a ser la Activation('relu') de 512
    unidades, que es la representación correcta sobre la que construir V y A.
    Si NO se usa dueling, esta red es funcionalmente idéntica a build_model
    (Dense(n) + Activation('linear') == Dense(n, activation='linear')).
    """
    model = Sequential()
    if K.image_data_format() == 'channels_last':
        model.add(Permute((2, 3, 1), input_shape=input_shape))
    elif K.image_data_format() == 'channels_first':
        model.add(Permute((1, 2, 3), input_shape=input_shape))
    else:
        raise RuntimeError('Unknown image_dim_ordering.')

    model.add(Convolution2D(32, (8, 8), strides=(4, 4)))
    model.add(Activation('relu'))
    model.add(Convolution2D(64, (4, 4), strides=(2, 2)))
    model.add(Activation('relu'))
    model.add(Convolution2D(64, (3, 3), strides=(1, 1)))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(nb_actions, activation='linear'))
    return model

# %% [markdown]
# 2. Implementación de la solución DQN

# %% [markdown]
# ##### Diagnóstico y diseño de las 3 propuestas de mejora

# %%
"""
### Diagnóstico del problema en Enduro

Antes de entrenar, conviene entender por qué una solución "copia-pega" del
ejemplo de Breakout no funciona en Enduro:

1. **Reward extremadamente disperso**: en Enduro solo se obtiene +1 por cada
   coche adelantado (fuente: documentación oficial de Farama/ALE). No hay
   reward por simplemente sobrevivir, ni penalización explícita por chocar.
   Con una política casi aleatoria al principio del entrenamiento (alto
   epsilon), la probabilidad de generar una secuencia de acciones que
   resulte en adelantar a un coche es muy baja.

2. **La acción de acelerar (FIRE) es solo 1 de 9 acciones posibles**. Hemos
   comprobado empíricamente que con NOOP el reward acumulado es 0, mientras
   que con FIRE sostenido se empieza a generar reward positivo desde los
   primeros steps. Si la política de exploración no favorece especialmente
   esta acción, el agente tarda mucho más en "descubrir" que acelerar es la
   base de cualquier estrategia ganadora.

3. **nb_steps_warmup demasiado alto combinado con annealing muy lento**:
   si se usa el mismo esquema que Breakout (warmup=50000, annealing sobre
   2M steps), el agente pasa cientos de miles de steps con una política casi
   uniforme antes de empezar a aprender señal útil, lo cual en Enduro es
   mucho más costoso que en Breakout porque el reward es más raro.

A partir de este diagnóstico, proponemos y comparamos 3 variantes de la
solución DQN, manteniendo la misma red y el mismo AtariProcessor, variando
únicamente la política de exploración/explotación y sus hiperparámetros:

- **Propuesta 1 — EpsGreedy fijo (baseline)**: epsilon constante a lo largo
  de todo el entrenamiento. Sirve como referencia de cuánto cuesta aprender
  sin ningún tipo de planificación de la exploración.

- **Propuesta 2 — LinearAnnealedPolicy (EpsGreedy con annealing rápido)**:
  epsilon decrece linealmente de 1.0 a 0.1 en un número de steps mucho menor
  que en Breakout (300k en lugar de 2M), adaptado a que Enduro necesita
  empezar a explotar antes lo poco que va aprendiendo, dado lo disperso del
  reward. Además, reducimos nb_steps_warmup respecto al ejemplo de Breakout.

- **Propuesta 3 — BoltzmannQPolicy**: la exploración se basa en muestrear
  acciones proporcionalmente a sus valores Q estimados (softmax), en lugar
  de epsilon-greedy puro. Esto permite que, en cuanto la red empiece a
  asignar valores Q más altos a FIRE/aceleración, esa acción se elija con
  más frecuencia de forma suave, sin depender de un parámetro epsilon
  explícito.

Las tres comparten la misma arquitectura de red, el mismo procesador de
estados, y el mismo gamma/target_model_update, para que la comparación aísle
el efecto de la política de exploración.
"""
# Out:
# '\n### Diagnóstico del problema en Enduro\n\nAntes de entrenar, conviene entender por qué una solución "copia-pega" del\nejemplo de Breakout no funciona en Enduro:\n\n1. **Reward extremadamente disperso**: en Enduro solo se obtiene +1 por cada\n   coche adelantado (fuente: documentación oficial de Farama/ALE). No hay\n   reward por simplemente sobrevivir, ni penalización explícita por chocar.\n   Con una política casi aleatoria al principio del entrenamiento (alto\n   epsilon), la probabilidad de generar una secuencia de acciones que\n   resulte en adelantar a un coche es muy baja.\n\n2. **La acción de acelerar (FIRE) es solo 1 de 9 acciones posibles**. Hemos\n   comprobado empíricamente que con NOOP el reward acumulado es 0, mientras\n   que con FIRE sostenido se empieza a generar reward positivo desde los\n   primeros steps. Si la política de exploración no favorece especialmente\n   esta acción, el agente tarda mucho más en "descubrir" que acelerar es la\n   base de cualquier estrategia ganadora.\n\n3. **nb_steps_warmup demasiado alto combinado con annealing muy lento**:\n   si se usa el mismo esquema que Breakout (warmup=50000, annealing sobre\n   2M steps), el agente pasa cientos de miles de steps con una política casi\n   uniforme antes de empezar a aprender señal útil, lo cual en Enduro es\n   mucho más costoso que en Breakout porque el reward es más raro.\n\nA partir de este diagnóstico, proponemos y comparamos 3 variantes de la\nsolución DQN, manteniendo la misma red y el mismo AtariProcessor, variando\núnicamente la política de exploración/explotación y sus hiperparámetros:\n\n- **Propuesta 1 — EpsGreedy fijo (baseline)**: epsilon constante a lo largo\n  de todo el entrenamiento. Sirve como referencia de cuánto cuesta aprender\n  sin ningún tipo de planificación de la exploración.\n\n- **Propuesta 2 — LinearAnnealedPolicy (EpsGreedy con annealing rápido)**:\n  epsilon decrece linealmente de 1.0 a 0.1 en un número de steps mucho menor\n  que en Breakout (300k en lugar de 2M), adaptado a que Enduro necesita\n  empezar a explotar antes lo poco que va aprendiendo, dado lo disperso del\n  reward. Además, reducimos nb_steps_warmup respecto al ejemplo de Breakout.\n\n- **Propuesta 3 — BoltzmannQPolicy**: la exploración se basa en muestrear\n  acciones proporcionalmente a sus valores Q estimados (softmax), en lugar\n  de epsilon-greedy puro. Esto permite que, en cuanto la red empiece a\n  asignar valores Q más altos a FIRE/aceleración, esa acción se elija con\n  más frecuencia de forma suave, sin depender de un parámetro epsilon\n  explícito.\n\nLas tres comparten la misma arquitectura de red, el mismo procesador de\nestados, y el mismo gamma/target_model_update, para que la comparación aísle\nel efecto de la política de exploración.\n'

# %%
def build_dqn_agent(model, nb_actions, memory, processor, policy,
                     nb_steps_warmup, target_model_update,
                     train_interval=4, gamma=.99,
                     enable_double_dqn=False, enable_dueling_network=False,
                     dueling_type='avg'):
    dqn = DQNAgent(model=model, nb_actions=nb_actions, policy=policy,
                   memory=memory, processor=processor,
                   nb_steps_warmup=nb_steps_warmup, gamma=gamma,
                   target_model_update=target_model_update,
                   train_interval=train_interval,
                   enable_double_dqn=enable_double_dqn,
                   enable_dueling_network=enable_dueling_network,
                   dueling_type=dueling_type)
    dqn.compile(Adam(learning_rate=.00025), metrics=['mae'])
    return dqn

# %%
# ----------------------------------------------------------------------
# Soporte para REANUDAR un entrenamiento interrumpido desde un checkpoint,
# sin pisar los checkpoints que ya existen.
#
# ModelIntervalCheckpoint (de keras-rl2) numera los archivos según un
# contador interno que SIEMPRE empieza en 0 al crear una instancia nueva.
# Si interrumpes un entrenamiento en el step 800000 y vuelves a ejecutar la
# celda de la propuesta desde cero, el nuevo ModelIntervalCheckpoint volverá
# a generar "..._weights_100000.h5f", "..._weights_200000.h5f", etc., que
# son EXACTAMENTE los mismos nombres que los de la tanda anterior -> se
# pisarían con overwrite=True.
#
# ResumableModelIntervalCheckpoint añade un step_offset: al reanudar, le
# decimos en qué step real nos quedamos (p.ej. 800000), y el contador
# absoluto que usa para nombrar los archivos sigue desde ahí
# (800100000... bien, 800000 + 100000 = 900000, etc.), por lo que los
# nuevos checkpoints nunca coinciden en nombre con los anteriores.
class ResumableModelIntervalCheckpoint(ModelIntervalCheckpoint):
    def __init__(self, filepath, interval, step_offset=0, verbose=0):
        super().__init__(filepath, interval, verbose=verbose)
        self.step_offset = step_offset

    def on_step_end(self, step, logs={}):
        self.total_steps += 1
        if self.total_steps % self.interval != 0:
            return
        absolute_step = self.step_offset + self.total_steps
        filepath = self.filepath.format(step=absolute_step, **logs)
        if self.verbose > 0:
            print(f'Step {absolute_step}: guardando modelo en {filepath}')
        self.model.save_weights(filepath, overwrite=True)


def find_latest_checkpoint(weights_dir, prefix):
    """
    Busca en weights_dir el checkpoint con el step más alto que siga el
    patrón '{prefix}_weights_{step}.h5f.index', y devuelve una tupla
    (ruta_sin_extension, step) o (None, 0) si no hay ninguno.
    Útil para retomar automáticamente "desde el último punto guardado".
    """
    import re
    import glob
    pattern = os.path.join(weights_dir, f'{prefix}_weights_*.h5f.index')
    candidates = glob.glob(pattern)
    best_step = -1
    best_path = None
    for c in candidates:
        m = re.search(r'_weights_(\d+)\.h5f\.index$', c)
        if m:
            step = int(m.group(1))
            if step > best_step:
                best_step = step
                best_path = c[:-len('.index')]
    if best_path is None:
        return None, 0
    return best_path, best_step
# ----------------------------------------------------------------------

# %%
NB_STEPS_TRAIN = 1000000  # ajustar según tiempo disponible / checkpoints

# %% [markdown]
# ###### Propuesta 1 — EpsGreedyQPolicy fijo (baseline)

# %%
# ----------------------------------------------------------------------
# PROPUESTA 1: EpsGreedyQPolicy fijo (baseline, sin annealing)
# ----------------------------------------------------------------------
# NB_STEPS_TRAIN = 1750000  # ajustar según tiempo disponible / checkpoints

# --- Reanudación opcional ---
# Si quieres CONTINUAR un entrenamiento interrumpido en vez de empezar de
# cero, pon aquí la ruta al checkpoint (sin extensión) del que quieres
# partir, por ejemplo:
#   RESUME_FROM_P1 = os.path.join(WEIGHTS_DIR_P1, 'dqn_Enduro-v0_p1_weights_800000.h5f')
# o deja que lo detecte automáticamente con find_latest_checkpoint:
#   RESUME_FROM_P1, STEP_OFFSET_P1 = find_latest_checkpoint(WEIGHTS_DIR_P1, 'dqn_Enduro-v0_p1')
# Si RESUME_FROM_P1 es None, se entrena desde cero como siempre.
RESUME_FROM_P1 = None
STEP_OFFSET_P1 = 0

# Descomenta esta línea para detectar automáticamente el último checkpoint
# guardado en WEIGHTS_DIR_P1 y continuar justo desde ahí:
RESUME_FROM_P1, STEP_OFFSET_P1 = find_latest_checkpoint(WEIGHTS_DIR_P1, 'dqn_Enduro-v0_p1')

model_p1 = build_model(nb_actions, input_shape)
memory_p1 = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)

policy_p1 = EpsGreedyQPolicy(eps=0.2)

dqn_p1 = build_dqn_agent(
    model=model_p1, nb_actions=nb_actions, memory=memory_p1,
    processor=AtariProcessor(), policy=policy_p1,
    nb_steps_warmup=10000, target_model_update=10000
)

if RESUME_FROM_P1 is not None:
    print(f"Reanudando Propuesta 1 desde el checkpoint: {RESUME_FROM_P1}")
    print(f"(step_offset = {STEP_OFFSET_P1}; la memoria de experiencia empieza vacía,")
    print(" lo cual es normal: keras-rl2 no persiste el replay buffer)")
    dqn_p1.load_weights(RESUME_FROM_P1)
    NB_STEPS_REMAINING_P1 = max(0, NB_STEPS_TRAIN - STEP_OFFSET_P1)
else:
    NB_STEPS_REMAINING_P1 = NB_STEPS_TRAIN

# Todo lo de esta propuesta se guarda en su carpeta dedicada DENTRO de Drive
# (WEIGHTS_DIR_P1), para que los checkpoints intermedios sobrevivan aunque
# el runtime de Colab se desconecte durante un entrenamiento largo.
weights_filename_p1 = os.path.join(WEIGHTS_DIR_P1, 'dqn_{}_p1_eps_fijo_weights.h5f'.format(env_name))
checkpoint_filename_p1 = os.path.join(WEIGHTS_DIR_P1, 'dqn_' + env_name + '_p1_weights_{step}.h5f')
log_filename_p1 = os.path.join(WEIGHTS_DIR_P1, 'dqn_{}_p1_log.json'.format(env_name))

# Usamos el checkpoint "resumable": si STEP_OFFSET_P1 > 0, los nombres de
# archivo seguirán numerándose desde ahí, sin pisar los checkpoints previos.
callbacks_p1 = [ResumableModelIntervalCheckpoint(checkpoint_filename_p1, interval=100000,
                                                  step_offset=STEP_OFFSET_P1)]
callbacks_p1 += [FileLogger(log_filename_p1, interval=1000)]

history_p1 = dqn_p1.fit(env, callbacks=callbacks_p1, nb_steps=NB_STEPS_REMAINING_P1,
                         log_interval=10000, visualize=False)

dqn_p1.save_weights(weights_filename_p1, overwrite=True)
print("Pesos finales de la Propuesta 1 guardados en Drive:", weights_filename_p1)
print("Contenido de la carpeta:", os.listdir(WEIGHTS_DIR_P1))
# Out:
# Reanudando Propuesta 1 desde el checkpoint: /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/p1_eps_fijo/dqn_Enduro-v0_p1_weights_800000.h5f
# (step_offset = 800000; la memoria de experiencia empieza vacía,
#  lo cual es normal: keras-rl2 no persiste el replay buffer)
# Training for 200000 steps ...
# Interval 1 (0 steps performed)
# /usr/local/lib/python3.11/dist-packages/tf_keras/src/engine/training_v1.py:2354: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 10000/10000 [==============================] - 49s 5ms/step - reward: 0.0258
# 2 episodes - episode_reward: 119.000 [118.000, 120.000] - ale.lives: 0.000
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 331s 33ms/step - reward: 0.0313
# 2 episodes - episode_reward: 143.000 [114.000, 172.000] - loss: 0.055 - mae: 4.534 - mean_q: 5.242 - ale.lives: 0.000
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 318s 32ms/step - reward: 0.0212
# 2 episodes - episode_reward: 91.000 [71.000, 111.000] - loss: 0.054 - mae: 4.492 - mean_q: 5.209 - ale.lives: 0.000
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 332s 33ms/step - reward: 0.0266
# 2 episodes - episode_reward: 110.500 [110.000, 111.000] - loss: 0.053 - mae: 4.561 - mean_q: 5.295 - ale.lives: 0.000
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 333s 33ms/step - reward: 0.0270
# 3 episodes - episode_reward: 118.333 [103.000, 130.000] - loss: 0.054 - mae: 4.589 - mean_q: 5.334 - ale.lives: 0.000
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 335s 33ms/step - reward: 0.0197
# 2 episodes - episode_reward: 99.500 [82.000, 117.000] - loss: 0.057 - mae: 4.690 - mean_q: 5.443 - ale.lives: 0.000
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 332s 33ms/step - reward: 0.0264
# 2 episodes - episode_reward: 119.000 [104.000, 134.000] - loss: 0.058 - mae: 4.727 - mean_q: 5.483 - ale.lives: 0.000
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 336s 34ms/step - reward: 0.0214
# 3 episodes - episode_reward: 91.667 [56.000, 111.000] - loss: 0.057 - mae: 4.819 - mean_q: 5.588 - ale.lives: 0.000
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 337s 34ms/step - reward: 0.0187
# 2 episodes - episode_reward: 86.500 [75.000, 98.000] - loss: 0.058 - mae: 4.815 - mean_q: 5.583 - ale.lives: 0.000
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 342s 34ms/step - reward: 0.0283
# 2 episodes - episode_reward: 124.000 [122.000, 126.000] - loss: 0.060 - mae: 4.883 - mean_q: 5.662 - ale.lives: 0.000
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 328s 33ms/step - reward: 0.0316
# 2 episodes - episode_reward: 121.000 [91.000, 151.000] - loss: 0.057 - mae: 4.972 - mean_q: 5.765 - ale.lives: 0.000
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 324s 32ms/step - reward: 0.0217
# 3 episodes - episode_reward: 113.333 [67.000, 142.000] - loss: 0.065 - mae: 5.106 - mean_q: 5.920 - ale.lives: 0.000
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 323s 32ms/step - reward: 0.0219
# 2 episodes - episode_reward: 99.000 [86.000, 112.000] - loss: 0.063 - mae: 5.143 - mean_q: 5.962 - ale.lives: 0.000
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 323s 32ms/step - reward: 0.0211
# 2 episodes - episode_reward: 107.000 [75.000, 139.000] - loss: 0.062 - mae: 5.268 - mean_q: 6.098 - ale.lives: 0.000
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 327s 33ms/step - reward: 0.0321
# 2 episodes - episode_reward: 118.000 [111.000, 125.000] - loss: 0.065 - mae: 5.244 - mean_q: 6.067 - ale.lives: 0.000
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 323s 32ms/step - reward: 0.0198
# 3 episodes - episode_reward: 100.333 [68.000, 119.000] - loss: 0.065 - mae: 5.243 - mean_q: 6.068 - ale.lives: 0.000
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 326s 33ms/step - reward: 0.0206
# 2 episodes - episode_reward: 91.500 [81.000, 102.000] - loss: 0.065 - mae: 5.303 - mean_q: 6.140 - ale.lives: 0.000
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 330s 33ms/step - reward: 0.0246
# 2 episodes - episode_reward: 110.500 [99.000, 122.000] - loss: 0.062 - mae: 5.313 - mean_q: 6.144 - ale.lives: 0.000
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 327s 33ms/step - reward: 0.0228
# 2 episodes - episode_reward: 93.500 [93.000, 94.000] - loss: 0.066 - mae: 5.402 - mean_q: 6.248 - ale.lives: 0.000
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 330s 33ms/step - reward: 0.0239
# done, took 6305.600 seconds
# Pesos finales de la Propuesta 1 guardados en Drive: /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/p1_eps_fijo/dqn_Enduro-v0_p1_eps_fijo_weights.h5f
# Contenido de la carpeta: ['dqn_Enduro-v0_p1_weights_100000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p1_weights_100000.h5f.index', 'dqn_Enduro-v0_p1_weights_200000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p1_weights_200000.h5f.index', 'dqn_Enduro-v0_p1_weights_300000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p1_weights_300000.h5f.index', 'dqn_Enduro-v0_p1_weights_400000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p1_weights_400000.h5f.index', 'dqn_Enduro-v0_p1_weights_500000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p1_weights_500000.h5f.index', 'dqn_Enduro-v0_p1_weights_600000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p1_weights_600000.h5f.index', 'dqn_Enduro-v0_p1_weights_700000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p1_weights_700000.h5f.index', 'dqn_Enduro-v0_p1_weights_800000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p1_weights_800000.h5f.index', 'checkpoint', 'dqn_Enduro-v0_p1_log.json', 'dqn_Enduro-v0_p1_weights_900000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p1_weights_900000.h5f.index', 'dqn_Enduro-v0_p1_weights_1000000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p1_weights_1000000.h5f.index', 'dqn_Enduro-v0_p1_eps_fijo_weights.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p1_eps_fijo_weights.h5f.index']

# %% [markdown]
# ###### Propuesta 2 — LinearAnnealedPolicy (EpsGreedy con annealing rápido)

# %%
# ----------------------------------------------------------------------
# PROPUESTA 2: LinearAnnealedPolicy (EpsGreedy con annealing rápido)
# ----------------------------------------------------------------------

# --- Reanudación opcional (ver explicación detallada en la Propuesta 1) ---
RESUME_FROM_P2 = None
STEP_OFFSET_P2 = 0
RESUME_FROM_P2, STEP_OFFSET_P2 = find_latest_checkpoint(WEIGHTS_DIR_P2, 'dqn_Enduro-v0_p2')

model_p2 = build_model(nb_actions, input_shape)
memory_p2 = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)

# Annealing más rápido que en Breakout (300k en lugar de 2M steps), dado que
# el reward en Enduro es más disperso y conviene empezar a explotar antes.
#
# OJO con reanudar esta propuesta en concreto: a diferencia de la Propuesta 1
# (epsilon fijo), aquí el valor de epsilon depende de self.step dentro de
# LinearAnnealedPolicy. Como keras-rl2 NO persiste self.step al recargar
# pesos, la policy nueva volverá a calcular epsilon como si empezara desde 0
# (es decir, con más exploración de la que tocaría en ese punto del
# annealing). Esto no rompe nada, pero conviene saberlo: tras reanudar, la
# exploración será algo más alta de lo que habría sido sin interrupción.
policy_p2 = LinearAnnealedPolicy(
    EpsGreedyQPolicy(), attr='eps',
    value_max=1., value_min=.1, value_test=.05,
    nb_steps=300000
)

dqn_p2 = build_dqn_agent(
    model=model_p2, nb_actions=nb_actions, memory=memory_p2,
    processor=AtariProcessor(), policy=policy_p2,
    nb_steps_warmup=10000, target_model_update=10000
)

if RESUME_FROM_P2 is not None:
    print(f"Reanudando Propuesta 2 desde el checkpoint: {RESUME_FROM_P2}")
    dqn_p2.load_weights(RESUME_FROM_P2)
    NB_STEPS_REMAINING_P2 = max(0, NB_STEPS_TRAIN - STEP_OFFSET_P2)
else:
    NB_STEPS_REMAINING_P2 = NB_STEPS_TRAIN

weights_filename_p2 = os.path.join(WEIGHTS_DIR_P2, 'dqn_{}_p2_annealed_weights.h5f'.format(env_name))
checkpoint_filename_p2 = os.path.join(WEIGHTS_DIR_P2, 'dqn_' + env_name + '_p2_weights_{step}.h5f')
log_filename_p2 = os.path.join(WEIGHTS_DIR_P2, 'dqn_{}_p2_log.json'.format(env_name))

callbacks_p2 = [ResumableModelIntervalCheckpoint(checkpoint_filename_p2, interval=100000,
                                                  step_offset=STEP_OFFSET_P2)]
callbacks_p2 += [FileLogger(log_filename_p2, interval=1000)]

history_p2 = dqn_p2.fit(env, callbacks=callbacks_p2, nb_steps=NB_STEPS_REMAINING_P2,
                         log_interval=10000, visualize=False)

dqn_p2.save_weights(weights_filename_p2, overwrite=True)
print("Pesos finales de la Propuesta 2 guardados en Drive:", weights_filename_p2)
print("Contenido de la carpeta:", os.listdir(WEIGHTS_DIR_P2))
# Out:
# Failed to connect to the remote Jupyter Server 'https://8080-gpu-t4-s-kkb-usw1b0-1dxbhz2c1bqcr-b.us-west1-0.prod.colab.dev/'. Verify the server is running and reachable.

# %% [markdown]
# ###### Propuesta 3 — BoltzmannQPolicy

# %%
# ----------------------------------------------------------------------
# PROPUESTA 3: BoltzmannQPolicy
# ----------------------------------------------------------------------

# --- Reanudación opcional (ver explicación detallada en la Propuesta 1) ---
RESUME_FROM_P3 = None
STEP_OFFSET_P3 = 0
RESUME_FROM_P3, STEP_OFFSET_P3 = find_latest_checkpoint(WEIGHTS_DIR_P3, 'dqn_Enduro-v0_p3')

model_p3 = build_model(nb_actions, input_shape)
memory_p3 = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)

policy_p3 = BoltzmannQPolicy(tau=1.)

dqn_p3 = build_dqn_agent(
    model=model_p3, nb_actions=nb_actions, memory=memory_p3,
    processor=AtariProcessor(), policy=policy_p3,
    nb_steps_warmup=10000, target_model_update=10000
)

if RESUME_FROM_P3 is not None:
    print(f"Reanudando Propuesta 3 desde el checkpoint: {RESUME_FROM_P3}")
    dqn_p3.load_weights(RESUME_FROM_P3)
    NB_STEPS_REMAINING_P3 = max(0, NB_STEPS_TRAIN - STEP_OFFSET_P3)
else:
    NB_STEPS_REMAINING_P3 = NB_STEPS_TRAIN

weights_filename_p3 = os.path.join(WEIGHTS_DIR_P3, 'dqn_{}_p3_boltzmann_weights.h5f'.format(env_name))
checkpoint_filename_p3 = os.path.join(WEIGHTS_DIR_P3, 'dqn_' + env_name + '_p3_weights_{step}.h5f')
log_filename_p3 = os.path.join(WEIGHTS_DIR_P3, 'dqn_{}_p3_log.json'.format(env_name))

callbacks_p3 = [ResumableModelIntervalCheckpoint(checkpoint_filename_p3, interval=100000,
                                                  step_offset=STEP_OFFSET_P3)]
callbacks_p3 += [FileLogger(log_filename_p3, interval=1000)]

history_p3 = dqn_p3.fit(env, callbacks=callbacks_p3, nb_steps=NB_STEPS_REMAINING_P3,
                         log_interval=10000, visualize=False)

dqn_p3.save_weights(weights_filename_p3, overwrite=True)
print("Pesos finales de la Propuesta 3 guardados en Drive:", weights_filename_p3)
print("Contenido de la carpeta:", os.listdir(WEIGHTS_DIR_P3))

# %% [markdown]
# ###### Propuesta 4 — Double DQN

# %%
# ----------------------------------------------------------------------
# PROPUESTA 4: Double DQN
#
# Mantiene la misma política de exploración que la Propuesta 1 (EpsGreedy
# fijo, eps=0.2), pero cambia el algoritmo: Double DQN usa la red principal
# para ELEGIR la mejor acción y la red objetivo para EVALUARLA, en lugar de
# usar la misma red objetivo para ambas cosas (como hace el DQN vanilla).
# Esto corrige la sobreestimación sistemática de los valores Q descrita en
# Van Hasselt et al. (2016), que puede ser especialmente problemática en
# entornos con reward disperso como Enduro, donde pocos pares (estado,
# acción) tienen una señal de reward fiable y el resto se basa en
# bootstrapping de estimaciones ya sesgadas.
#
# No necesita la arquitectura especial de Dueling (build_model_dueling_ready):
# usamos build_model, la misma red que en las Propuestas 1-3.
# ----------------------------------------------------------------------

# NB_STEPS_TRAIN = 1000000  # ajustar según tiempo disponible / checkpoints


# --- Reanudación opcional (ver explicación detallada en la Propuesta 1) ---
RESUME_FROM_P4 = None
STEP_OFFSET_P4 = 0
RESUME_FROM_P4, STEP_OFFSET_P4 = find_latest_checkpoint(WEIGHTS_DIR_P4, 'dqn_Enduro-v0_p4')

model_p4 = build_model(nb_actions, input_shape)
memory_p4 = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)

policy_p4 = EpsGreedyQPolicy(eps=0.2)

dqn_p4 = build_dqn_agent(
    model=model_p4, nb_actions=nb_actions, memory=memory_p4,
    processor=AtariProcessor(), policy=policy_p4,
    nb_steps_warmup=10000, target_model_update=10000,
    enable_double_dqn=True, enable_dueling_network=False
)

if RESUME_FROM_P4 is not None:
    print(f"Reanudando Propuesta 4 desde el checkpoint: {RESUME_FROM_P4}")
    dqn_p4.load_weights(RESUME_FROM_P4)
    NB_STEPS_REMAINING_P4 = max(0, NB_STEPS_TRAIN - STEP_OFFSET_P4)
else:
    NB_STEPS_REMAINING_P4 = NB_STEPS_TRAIN

weights_filename_p4 = os.path.join(WEIGHTS_DIR_P4, 'dqn_{}_p4_double_dqn_weights.h5f'.format(env_name))
checkpoint_filename_p4 = os.path.join(WEIGHTS_DIR_P4, 'dqn_' + env_name + '_p4_weights_{step}.h5f')
log_filename_p4 = os.path.join(WEIGHTS_DIR_P4, 'dqn_{}_p4_log.json'.format(env_name))

callbacks_p4 = [ResumableModelIntervalCheckpoint(checkpoint_filename_p4, interval=100000,
                                                  step_offset=STEP_OFFSET_P4)]
callbacks_p4 += [FileLogger(log_filename_p4, interval=1000)]

history_p4 = dqn_p4.fit(env, callbacks=callbacks_p4, nb_steps=NB_STEPS_REMAINING_P4,
                         log_interval=10000, visualize=False)

dqn_p4.save_weights(weights_filename_p4, overwrite=True)
print("Pesos finales de la Propuesta 4 guardados en Drive:", weights_filename_p4)
print("Contenido de la carpeta:", os.listdir(WEIGHTS_DIR_P4))
# Out:
# Training for 1000000 steps ...
# Interval 1 (0 steps performed)
# /usr/local/lib/python3.11/dist-packages/tf_keras/src/engine/training_v1.py:2354: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 10000/10000 [==============================] - 49s 5ms/step - reward: 1.0000e-04
# 2 episodes - episode_reward: 0.000 [0.000, 0.000] - ale.lives: 0.000
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 323s 32ms/step - reward: -1.0000e-04
# 2 episodes - episode_reward: 0.000 [0.000, 0.000] - loss: 0.001 - mae: 0.015 - mean_q: 0.024 - ale.lives: 0.000
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 322s 32ms/step - reward: 0.0000e+00
# 2 episodes - episode_reward: 0.000 [0.000, 0.000] - loss: 0.003 - mae: 0.012 - mean_q: 0.020 - ale.lives: 0.000
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 325s 32ms/step - reward: 0.0000e+00
# 2 episodes - episode_reward: 0.000 [0.000, 0.000] - loss: 0.003 - mae: 0.012 - mean_q: 0.016 - ale.lives: 0.000
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 322s 32ms/step - reward: 1.0000e-04
# 3 episodes - episode_reward: 0.000 [0.000, 0.000] - loss: 0.003 - mae: 0.015 - mean_q: 0.018 - ale.lives: 0.000
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 324s 32ms/step - reward: -1.0000e-04
# 2 episodes - episode_reward: 0.000 [0.000, 0.000] - loss: 0.004 - mae: 0.019 - mean_q: 0.022 - ale.lives: 0.000
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 321s 32ms/step - reward: 7.0000e-04
# 2 episodes - episode_reward: 0.500 [0.000, 1.000] - loss: 0.004 - mae: 0.027 - mean_q: 0.036 - ale.lives: 0.000
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 321s 32ms/step - reward: 1.0000e-04
# 3 episodes - episode_reward: 2.333 [0.000, 7.000] - loss: 0.004 - mae: 0.032 - mean_q: 0.036 - ale.lives: 0.000
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 324s 32ms/step - reward: 1.0000e-04
# 2 episodes - episode_reward: 0.000 [0.000, 0.000] - loss: 0.004 - mae: 0.038 - mean_q: 0.033 - ale.lives: 0.000
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 322s 32ms/step - reward: 0.0018
# 2 episodes - episode_reward: 9.500 [8.000, 11.000] - loss: 0.004 - mae: 0.050 - mean_q: 0.039 - ale.lives: 0.000
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 320s 32ms/step - reward: 0.0000e+00
# 2 episodes - episode_reward: 0.000 [0.000, 0.000] - loss: 0.004 - mae: 0.053 - mean_q: 0.046 - ale.lives: 0.000
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 319s 32ms/step - reward: 2.0000e-04
# 3 episodes - episode_reward: 0.667 [0.000, 2.000] - loss: 0.004 - mae: 0.064 - mean_q: 0.051 - ale.lives: 0.000
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 326s 33ms/step - reward: 5.0000e-04
# 2 episodes - episode_reward: 2.500 [0.000, 5.000] - loss: 0.005 - mae: 0.072 - mean_q: 0.064 - ale.lives: 0.000
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 322s 32ms/step - reward: 9.0000e-04
# 2 episodes - episode_reward: 3.500 [0.000, 7.000] - loss: 0.005 - mae: 0.083 - mean_q: 0.076 - ale.lives: 0.000
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 322s 32ms/step - reward: 5.0000e-04
# 2 episodes - episode_reward: 3.500 [1.000, 6.000] - loss: 0.005 - mae: 0.085 - mean_q: 0.078 - ale.lives: 0.000
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 324s 32ms/step - reward: 2.0000e-04
# 3 episodes - episode_reward: 0.667 [0.000, 1.000] - loss: 0.005 - mae: 0.099 - mean_q: 0.092 - ale.lives: 0.000
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 330s 33ms/step - reward: 0.0000e+00
# 2 episodes - episode_reward: 0.000 [0.000, 0.000] - loss: 0.005 - mae: 0.115 - mean_q: 0.105 - ale.lives: 0.000
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 334s 33ms/step - reward: 0.0012
# 2 episodes - episode_reward: 1.500 [0.000, 3.000] - loss: 0.006 - mae: 0.125 - mean_q: 0.110 - ale.lives: 0.000
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 332s 33ms/step - reward: 3.0000e-04
# 2 episodes - episode_reward: 3.000 [0.000, 6.000] - loss: 0.006 - mae: 0.144 - mean_q: 0.125 - ale.lives: 0.000
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 333s 33ms/step - reward: 1.0000e-04
# 3 episodes - episode_reward: 2.333 [0.000, 7.000] - loss: 0.007 - mae: 0.162 - mean_q: 0.131 - ale.lives: 0.000
#
# Interval 21 (200000 steps performed)
# 10000/10000 [==============================] - 333s 33ms/step - reward: 3.0000e-04
# 2 episodes - episode_reward: 1.500 [0.000, 3.000] - loss: 0.008 - mae: 0.191 - mean_q: 0.156 - ale.lives: 0.000
#
# Interval 22 (210000 steps performed)
# 10000/10000 [==============================] - 336s 34ms/step - reward: 0.0019
# 2 episodes - episode_reward: 9.000 [0.000, 18.000] - loss: 0.008 - mae: 0.220 - mean_q: 0.186 - ale.lives: 0.000
#
# Interval 23 (220000 steps performed)
# 10000/10000 [==============================] - 344s 34ms/step - reward: 0.0028
# 2 episodes - episode_reward: 11.500 [6.000, 17.000] - loss: 0.009 - mae: 0.241 - mean_q: 0.210 - ale.lives: 0.000
#
# Interval 24 (230000 steps performed)
# 10000/10000 [==============================] - 349s 35ms/step - reward: 0.0038
# 3 episodes - episode_reward: 14.000 [5.000, 26.000] - loss: 0.010 - mae: 0.267 - mean_q: 0.237 - ale.lives: 0.000
#
# Interval 25 (240000 steps performed)
# 10000/10000 [==============================] - 344s 34ms/step - reward: 0.0042
# 2 episodes - episode_reward: 22.000 [7.000, 37.000] - loss: 0.010 - mae: 0.294 - mean_q: 0.260 - ale.lives: 0.000
#
# Interval 26 (250000 steps performed)
# 10000/10000 [==============================] - 353s 35ms/step - reward: 0.0049
# 2 episodes - episode_reward: 24.500 [9.000, 40.000] - loss: 0.011 - mae: 0.323 - mean_q: 0.281 - ale.lives: 0.000
#
# Interval 27 (260000 steps performed)
# 10000/10000 [==============================] - 352s 35ms/step - reward: 6.0000e-04
# 2 episodes - episode_reward: 3.000 [0.000, 6.000] - loss: 0.011 - mae: 0.340 - mean_q: 0.292 - ale.lives: 0.000
#
# Interval 28 (270000 steps performed)
# 10000/10000 [==============================] - 353s 35ms/step - reward: 0.0029
# 3 episodes - episode_reward: 8.667 [4.000, 16.000] - loss: 0.012 - mae: 0.373 - mean_q: 0.324 - ale.lives: 0.000
#
# Interval 29 (280000 steps performed)
# 10000/10000 [==============================] - 359s 36ms/step - reward: 0.0011
# 2 episodes - episode_reward: 6.000 [6.000, 6.000] - loss: 0.012 - mae: 0.394 - mean_q: 0.329 - ale.lives: 0.000
#
# Interval 30 (290000 steps performed)
# 10000/10000 [==============================] - 356s 36ms/step - reward: 0.0041
# 2 episodes - episode_reward: 21.500 [7.000, 36.000] - loss: 0.012 - mae: 0.414 - mean_q: 0.338 - ale.lives: 0.000
#
# Interval 31 (300000 steps performed)
# 10000/10000 [==============================] - 356s 36ms/step - reward: 0.0046
# 2 episodes - episode_reward: 22.000 [14.000, 30.000] - loss: 0.013 - mae: 0.428 - mean_q: 0.345 - ale.lives: 0.000
#
# Interval 32 (310000 steps performed)
# 10000/10000 [==============================] - 357s 36ms/step - reward: 0.0025
# 3 episodes - episode_reward: 9.000 [0.000, 23.000] - loss: 0.014 - mae: 0.439 - mean_q: 0.334 - ale.lives: 0.000
#
# Interval 33 (320000 steps performed)
# 10000/10000 [==============================] - 362s 36ms/step - reward: 0.0036
# 2 episodes - episode_reward: 16.000 [6.000, 26.000] - loss: 0.014 - mae: 0.461 - mean_q: 0.355 - ale.lives: 0.000
#
# Interval 34 (330000 steps performed)
# 10000/10000 [==============================] - 363s 36ms/step - reward: 0.0073
# 2 episodes - episode_reward: 29.000 [10.000, 48.000] - loss: 0.013 - mae: 0.469 - mean_q: 0.348 - ale.lives: 0.000
#
# Interval 35 (340000 steps performed)
# 10000/10000 [==============================] - 366s 37ms/step - reward: 0.0056
# 2 episodes - episode_reward: 21.000 [20.000, 22.000] - loss: 0.014 - mae: 0.485 - mean_q: 0.352 - ale.lives: 0.000
#
# Interval 36 (350000 steps performed)
# 10000/10000 [==============================] - 367s 37ms/step - reward: 0.0120
# 3 episodes - episode_reward: 46.000 [42.000, 48.000] - loss: 0.015 - mae: 0.517 - mean_q: 0.383 - ale.lives: 0.000
#
# Interval 37 (360000 steps performed)
# 10000/10000 [==============================] - 368s 37ms/step - reward: 0.0065
# 2 episodes - episode_reward: 26.500 [12.000, 41.000] - loss: 0.016 - mae: 0.538 - mean_q: 0.387 - ale.lives: 0.000
#
# Interval 38 (370000 steps performed)
# 10000/10000 [==============================] - 370s 37ms/step - reward: 0.0046
# 2 episodes - episode_reward: 25.000 [16.000, 34.000] - loss: 0.017 - mae: 0.572 - mean_q: 0.394 - ale.lives: 0.000
#
# Interval 39 (380000 steps performed)
# 10000/10000 [==============================] - 370s 37ms/step - reward: 0.0067
# 2 episodes - episode_reward: 29.000 [15.000, 43.000] - loss: 0.018 - mae: 0.602 - mean_q: 0.434 - ale.lives: 0.000
#
# Interval 40 (390000 steps performed)
# 10000/10000 [==============================] - 372s 37ms/step - reward: 0.0076
# 3 episodes - episode_reward: 28.000 [20.000, 36.000] - loss: 0.019 - mae: 0.644 - mean_q: 0.454 - ale.lives: 0.000
#
# Interval 41 (400000 steps performed)
# 10000/10000 [==============================] - 377s 38ms/step - reward: 0.0044
# 2 episodes - episode_reward: 30.500 [20.000, 41.000] - loss: 0.019 - mae: 0.666 - mean_q: 0.474 - ale.lives: 0.000
#
# Interval 42 (410000 steps performed)
# 10000/10000 [==============================] - 378s 38ms/step - reward: 0.0101
# 2 episodes - episode_reward: 41.000 [34.000, 48.000] - loss: 0.020 - mae: 0.716 - mean_q: 0.522 - ale.lives: 0.000
#
# Interval 43 (420000 steps performed)
# 10000/10000 [==============================] - 381s 38ms/step - reward: 0.0118
# 2 episodes - episode_reward: 34.500 [34.000, 35.000] - loss: 0.022 - mae: 0.769 - mean_q: 0.592 - ale.lives: 0.000
#
# Interval 44 (430000 steps performed)
# 10000/10000 [==============================] - 381s 38ms/step - reward: 0.0176
# 3 episodes - episode_reward: 78.667 [47.000, 97.000] - loss: 0.022 - mae: 0.789 - mean_q: 0.618 - ale.lives: 0.000
#
# Interval 45 (440000 steps performed)
# 10000/10000 [==============================] - 379s 38ms/step - reward: 0.0074
# 2 episodes - episode_reward: 36.500 [19.000, 54.000] - loss: 0.022 - mae: 0.804 - mean_q: 0.624 - ale.lives: 0.000
#
# Interval 46 (450000 steps performed)
# 10000/10000 [==============================] - 381s 38ms/step - reward: 0.0133
# 2 episodes - episode_reward: 62.000 [31.000, 93.000] - loss: 0.023 - mae: 0.811 - mean_q: 0.637 - ale.lives: 0.000
#
# Interval 47 (460000 steps performed)
# 10000/10000 [==============================] - 386s 39ms/step - reward: 0.0133
# 2 episodes - episode_reward: 56.500 [45.000, 68.000] - loss: 0.022 - mae: 0.847 - mean_q: 0.675 - ale.lives: 0.000
#
# Interval 48 (470000 steps performed)
# 10000/10000 [==============================] - 394s 39ms/step - reward: 0.0231
# 3 episodes - episode_reward: 86.333 [65.000, 113.000] - loss: 0.024 - mae: 0.858 - mean_q: 0.686 - ale.lives: 0.000
#
# Interval 49 (480000 steps performed)
# 10000/10000 [==============================] - 390s 39ms/step - reward: 0.0150
# 2 episodes - episode_reward: 74.000 [57.000, 91.000] - loss: 0.023 - mae: 0.869 - mean_q: 0.702 - ale.lives: 0.000
#
# Interval 50 (490000 steps performed)
# 10000/10000 [==============================] - 389s 39ms/step - reward: 0.0108
# 2 episodes - episode_reward: 51.000 [14.000, 88.000] - loss: 0.025 - mae: 0.931 - mean_q: 0.762 - ale.lives: 0.000
#
# Interval 51 (500000 steps performed)
# 10000/10000 [==============================] - 391s 39ms/step - reward: 0.0148
# 2 episodes - episode_reward: 56.500 [30.000, 83.000] - loss: 0.024 - mae: 0.947 - mean_q: 0.755 - ale.lives: 0.000
#
# Interval 52 (510000 steps performed)
# 10000/10000 [==============================] - 400s 40ms/step - reward: 0.0222
# 3 episodes - episode_reward: 93.333 [90.000, 99.000] - loss: 0.026 - mae: 0.945 - mean_q: 0.748 - ale.lives: 0.000
#
# Interval 53 (520000 steps performed)
# 10000/10000 [==============================] - 404s 40ms/step - reward: 0.0174
# 2 episodes - episode_reward: 86.500 [56.000, 117.000] - loss: 0.026 - mae: 0.996 - mean_q: 0.815 - ale.lives: 0.000
#
# Interval 54 (530000 steps performed)
# 10000/10000 [==============================] - 400s 40ms/step - reward: 0.0248
# 2 episodes - episode_reward: 103.500 [86.000, 121.000] - loss: 0.025 - mae: 1.010 - mean_q: 0.854 - ale.lives: 0.000
#
# Interval 55 (540000 steps performed)
# 10000/10000 [==============================] - 400s 40ms/step - reward: 0.0219
# 2 episodes - episode_reward: 97.500 [92.000, 103.000] - loss: 0.026 - mae: 1.047 - mean_q: 0.910 - ale.lives: 0.000
#
# Interval 56 (550000 steps performed)
# 10000/10000 [==============================] - 409s 41ms/step - reward: 0.0225
# 3 episodes - episode_reward: 89.667 [66.000, 114.000] - loss: 0.026 - mae: 1.042 - mean_q: 0.914 - ale.lives: 0.000
#
# Interval 57 (560000 steps performed)
# 10000/10000 [==============================] - 409s 41ms/step - reward: 0.0194
# 2 episodes - episode_reward: 99.500 [87.000, 112.000] - loss: 0.027 - mae: 1.086 - mean_q: 0.957 - ale.lives: 0.000
#
# Interval 58 (570000 steps performed)
# 10000/10000 [==============================] - 407s 41ms/step - reward: 0.0270
# 2 episodes - episode_reward: 106.000 [105.000, 107.000] - loss: 0.027 - mae: 1.105 - mean_q: 0.964 - ale.lives: 0.000
#
# Interval 59 (580000 steps performed)
# 10000/10000 [==============================] - 413s 41ms/step - reward: 0.0257
# 2 episodes - episode_reward: 116.000 [116.000, 116.000] - loss: 0.028 - mae: 1.164 - mean_q: 1.038 - ale.lives: 0.000
#
# Interval 60 (590000 steps performed)
# 10000/10000 [==============================] - 412s 41ms/step - reward: 0.0220
# 3 episodes - episode_reward: 98.000 [84.000, 106.000] - loss: 0.027 - mae: 1.180 - mean_q: 1.069 - ale.lives: 0.000
#
# Interval 61 (600000 steps performed)
# 10000/10000 [==============================] - 418s 42ms/step - reward: 0.0204
# 2 episodes - episode_reward: 107.500 [83.000, 132.000] - loss: 0.032 - mae: 1.248 - mean_q: 1.123 - ale.lives: 0.000
#
# Interval 62 (610000 steps performed)
# 10000/10000 [==============================] - 418s 42ms/step - reward: 0.0296
# 2 episodes - episode_reward: 109.000 [99.000, 119.000] - loss: 0.030 - mae: 1.291 - mean_q: 1.186 - ale.lives: 0.000
#
# Interval 63 (620000 steps performed)
# 10000/10000 [==============================] - 426s 43ms/step - reward: 0.0272
# 2 episodes - episode_reward: 127.000 [113.000, 141.000] - loss: 0.032 - mae: 1.330 - mean_q: 1.249 - ale.lives: 0.000
#
# Interval 64 (630000 steps performed)
# 10000/10000 [==============================] - 433s 43ms/step - reward: 0.0298
# 3 episodes - episode_reward: 129.333 [117.000, 152.000] - loss: 0.033 - mae: 1.357 - mean_q: 1.274 - ale.lives: 0.000
#
# Interval 65 (640000 steps performed)
# 10000/10000 [==============================] - 433s 43ms/step - reward: 0.0200
# 2 episodes - episode_reward: 90.000 [62.000, 118.000] - loss: 0.032 - mae: 1.367 - mean_q: 1.290 - ale.lives: 0.000
#
# Interval 66 (650000 steps performed)
# 10000/10000 [==============================] - 438s 44ms/step - reward: 0.0264
# 2 episodes - episode_reward: 114.500 [104.000, 125.000] - loss: 0.034 - mae: 1.420 - mean_q: 1.370 - ale.lives: 0.000
#
# Interval 67 (660000 steps performed)
# 10000/10000 [==============================] - 440s 44ms/step - reward: 0.0273
# 2 episodes - episode_reward: 113.500 [108.000, 119.000] - loss: 0.033 - mae: 1.467 - mean_q: 1.431 - ale.lives: 0.000
#
# Interval 68 (670000 steps performed)
# 10000/10000 [==============================] - 443s 44ms/step - reward: 0.0276
# 3 episodes - episode_reward: 127.667 [121.000, 138.000] - loss: 0.033 - mae: 1.481 - mean_q: 1.438 - ale.lives: 0.000
#
# Interval 69 (680000 steps performed)
# 10000/10000 [==============================] - 443s 44ms/step - reward: 0.0254
# 2 episodes - episode_reward: 117.500 [93.000, 142.000] - loss: 0.033 - mae: 1.519 - mean_q: 1.487 - ale.lives: 0.000
#
# Interval 70 (690000 steps performed)
# 10000/10000 [==============================] - 442s 44ms/step - reward: 0.0251
# 2 episodes - episode_reward: 100.500 [81.000, 120.000] - loss: 0.032 - mae: 1.532 - mean_q: 1.498 - ale.lives: 0.000
#
# Interval 71 (700000 steps performed)
# 10000/10000 [==============================] - 449s 45ms/step - reward: 0.0168
# 3 episodes - episode_reward: 84.667 [65.000, 101.000] - loss: 0.033 - mae: 1.556 - mean_q: 1.517 - ale.lives: 0.000
#
# Interval 72 (710000 steps performed)
# 10000/10000 [==============================] - 443s 44ms/step - reward: 0.0251
# 2 episodes - episode_reward: 118.500 [116.000, 121.000] - loss: 0.035 - mae: 1.598 - mean_q: 1.571 - ale.lives: 0.000
#
# Interval 73 (720000 steps performed)
# 10000/10000 [==============================] - 446s 45ms/step - reward: 0.0246
# 2 episodes - episode_reward: 111.000 [100.000, 122.000] - loss: 0.034 - mae: 1.595 - mean_q: 1.558 - ale.lives: 0.000
#
# Interval 74 (730000 steps performed)
# 10000/10000 [==============================] - 458s 46ms/step - reward: 0.0271
# 2 episodes - episode_reward: 105.000 [98.000, 112.000] - loss: 0.033 - mae: 1.622 - mean_q: 1.603 - ale.lives: 0.000
#
# Interval 75 (740000 steps performed)
# 10000/10000 [==============================] - 468s 47ms/step - reward: 0.0256
# 3 episodes - episode_reward: 118.333 [114.000, 126.000] - loss: 0.039 - mae: 1.636 - mean_q: 1.605 - ale.lives: 0.000
#
# Interval 76 (750000 steps performed)
# 10000/10000 [==============================] - 468s 47ms/step - reward: 0.0272
# 2 episodes - episode_reward: 114.500 [106.000, 123.000] - loss: 0.035 - mae: 1.659 - mean_q: 1.644 - ale.lives: 0.000
#
# Interval 77 (760000 steps performed)
# 10000/10000 [==============================] - 464s 46ms/step - reward: 0.0162
# 2 episodes - episode_reward: 91.500 [59.000, 124.000] - loss: 0.035 - mae: 1.671 - mean_q: 1.664 - ale.lives: 0.000
#
# Interval 78 (770000 steps performed)
# 10000/10000 [==============================] - 471s 47ms/step - reward: 0.0195
# 2 episodes - episode_reward: 58.000 [55.000, 61.000] - loss: 0.037 - mae: 1.678 - mean_q: 1.673 - ale.lives: 0.000
#
# Interval 79 (780000 steps performed)
# 10000/10000 [==============================] - 477s 48ms/step - reward: 0.0271
# 3 episodes - episode_reward: 122.667 [117.000, 127.000] - loss: 0.037 - mae: 1.711 - mean_q: 1.707 - ale.lives: 0.000
#
# Interval 80 (790000 steps performed)
# 10000/10000 [==============================] - 480s 48ms/step - reward: 0.0250
# 2 episodes - episode_reward: 118.500 [117.000, 120.000] - loss: 0.038 - mae: 1.740 - mean_q: 1.741 - ale.lives: 0.000
#
# Interval 81 (800000 steps performed)
# 10000/10000 [==============================] - 475s 48ms/step - reward: 0.0310
# 2 episodes - episode_reward: 137.000 [126.000, 148.000] - loss: 0.038 - mae: 1.779 - mean_q: 1.780 - ale.lives: 0.000
#
# Interval 82 (810000 steps performed)
# 10000/10000 [==============================] - 480s 48ms/step - reward: 0.0234
# 2 episodes - episode_reward: 104.500 [99.000, 110.000] - loss: 0.041 - mae: 1.811 - mean_q: 1.814 - ale.lives: 0.000
#
# Interval 83 (820000 steps performed)
# 10000/10000 [==============================] - 483s 48ms/step - reward: 0.0270
# 3 episodes - episode_reward: 114.333 [91.000, 139.000] - loss: 0.040 - mae: 1.845 - mean_q: 1.863 - ale.lives: 0.000
#
# Interval 84 (830000 steps performed)
# 10000/10000 [==============================] - 482s 48ms/step - reward: 0.0217
# 2 episodes - episode_reward: 101.500 [85.000, 118.000] - loss: 0.039 - mae: 1.914 - mean_q: 1.940 - ale.lives: 0.000
#
# Interval 85 (840000 steps performed)
# 10000/10000 [==============================] - 494s 49ms/step - reward: 0.0267
# 2 episodes - episode_reward: 120.000 [99.000, 141.000] - loss: 0.039 - mae: 1.938 - mean_q: 1.966 - ale.lives: 0.000
#
# Interval 86 (850000 steps performed)
# 10000/10000 [==============================] - 494s 49ms/step - reward: 0.0305
# 2 episodes - episode_reward: 109.000 [99.000, 119.000] - loss: 0.041 - mae: 1.948 - mean_q: 2.021 - ale.lives: 0.000
#
# Interval 87 (860000 steps performed)
# 10000/10000 [==============================] - 492s 49ms/step - reward: 0.0212
# 3 episodes - episode_reward: 113.333 [89.000, 158.000] - loss: 0.040 - mae: 1.948 - mean_q: 2.028 - ale.lives: 0.000
#
# Interval 88 (870000 steps performed)
# 10000/10000 [==============================] - 478s 48ms/step - reward: 0.0234
# 2 episodes - episode_reward: 101.000 [79.000, 123.000] - loss: 0.039 - mae: 1.958 - mean_q: 2.039 - ale.lives: 0.000
#
# Interval 89 (880000 steps performed)
# 10000/10000 [==============================] - 478s 48ms/step - reward: 0.0183
# 2 episodes - episode_reward: 96.000 [86.000, 106.000] - loss: 0.041 - mae: 1.985 - mean_q: 2.084 - ale.lives: 0.000
#
# Interval 90 (890000 steps performed)
#  6765/10000 [===================>..........] - ETA: 2:39 - reward: 0.0273

# %% [markdown]
# ###### Propuesta 5 — Dueling DQN

# %%
# ----------------------------------------------------------------------
# PROPUESTA 5: Dueling DQN
#
# Mantiene la misma política de exploración que la Propuesta 1 (EpsGreedy
# fijo, eps=0.2), pero cambia el algoritmo: Dueling DQN separa la
# estimación del valor del estado V(s) de la ventaja de cada acción
# A(s,a), en lugar de estimar Q(s,a) directamente de forma monolítica.
# Útil en Enduro porque en muchos frames la acción concreta importa poco
# (conducir recto sin coches cerca), pero el valor del estado sí varía
# bastante (coches restantes, posición en pista) - separar ambas señales
# suele acelerar el aprendizaje en este tipo de secuencias con largos
# tramos "neutros".
#
# IMPORTANTE: usamos build_model_dueling_ready (no build_model) porque
# Dueling DQN necesita que la penúltima capa de la red sea la
# representación de 512 unidades, no la capa ya colapsada a 9 acciones
# (ver la explicación completa en la celda donde se define esa función).
# ----------------------------------------------------------------------

# NB_STEPS_TRAIN = 1000000  # ajustar según tiempo disponible / checkpoints

# --- Reanudación opcional (ver explicación detallada en la Propuesta 1) ---
RESUME_FROM_P5 = None
STEP_OFFSET_P5 = 0
RESUME_FROM_P5, STEP_OFFSET_P5 = find_latest_checkpoint(WEIGHTS_DIR_P5, 'dqn_Enduro-v0_p5')

model_p5 = build_model_dueling_ready(nb_actions, input_shape)
memory_p5 = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)

policy_p5 = EpsGreedyQPolicy(eps=0.2)

dqn_p5 = build_dqn_agent(
    model=model_p5, nb_actions=nb_actions, memory=memory_p5,
    processor=AtariProcessor(), policy=policy_p5,
    nb_steps_warmup=10000, target_model_update=10000,
    enable_double_dqn=False, enable_dueling_network=True, dueling_type='avg'
)

if RESUME_FROM_P5 is not None:
    print(f"Reanudando Propuesta 5 desde el checkpoint: {RESUME_FROM_P5}")
    dqn_p5.load_weights(RESUME_FROM_P5)
    NB_STEPS_REMAINING_P5 = max(0, NB_STEPS_TRAIN - STEP_OFFSET_P5)
else:
    NB_STEPS_REMAINING_P5 = NB_STEPS_TRAIN

weights_filename_p5 = os.path.join(WEIGHTS_DIR_P5, 'dqn_{}_p5_dueling_dqn_weights.h5f'.format(env_name))
checkpoint_filename_p5 = os.path.join(WEIGHTS_DIR_P5, 'dqn_' + env_name + '_p5_weights_{step}.h5f')
log_filename_p5 = os.path.join(WEIGHTS_DIR_P5, 'dqn_{}_p5_log.json'.format(env_name))

callbacks_p5 = [ResumableModelIntervalCheckpoint(checkpoint_filename_p5, interval=100000,
                                                  step_offset=STEP_OFFSET_P5)]
callbacks_p5 += [FileLogger(log_filename_p5, interval=1000)]

history_p5 = dqn_p5.fit(env, callbacks=callbacks_p5, nb_steps=NB_STEPS_REMAINING_P5,
                         log_interval=10000, visualize=False)

dqn_p5.save_weights(weights_filename_p5, overwrite=True)
print("Pesos finales de la Propuesta 5 guardados en Drive:", weights_filename_p5)
print("Contenido de la carpeta:", os.listdir(WEIGHTS_DIR_P5))
# Out:
# Reanudando Propuesta 5 desde el checkpoint: /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/p5_dueling_dqn/dqn_Enduro-v0_p5_weights_600000.h5f
# Training for 400000 steps ...
# Interval 1 (0 steps performed)
# /usr/local/lib/python3.11/dist-packages/tf_keras/src/engine/training_v1.py:2354: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 10000/10000 [==============================] - 50s 5ms/step - reward: 0.0286
# 2 episodes - episode_reward: 128.000 [118.000, 138.000] - ale.lives: 0.000
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 331s 33ms/step - reward: 0.0129
# 2 episodes - episode_reward: 67.000 [34.000, 100.000] - loss: 0.048 - mae: 2.935 - mean_q: 3.362 - ale.lives: 0.000
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 333s 33ms/step - reward: 0.0186
# 2 episodes - episode_reward: 86.500 [62.000, 111.000] - loss: 0.042 - mae: 2.941 - mean_q: 3.397 - ale.lives: 0.000
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 335s 33ms/step - reward: 0.0261
# 2 episodes - episode_reward: 86.000 [58.000, 114.000] - loss: 0.044 - mae: 2.990 - mean_q: 3.462 - ale.lives: 0.000
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 337s 34ms/step - reward: 0.0252
# 3 episodes - episode_reward: 123.000 [90.000, 152.000] - loss: 0.047 - mae: 3.089 - mean_q: 3.586 - ale.lives: 0.000
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 334s 33ms/step - reward: 0.0147
# 2 episodes - episode_reward: 72.000 [49.000, 95.000] - loss: 0.048 - mae: 3.120 - mean_q: 3.626 - ale.lives: 0.000
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 338s 34ms/step - reward: 0.0174
# 2 episodes - episode_reward: 75.500 [63.000, 88.000] - loss: 0.049 - mae: 3.139 - mean_q: 3.653 - ale.lives: 0.000
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 349s 35ms/step - reward: 0.0263
# 3 episodes - episode_reward: 99.667 [81.000, 127.000] - loss: 0.048 - mae: 3.224 - mean_q: 3.745 - ale.lives: 0.000
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 332s 33ms/step - reward: 0.0226
# 2 episodes - episode_reward: 104.000 [100.000, 108.000] - loss: 0.054 - mae: 3.259 - mean_q: 3.793 - ale.lives: 0.000
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 327s 33ms/step - reward: 0.0226
# 2 episodes - episode_reward: 104.500 [104.000, 105.000] - loss: 0.052 - mae: 3.331 - mean_q: 3.876 - ale.lives: 0.000
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 324s 32ms/step - reward: 0.0309
# 2 episodes - episode_reward: 127.000 [116.000, 138.000] - loss: 0.053 - mae: 3.369 - mean_q: 3.922 - ale.lives: 0.000
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 330s 33ms/step - reward: 0.0216
# 3 episodes - episode_reward: 101.333 [89.000, 110.000] - loss: 0.055 - mae: 3.478 - mean_q: 4.047 - ale.lives: 0.000
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 330s 33ms/step - reward: 0.0237
# 2 episodes - episode_reward: 106.000 [94.000, 118.000] - loss: 0.053 - mae: 3.528 - mean_q: 4.098 - ale.lives: 0.000
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 323s 32ms/step - reward: 0.0189
# 2 episodes - episode_reward: 98.500 [91.000, 106.000] - loss: 0.054 - mae: 3.556 - mean_q: 4.129 - ale.lives: 0.000
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 323s 32ms/step - reward: 0.0210
# 2 episodes - episode_reward: 96.500 [78.000, 115.000] - loss: 0.056 - mae: 3.616 - mean_q: 4.193 - ale.lives: 0.000
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 326s 33ms/step - reward: 0.0194
# 3 episodes - episode_reward: 76.000 [44.000, 116.000] - loss: 0.056 - mae: 3.624 - mean_q: 4.205 - ale.lives: 0.000
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 326s 33ms/step - reward: 0.0182
# 2 episodes - episode_reward: 85.000 [60.000, 110.000] - loss: 0.056 - mae: 3.638 - mean_q: 4.221 - ale.lives: 0.000
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 341s 34ms/step - reward: 0.0212
# 2 episodes - episode_reward: 94.000 [86.000, 102.000] - loss: 0.056 - mae: 3.682 - mean_q: 4.274 - ale.lives: 0.000
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 348s 35ms/step - reward: 0.0268
# 2 episodes - episode_reward: 106.500 [100.000, 113.000] - loss: 0.057 - mae: 3.743 - mean_q: 4.347 - ale.lives: 0.000
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 346s 35ms/step - reward: 0.0250
# 3 episodes - episode_reward: 112.667 [109.000, 115.000] - loss: 0.059 - mae: 3.761 - mean_q: 4.359 - ale.lives: 0.000
#
# Interval 21 (200000 steps performed)
# 10000/10000 [==============================] - 352s 35ms/step - reward: 0.0209
# 2 episodes - episode_reward: 87.500 [45.000, 130.000] - loss: 0.055 - mae: 3.796 - mean_q: 4.399 - ale.lives: 0.000
#
# Interval 22 (210000 steps performed)
# 10000/10000 [==============================] - 346s 35ms/step - reward: 0.0203
# 2 episodes - episode_reward: 114.000 [106.000, 122.000] - loss: 0.054 - mae: 3.839 - mean_q: 4.448 - ale.lives: 0.000
#
# Interval 23 (220000 steps performed)
# 10000/10000 [==============================] - 345s 34ms/step - reward: 0.0280
# 2 episodes - episode_reward: 86.000 [49.000, 123.000] - loss: 0.062 - mae: 3.855 - mean_q: 4.462 - ale.lives: 0.000
#
# Interval 24 (230000 steps performed)
# 10000/10000 [==============================] - 353s 35ms/step - reward: 0.0232
# 3 episodes - episode_reward: 116.667 [68.000, 160.000] - loss: 0.058 - mae: 3.938 - mean_q: 4.559 - ale.lives: 0.000
#
# Interval 25 (240000 steps performed)
# 10000/10000 [==============================] - 349s 35ms/step - reward: 0.0196
# 2 episodes - episode_reward: 96.000 [72.000, 120.000] - loss: 0.061 - mae: 4.015 - mean_q: 4.649 - ale.lives: 0.000
#
# Interval 26 (250000 steps performed)
# 10000/10000 [==============================] - 355s 35ms/step - reward: 0.0215
# 2 episodes - episode_reward: 94.000 [88.000, 100.000] - loss: 0.060 - mae: 4.120 - mean_q: 4.764 - ale.lives: 0.000
#
# Interval 27 (260000 steps performed)
# 10000/10000 [==============================] - 354s 35ms/step - reward: 0.0259
# 2 episodes - episode_reward: 99.500 [67.000, 132.000] - loss: 0.060 - mae: 4.164 - mean_q: 4.816 - ale.lives: 0.000
#
# Interval 28 (270000 steps performed)
# 10000/10000 [==============================] - 349s 35ms/step - reward: 0.0197
# 3 episodes - episode_reward: 91.000 [57.000, 112.000] - loss: 0.062 - mae: 4.192 - mean_q: 4.850 - ale.lives: 0.000
#
# Interval 29 (280000 steps performed)
# 10000/10000 [==============================] - 356s 36ms/step - reward: 0.0201
# 2 episodes - episode_reward: 108.000 [104.000, 112.000] - loss: 0.059 - mae: 4.282 - mean_q: 4.951 - ale.lives: 0.000
#
# Interval 30 (290000 steps performed)
# 10000/10000 [==============================] - 353s 35ms/step - reward: 0.0179
# 2 episodes - episode_reward: 72.000 [71.000, 73.000] - loss: 0.066 - mae: 4.326 - mean_q: 5.006 - ale.lives: 0.000
#
# Interval 31 (300000 steps performed)
# 10000/10000 [==============================] - 355s 36ms/step - reward: 0.0275
# 2 episodes - episode_reward: 109.500 [107.000, 112.000] - loss: 0.062 - mae: 4.357 - mean_q: 5.042 - ale.lives: 0.000
#
# Interval 32 (310000 steps performed)
# 10000/10000 [==============================] - 366s 37ms/step - reward: 0.0276
# 3 episodes - episode_reward: 116.667 [100.000, 143.000] - loss: 0.062 - mae: 4.398 - mean_q: 5.092 - ale.lives: 0.000
#
# Interval 33 (320000 steps performed)
# 10000/10000 [==============================] - 361s 36ms/step - reward: 0.0271
# 2 episodes - episode_reward: 127.000 [110.000, 144.000] - loss: 0.064 - mae: 4.553 - mean_q: 5.266 - ale.lives: 0.000
#
# Interval 34 (330000 steps performed)
# 10000/10000 [==============================] - 368s 37ms/step - reward: 0.0170
# 2 episodes - episode_reward: 94.000 [68.000, 120.000] - loss: 0.065 - mae: 4.614 - mean_q: 5.330 - ale.lives: 0.000
#
# Interval 35 (340000 steps performed)
# 10000/10000 [==============================] - 369s 37ms/step - reward: 0.0300
# 2 episodes - episode_reward: 102.000 [34.000, 170.000] - loss: 0.071 - mae: 4.608 - mean_q: 5.328 - ale.lives: 0.000
#
# Interval 36 (350000 steps performed)
# 10000/10000 [==============================] - 368s 37ms/step - reward: 0.0219
# 3 episodes - episode_reward: 105.667 [90.000, 120.000] - loss: 0.070 - mae: 4.720 - mean_q: 5.459 - ale.lives: 0.000
#
# Interval 37 (360000 steps performed)
# 10000/10000 [==============================] - 369s 37ms/step - reward: 0.0266
# 2 episodes - episode_reward: 129.500 [127.000, 132.000] - loss: 0.072 - mae: 4.867 - mean_q: 5.627 - ale.lives: 0.000
#
# Interval 38 (370000 steps performed)
# 10000/10000 [==============================] - 373s 37ms/step - reward: 0.0268
# 2 episodes - episode_reward: 121.000 [78.000, 164.000] - loss: 0.070 - mae: 4.901 - mean_q: 5.659 - ale.lives: 0.000
#
# Interval 39 (380000 steps performed)
# 10000/10000 [==============================] - 370s 37ms/step - reward: 0.0323
# 2 episodes - episode_reward: 125.000 [107.000, 143.000] - loss: 0.072 - mae: 5.002 - mean_q: 5.781 - ale.lives: 0.000
#
# Interval 40 (390000 steps performed)
# 10000/10000 [==============================] - 377s 38ms/step - reward: 0.0257
# done, took 13573.124 seconds
# Pesos finales de la Propuesta 5 guardados en Drive: /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/p5_dueling_dqn/dqn_Enduro-v0_p5_dueling_dqn_weights.h5f
# Contenido de la carpeta: ['dqn_Enduro-v0_p5_log.json', 'dqn_Enduro-v0_p5_weights_100000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_100000.h5f.index', 'dqn_Enduro-v0_p5_weights_200000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_200000.h5f.index', 'dqn_Enduro-v0_p5_weights_300000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_300000.h5f.index', 'dqn_Enduro-v0_p5_weights_400000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_400000.h5f.index', 'dqn_Enduro-v0_p5_weights_500000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_500000.h5f.index', 'dqn_Enduro-v0_p5_weights_600000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_600000.h5f.index', 'checkpoint', 'dqn_Enduro-v0_p5_weights_700000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_700000.h5f.index', 'dqn_Enduro-v0_p5_weights_800000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_800000.h5f.index', 'dqn_Enduro-v0_p5_weights_900000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_900000.h5f.index', 'dqn_Enduro-v0_p5_weights_1000000.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_weights_1000000.h5f.index', 'dqn_Enduro-v0_p5_dueling_dqn_weights.h5f.data-00000-of-00001', 'dqn_Enduro-v0_p5_dueling_dqn_weights.h5f.index']

# %% [markdown]
# ###### Propuesta 6 — Double DQN + Dueling DQN (combinando ambas mejoras)

# %%
# ----------------------------------------------------------------------
# PROPUESTA 6: Double DQN + Dueling DQN combinados
#
# Combina las dos mejoras evaluadas por separado en las Propuestas 4 y 5,
# manteniendo la misma política de exploración (EpsGreedy fijo, eps=0.2).
# Permite ver si los efectos de Double y Dueling se complementan o si,
# por el contrario, uno domina al otro / hay redundancia entre ambos en
# este entorno concreto.
#
# Usa build_model_dueling_ready, igual que la Propuesta 5.
# ----------------------------------------------------------------------

# NB_STEPS_TRAIN = 1000000  # ajustar según tiempo disponible / checkpoints


# --- Reanudación opcional (ver explicación detallada en la Propuesta 1) ---
RESUME_FROM_P6 = None
STEP_OFFSET_P6 = 0
RESUME_FROM_P6, STEP_OFFSET_P6 = find_latest_checkpoint(WEIGHTS_DIR_P6, 'dqn_Enduro-v0_p6')

model_p6 = build_model_dueling_ready(nb_actions, input_shape)
memory_p6 = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)

policy_p6 = EpsGreedyQPolicy(eps=0.2)

dqn_p6 = build_dqn_agent(
    model=model_p6, nb_actions=nb_actions, memory=memory_p6,
    processor=AtariProcessor(), policy=policy_p6,
    nb_steps_warmup=10000, target_model_update=10000,
    enable_double_dqn=True, enable_dueling_network=True, dueling_type='avg'
)

if RESUME_FROM_P6 is not None:
    print(f"Reanudando Propuesta 6 desde el checkpoint: {RESUME_FROM_P6}")
    dqn_p6.load_weights(RESUME_FROM_P6)
    NB_STEPS_REMAINING_P6 = max(0, NB_STEPS_TRAIN - STEP_OFFSET_P6)
else:
    NB_STEPS_REMAINING_P6 = NB_STEPS_TRAIN

weights_filename_p6 = os.path.join(WEIGHTS_DIR_P6, 'dqn_{}_p6_double_dueling_weights.h5f'.format(env_name))
checkpoint_filename_p6 = os.path.join(WEIGHTS_DIR_P6, 'dqn_' + env_name + '_p6_weights_{step}.h5f')
log_filename_p6 = os.path.join(WEIGHTS_DIR_P6, 'dqn_{}_p6_log.json'.format(env_name))

callbacks_p6 = [ResumableModelIntervalCheckpoint(checkpoint_filename_p6, interval=100000,
                                                  step_offset=STEP_OFFSET_P6)]
callbacks_p6 += [FileLogger(log_filename_p6, interval=1000)]

history_p6 = dqn_p6.fit(env, callbacks=callbacks_p6, nb_steps=NB_STEPS_REMAINING_P6,
                         log_interval=10000, visualize=False)

dqn_p6.save_weights(weights_filename_p6, overwrite=True)
print("Pesos finales de la Propuesta 6 guardados en Drive:", weights_filename_p6)
print("Contenido de la carpeta:", os.listdir(WEIGHTS_DIR_P6))
# Out:
# Reanudando Propuesta 6 desde el checkpoint: /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/p6_double_dueling/dqn_Enduro-v0_p6_weights_400000.h5f
# Training for 600000 steps ...
# Interval 1 (0 steps performed)
# /usr/local/lib/python3.11/dist-packages/tf_keras/src/engine/training_v1.py:2354: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 10000/10000 [==============================] - 49s 5ms/step - reward: 0.0166
# 2 episodes - episode_reward: 77.500 [52.000, 103.000] - ale.lives: 0.000
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 330s 33ms/step - reward: 0.0054
# 2 episodes - episode_reward: 30.000 [21.000, 39.000] - loss: 0.022 - mae: 0.965 - mean_q: 0.793 - ale.lives: 0.000
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 319s 32ms/step - reward: 0.0193
# 2 episodes - episode_reward: 82.500 [58.000, 107.000] - loss: 0.020 - mae: 0.975 - mean_q: 0.838 - ale.lives: 0.000
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 325s 33ms/step - reward: 0.0056
# 2 episodes - episode_reward: 25.500 [17.000, 34.000] - loss: 0.021 - mae: 0.999 - mean_q: 0.873 - ale.lives: 0.000
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 327s 33ms/step - reward: 0.0074
# 3 episodes - episode_reward: 34.000 [27.000, 38.000] - loss: 0.021 - mae: 0.976 - mean_q: 0.833 - ale.lives: 0.000
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 327s 33ms/step - reward: 0.0137
# 2 episodes - episode_reward: 61.500 [26.000, 97.000] - loss: 0.022 - mae: 1.036 - mean_q: 0.923 - ale.lives: 0.000
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 325s 33ms/step - reward: 0.0144
# 2 episodes - episode_reward: 67.000 [45.000, 89.000] - loss: 0.023 - mae: 1.045 - mean_q: 0.930 - ale.lives: 0.000
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 327s 33ms/step - reward: 0.0125
# 3 episodes - episode_reward: 53.000 [45.000, 62.000] - loss: 0.023 - mae: 1.061 - mean_q: 0.955 - ale.lives: 0.000
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 323s 32ms/step - reward: 0.0112
# 2 episodes - episode_reward: 48.500 [37.000, 60.000] - loss: 0.023 - mae: 1.075 - mean_q: 0.985 - ale.lives: 0.000
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 330s 33ms/step - reward: 0.0236
# 2 episodes - episode_reward: 114.500 [102.000, 127.000] - loss: 0.024 - mae: 1.101 - mean_q: 1.024 - ale.lives: 0.000
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 324s 32ms/step - reward: 0.0135
# 2 episodes - episode_reward: 59.000 [18.000, 100.000] - loss: 0.026 - mae: 1.142 - mean_q: 1.077 - ale.lives: 0.000
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 326s 33ms/step - reward: 0.0131
# 3 episodes - episode_reward: 56.667 [4.000, 99.000] - loss: 0.027 - mae: 1.159 - mean_q: 1.101 - ale.lives: 0.000
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 327s 33ms/step - reward: 0.0112
# 2 episodes - episode_reward: 50.000 [48.000, 52.000] - loss: 0.028 - mae: 1.178 - mean_q: 1.124 - ale.lives: 0.000
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 331s 33ms/step - reward: 0.0140
# 2 episodes - episode_reward: 72.500 [51.000, 94.000] - loss: 0.026 - mae: 1.156 - mean_q: 1.103 - ale.lives: 0.000
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 335s 33ms/step - reward: 0.0088
# 2 episodes - episode_reward: 38.500 [34.000, 43.000] - loss: 0.028 - mae: 1.191 - mean_q: 1.147 - ale.lives: 0.000
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 334s 33ms/step - reward: 0.0165
# 3 episodes - episode_reward: 59.333 [35.000, 86.000] - loss: 0.028 - mae: 1.211 - mean_q: 1.168 - ale.lives: 0.000
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 334s 33ms/step - reward: 0.0105
# 2 episodes - episode_reward: 52.500 [45.000, 60.000] - loss: 0.028 - mae: 1.249 - mean_q: 1.249 - ale.lives: 0.000
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 337s 34ms/step - reward: 0.0224
# 2 episodes - episode_reward: 111.000 [105.000, 117.000] - loss: 0.029 - mae: 1.281 - mean_q: 1.294 - ale.lives: 0.000
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 331s 33ms/step - reward: 0.0203
# 2 episodes - episode_reward: 88.000 [70.000, 106.000] - loss: 0.028 - mae: 1.292 - mean_q: 1.319 - ale.lives: 0.000
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 332s 33ms/step - reward: 0.0097
# 3 episodes - episode_reward: 43.667 [40.000, 46.000] - loss: 0.028 - mae: 1.343 - mean_q: 1.391 - ale.lives: 0.000
#
# Interval 21 (200000 steps performed)
# 10000/10000 [==============================] - 333s 33ms/step - reward: 0.0099
# 2 episodes - episode_reward: 34.000 [28.000, 40.000] - loss: 0.028 - mae: 1.412 - mean_q: 1.469 - ale.lives: 0.000
#
# Interval 22 (210000 steps performed)
# 10000/10000 [==============================] - 346s 35ms/step - reward: 0.0216
# 2 episodes - episode_reward: 102.000 [97.000, 107.000] - loss: 0.030 - mae: 1.411 - mean_q: 1.480 - ale.lives: 0.000
#
# Interval 23 (220000 steps performed)
# 10000/10000 [==============================] - 354s 35ms/step - reward: 0.0185
# 2 episodes - episode_reward: 107.000 [102.000, 112.000] - loss: 0.029 - mae: 1.425 - mean_q: 1.511 - ale.lives: 0.000
#
# Interval 24 (230000 steps performed)
# 10000/10000 [==============================] - 354s 35ms/step - reward: 0.0096
# 3 episodes - episode_reward: 36.333 [20.000, 60.000] - loss: 0.032 - mae: 1.431 - mean_q: 1.511 - ale.lives: 0.000
#
# Interval 25 (240000 steps performed)
# 10000/10000 [==============================] - 353s 35ms/step - reward: 0.0095
# 2 episodes - episode_reward: 48.000 [47.000, 49.000] - loss: 0.030 - mae: 1.428 - mean_q: 1.519 - ale.lives: 0.000
#
# Interval 26 (250000 steps performed)
# 10000/10000 [==============================] - 358s 36ms/step - reward: 0.0110
# 2 episodes - episode_reward: 47.000 [15.000, 79.000] - loss: 0.031 - mae: 1.479 - mean_q: 1.577 - ale.lives: 0.000
#
# Interval 27 (260000 steps performed)
# 10000/10000 [==============================] - 357s 36ms/step - reward: 0.0101
# 2 episodes - episode_reward: 27.500 [6.000, 49.000] - loss: 0.031 - mae: 1.506 - mean_q: 1.609 - ale.lives: 0.000
#
# Interval 28 (270000 steps performed)
# 10000/10000 [==============================] - 366s 37ms/step - reward: 0.0233
# 3 episodes - episode_reward: 94.333 [64.000, 116.000] - loss: 0.032 - mae: 1.527 - mean_q: 1.637 - ale.lives: 0.000
#
# Interval 29 (280000 steps performed)
# 10000/10000 [==============================] - 361s 36ms/step - reward: 0.0078
# 2 episodes - episode_reward: 44.500 [23.000, 66.000] - loss: 0.032 - mae: 1.535 - mean_q: 1.647 - ale.lives: 0.000
#
# Interval 30 (290000 steps performed)
# 10000/10000 [==============================] - 367s 37ms/step - reward: 0.0110
# 2 episodes - episode_reward: 39.000 [31.000, 47.000] - loss: 0.034 - mae: 1.566 - mean_q: 1.685 - ale.lives: 0.000
#
# Interval 31 (300000 steps performed)
# 10000/10000 [==============================] - 359s 36ms/step - reward: 0.0119
# 2 episodes - episode_reward: 50.000 [25.000, 75.000] - loss: 0.034 - mae: 1.608 - mean_q: 1.725 - ale.lives: 0.000
#
# Interval 32 (310000 steps performed)
# 10000/10000 [==============================] - 366s 37ms/step - reward: 0.0168
# 3 episodes - episode_reward: 73.000 [49.000, 112.000] - loss: 0.035 - mae: 1.604 - mean_q: 1.717 - ale.lives: 0.000
#
# Interval 33 (320000 steps performed)
# 10000/10000 [==============================] - 369s 37ms/step - reward: 0.0144
# 2 episodes - episode_reward: 62.000 [52.000, 72.000] - loss: 0.035 - mae: 1.651 - mean_q: 1.766 - ale.lives: 0.000
#
# Interval 34 (330000 steps performed)
# 10000/10000 [==============================] - 366s 37ms/step - reward: 0.0224
# 2 episodes - episode_reward: 100.000 [52.000, 148.000] - loss: 0.036 - mae: 1.681 - mean_q: 1.806 - ale.lives: 0.000
#
# Interval 35 (340000 steps performed)
# 10000/10000 [==============================] - 366s 37ms/step - reward: 0.0286
# 2 episodes - episode_reward: 117.500 [117.000, 118.000] - loss: 0.036 - mae: 1.694 - mean_q: 1.802 - ale.lives: 0.000
#
# Interval 36 (350000 steps performed)
# 10000/10000 [==============================] - 366s 37ms/step - reward: 0.0258
# 3 episodes - episode_reward: 113.000 [104.000, 120.000] - loss: 0.036 - mae: 1.727 - mean_q: 1.847 - ale.lives: 0.000
#
# Interval 37 (360000 steps performed)
# 10000/10000 [==============================] - 364s 36ms/step - reward: 0.0269
# 2 episodes - episode_reward: 128.000 [105.000, 151.000] - loss: 0.038 - mae: 1.799 - mean_q: 1.911 - ale.lives: 0.000
#
# Interval 38 (370000 steps performed)
# 10000/10000 [==============================] - 373s 37ms/step - reward: 0.0231
# 2 episodes - episode_reward: 95.500 [64.000, 127.000] - loss: 0.038 - mae: 1.843 - mean_q: 1.950 - ale.lives: 0.000
#
# Interval 39 (380000 steps performed)
# 10000/10000 [==============================] - 374s 37ms/step - reward: 0.0287
# 2 episodes - episode_reward: 115.500 [113.000, 118.000] - loss: 0.039 - mae: 1.829 - mean_q: 1.920 - ale.lives: 0.000
#
# Interval 40 (390000 steps performed)
# 10000/10000 [==============================] - 380s 38ms/step - reward: 0.0235
# 3 episodes - episode_reward: 116.333 [107.000, 132.000] - loss: 0.040 - mae: 1.848 - mean_q: 1.944 - ale.lives: 0.000
#
# Interval 41 (400000 steps performed)
#   901/10000 [=>............................] - ETA: 5:44 - reward: 0.0166
#   913/10000 [=>............................] - ETA: 5:45 - reward: 0.0164
# Failed to restart the Kernel.
#
# Invalid response: 404 Not Found.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
model_p1 = build_model(nb_actions, input_shape)
memory_p1 = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)

policy_p1 = EpsGreedyQPolicy(eps=0.2)

dqn_p1 = build_dqn_agent(
    model=model_p1, nb_actions=nb_actions, memory=memory_p1,
    processor=AtariProcessor(), policy=policy_p1,
    nb_steps_warmup=10000, target_model_update=10000
)

# %%
# Testing part to calculate the mean reward
#
# NOTA: el objetivo del grupo es superar el primer día de carrera de Enduro
# durante 100 episodios consecutivos en modo test.
#
# Elige aquí qué propuesta quieres evaluar (no hace falta que haya
# terminado del todo: detecta automáticamente el ÚLTIMO checkpoint
# disponible en su carpeta, aunque el entrenamiento se haya interrummpido a
# medias). Solo necesitas tener en memoria el dqn_* de la propuesta que
# vayas a evaluar (no hace falta haber ejecutado las otras dos).

PROPUESTA_A_EVALUAR = 'p1'  # 'p1', 'p2', 'p3', 'p4', 'p5' o 'p6'

_info_por_propuesta = {
    'p1': {'dir': WEIGHTS_DIR_P1, 'prefix': 'dqn_Enduro-v0_p1', 'var': 'dqn_p1'},
    'p2': {'dir': WEIGHTS_DIR_P2, 'prefix': 'dqn_Enduro-v0_p2', 'var': 'dqn_p2'},
    'p3': {'dir': WEIGHTS_DIR_P3, 'prefix': 'dqn_Enduro-v0_p3', 'var': 'dqn_p3'},
    'p4': {'dir': WEIGHTS_DIR_P4, 'prefix': 'dqn_Enduro-v0_p4', 'var': 'dqn_p4'},
    'p5': {'dir': WEIGHTS_DIR_P5, 'prefix': 'dqn_Enduro-v0_p5', 'var': 'dqn_p5'},
    'p6': {'dir': WEIGHTS_DIR_P6, 'prefix': 'dqn_Enduro-v0_p6', 'var': 'dqn_p6'},
}

info = _info_por_propuesta[PROPUESTA_A_EVALUAR]

if info['var'] not in globals():
    print(f"No tienes '{info['var']}' en memoria todavía: ejecuta primero la celda "
          f"de la {PROPUESTA_A_EVALUAR.upper()} (aunque sea solo hasta que se cree el "
          f"agente, no falta que termine de entrenar) antes de correr este test.")
else:
    dqn_test = globals()[info['var']]
    # find_latest_checkpoint ya está definida más arriba (junto a ResumableModelIntervalCheckpoint)
    weights_filename, last_step = find_latest_checkpoint(info['dir'], info['prefix'])

    if weights_filename is None:
        print(f"No se encontró ningún checkpoint guardado todavía para {PROPUESTA_A_EVALUAR} "
              f"en {info['dir']}")
    else:
        print(f"Cargando pesos desde: {weights_filename}  (step {last_step})")
        dqn_test.load_weights(weights_filename)
        test_history = dqn_test.test(env, nb_episodes=100, visualize=False)

        mean_reward = np.mean(test_history.history['episode_reward'])
        std_reward = np.std(test_history.history['episode_reward'])
        print(f"\nRecompensa media en 100 episodios de test: {mean_reward:.2f} (+/- {std_reward:.2f})")
# Out:
# Cargando pesos desde: /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/p1_eps_fijo/dqn_Enduro-v0_p1_weights_1000000.h5f  (step 1000000)
# Testing for 100 episodes ...
# /usr/local/lib/python3.11/dist-packages/tf_keras/src/engine/training_v1.py:2354: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Episode 1: reward: 148.000, steps: 4438
# Episode 2: reward: 324.000, steps: 8901
# Episode 3: reward: 186.000, steps: 4442
# Episode 4: reward: 119.000, steps: 4450
# Episode 5: reward: 129.000, steps: 4428
# Episode 6: reward: 139.000, steps: 4471
# Episode 7: reward: 128.000, steps: 4423
# Episode 8: reward: 118.000, steps: 4448
# Episode 9: reward: 290.000, steps: 8876
# Episode 10: reward: 122.000, steps: 4465
# Episode 11: reward: 186.000, steps: 4451
# Episode 12: reward: 282.000, steps: 8860
# Episode 13: reward: 106.000, steps: 4433
# Episode 14: reward: 144.000, steps: 4432
# Episode 15: reward: 154.000, steps: 4406
# Episode 16: reward: 168.000, steps: 4443
# Episode 17: reward: 183.000, steps: 4407
# Episode 18: reward: 166.000, steps: 4439
# Episode 19: reward: 159.000, steps: 4432
# Episode 20: reward: 159.000, steps: 4436
# Episode 21: reward: 178.000, steps: 4444
# Episode 22: reward: 172.000, steps: 4441
# Episode 23: reward: 99.000, steps: 4428
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-18-643161126.py in <cell line: 0>()
#      38         print(f"Cargando pesos desde: {weights_filename}  (step {last_step})")
#      39         dqn_test.load_weights(weights_filename)
# ---> 40         test_history = dqn_test.test(env, nb_episodes=100, visualize=False)
#      41
#      42         mean_reward = np.mean(test_history.history['episode_reward'])
#
# /usr/local/lib/python3.11/dist-packages/rl/core.py in test(self, env, nb_episodes, action_repetition, callbacks, visualize, nb_max_episode_steps, nb_max_start_steps, start_step_policy, verbose)
#     339                 callbacks.on_step_begin(episode_step)
#     340
# --> 341                 action = self.forward(observation)
#     342                 if self.processor is not None:
#     343                     action = self.processor.process_action(action)
#
# /usr/local/lib/python3.11/dist-packages/rl/agents/dqn.py in forward(self, observation)
#     222         # Select an action.
#     223         state = self.memory.get_recent_state(observation)
# --> 224         q_values = self.compute_q_values(state)
#     225         if self.training:
#     226             action = self.policy.select_action(q_values=q_values)
#
# /usr/local/lib/python3.11/dist-packages/rl/agents/dqn.py in compute_q_values(self, state)
#      66
#      67     def compute_q_values(self, state):
# ---> 68         q_values = self.compute_batch_q_values([state]).flatten()
#      69         assert q_values.shape == (self.nb_actions,)
#      70         return q_values
#
# /usr/local/lib/python3.11/dist-packages/rl/agents/dqn.py in compute_batch_q_values(self, state_batch)
#      60
#      61     def compute_batch_q_values(self, state_batch):
# ---> 62         batch = self.process_state_batch(state_batch)
#      63         q_values = self.model.predict_on_batch(batch)
#      64         assert q_values.shape == (len(state_batch), self.nb_actions)
#
# /usr/local/lib/python3.11/dist-packages/rl/agents/dqn.py in process_state_batch(self, batch)
#      57         if self.processor is None:
#      58             return batch
# ---> 59         return self.processor.process_state_batch(batch)
#      60
#      61     def compute_batch_q_values(self, state_batch):
#
# /tmp/ipython-input-9-2035342856.py in process_state_batch(self, batch)
#      33
#      34     def process_state_batch(self, batch):
# ---> 35         processed_batch = batch.astype('float32') / 255.
#      36         return processed_batch
#      37
#
# KeyboardInterrupt:

# %%
model_p2 = build_model(nb_actions, input_shape)
memory_p2 = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)

# Annealing más rápido que en Breakout (300k en lugar de 2M steps), dado que
# el reward en Enduro es más disperso y conviene empezar a explotar antes.
#
# OJO con reanudar esta propuesta en concreto: a diferencia de la Propuesta 1
# (epsilon fijo), aquí el valor de epsilon depende de self.step dentro de
# LinearAnnealedPolicy. Como keras-rl2 NO persiste self.step al recargar
# pesos, la policy nueva volverá a calcular epsilon como si empezara desde 0
# (es decir, con más exploración de la que tocaría en ese punto del
# annealing). Esto no rompe nada, pero conviene saberlo: tras reanudar, la
# exploración será algo más alta de lo que habría sido sin interrupción.
policy_p2 = LinearAnnealedPolicy(
    EpsGreedyQPolicy(), attr='eps',
    value_max=1., value_min=.1, value_test=.05,
    nb_steps=300000
)

dqn_p2 = build_dqn_agent(
    model=model_p2, nb_actions=nb_actions, memory=memory_p2,
    processor=AtariProcessor(), policy=policy_p2,
    nb_steps_warmup=10000, target_model_update=10000
)

# %%
# Testing part to calculate the mean reward
#
# NOTA: el objetivo del grupo es superar el primer día de carrera de Enduro
# durante 100 episodios consecutivos en modo test.
#
# Elige aquí qué propuesta quieres evaluar (no hace falta que haya
# terminado del todo: detecta automáticamente el ÚLTIMO checkpoint
# disponible en su carpeta, aunque el entrenamiento se haya interrummpido a
# medias). Solo necesitas tener en memoria el dqn_* de la propuesta que
# vayas a evaluar (no hace falta haber ejecutado las otras dos).

PROPUESTA_A_EVALUAR = 'p2'  # 'p1', 'p2', 'p3', 'p4', 'p5' o 'p6'

_info_por_propuesta = {
    'p1': {'dir': WEIGHTS_DIR_P1, 'prefix': 'dqn_Enduro-v0_p1', 'var': 'dqn_p1'},
    'p2': {'dir': WEIGHTS_DIR_P2, 'prefix': 'dqn_Enduro-v0_p2', 'var': 'dqn_p2'},
    'p3': {'dir': WEIGHTS_DIR_P3, 'prefix': 'dqn_Enduro-v0_p3', 'var': 'dqn_p3'},
    'p4': {'dir': WEIGHTS_DIR_P4, 'prefix': 'dqn_Enduro-v0_p4', 'var': 'dqn_p4'},
    'p5': {'dir': WEIGHTS_DIR_P5, 'prefix': 'dqn_Enduro-v0_p5', 'var': 'dqn_p5'},
    'p6': {'dir': WEIGHTS_DIR_P6, 'prefix': 'dqn_Enduro-v0_p6', 'var': 'dqn_p6'},
}

info = _info_por_propuesta[PROPUESTA_A_EVALUAR]

if info['var'] not in globals():
    print(f"No tienes '{info['var']}' en memoria todavía: ejecuta primero la celda "
          f"de la {PROPUESTA_A_EVALUAR.upper()} (aunque sea solo hasta que se cree el "
          f"agente, no falta que termine de entrenar) antes de correr este test.")
else:
    dqn_test = globals()[info['var']]
    # find_latest_checkpoint ya está definida más arriba (junto a ResumableModelIntervalCheckpoint)
    weights_filename, last_step = find_latest_checkpoint(info['dir'], info['prefix'])

    if weights_filename is None:
        print(f"No se encontró ningún checkpoint guardado todavía para {PROPUESTA_A_EVALUAR} "
              f"en {info['dir']}")
    else:
        print(f"Cargando pesos desde: {weights_filename}  (step {last_step})")
        dqn_test.load_weights(weights_filename)
        test_history = dqn_test.test(env, nb_episodes=100, visualize=False)

        mean_reward = np.mean(test_history.history['episode_reward'])
        std_reward = np.std(test_history.history['episode_reward'])
        print(f"\nRecompensa media en 100 episodios de test: {mean_reward:.2f} (+/- {std_reward:.2f})")
# Out:
# Cargando pesos desde: /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/p2_annealed/dqn_Enduro-v0_p2_weights_700000.h5f  (step 700000)
# Testing for 100 episodes ...
# Episode 1: reward: 0.000, steps: 4443
# Episode 2: reward: 0.000, steps: 4426
# Episode 3: reward: 0.000, steps: 4429
# Episode 4: reward: 0.000, steps: 4439
# Episode 5: reward: 0.000, steps: 4437
# Episode 6: reward: 14.000, steps: 4421
# Episode 7: reward: 0.000, steps: 4447
# Episode 8: reward: 0.000, steps: 4473
# Episode 9: reward: 0.000, steps: 4444
# Episode 10: reward: 0.000, steps: 4447
# Episode 11: reward: 0.000, steps: 4427
# Episode 12: reward: 0.000, steps: 4448
# Episode 13: reward: 0.000, steps: 4395
# Episode 14: reward: 0.000, steps: 4416
# Episode 15: reward: 0.000, steps: 4440
# Episode 16: reward: 0.000, steps: 4468
# Episode 17: reward: 0.000, steps: 4435
# Episode 18: reward: 0.000, steps: 4453
# Episode 19: reward: 0.000, steps: 4437
# Episode 20: reward: 0.000, steps: 4441
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-22-2233813634.py in <cell line: 0>()
#      38         print(f"Cargando pesos desde: {weights_filename}  (step {last_step})")
#      39         dqn_test.load_weights(weights_filename)
# ---> 40         test_history = dqn_test.test(env, nb_episodes=100, visualize=False)
#      41
#      42         mean_reward = np.mean(test_history.history['episode_reward'])
#
# /usr/local/lib/python3.11/dist-packages/rl/core.py in test(self, env, nb_episodes, action_repetition, callbacks, visualize, nb_max_episode_steps, nb_max_start_steps, start_step_policy, verbose)
#     349                     observation = deepcopy(observation)
#     350                     if self.processor is not None:
# --> 351                         observation, r, d, info = self.processor.process_step(observation, r, d, info)
#     352                     callbacks.on_action_end(action)
#     353                     reward += r
#
# /usr/local/lib/python3.11/dist-packages/rl/core.py in process_step(self, observation, reward, done, info)
#     520             The tupel (observation, reward, done, reward) with with all elements after being processed.
#     521         """
# --> 522         observation = self.process_observation(observation)
#     523         reward = self.process_reward(reward)
#     524         info = self.process_info(info)
#
# /tmp/ipython-input-9-2035342856.py in process_observation(self, observation)
#      27         assert observation.ndim == 3  # (height, width, channel)
#      28         img = Image.fromarray(observation)
# ---> 29         img = img.resize(INPUT_SHAPE).convert('L')
#      30         processed_observation = np.array(img)
#      31         assert processed_observation.shape == INPUT_SHAPE
#
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py in resize(self, size, resample, box, reducing_gap)
#    2314                 )
#    2315
# -> 2316         return self._new(self.im.resize(size, resample, box))
#    2317
#    2318     def reduce(
#
# KeyboardInterrupt:

# %%
model_p3 = build_model(nb_actions, input_shape)
memory_p3 = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)

policy_p3 = BoltzmannQPolicy(tau=1.)

dqn_p3 = build_dqn_agent(
    model=model_p3, nb_actions=nb_actions, memory=memory_p3,
    processor=AtariProcessor(), policy=policy_p3,
    nb_steps_warmup=10000, target_model_update=10000
)

# %%
# Testing part to calculate the mean reward
#
# NOTA: el objetivo del grupo es superar el primer día de carrera de Enduro
# durante 100 episodios consecutivos en modo test.
#
# Elige aquí qué propuesta quieres evaluar (no hace falta que haya
# terminado del todo: detecta automáticamente el ÚLTIMO checkpoint
# disponible en su carpeta, aunque el entrenamiento se haya interrummpido a
# medias). Solo necesitas tener en memoria el dqn_* de la propuesta que
# vayas a evaluar (no hace falta haber ejecutado las otras dos).

PROPUESTA_A_EVALUAR = 'p3'  # 'p1', 'p2', 'p3', 'p4', 'p5' o 'p6'

_info_por_propuesta = {
    'p1': {'dir': WEIGHTS_DIR_P1, 'prefix': 'dqn_Enduro-v0_p1', 'var': 'dqn_p1'},
    'p2': {'dir': WEIGHTS_DIR_P2, 'prefix': 'dqn_Enduro-v0_p2', 'var': 'dqn_p2'},
    'p3': {'dir': WEIGHTS_DIR_P3, 'prefix': 'dqn_Enduro-v0_p3', 'var': 'dqn_p3'},
    'p4': {'dir': WEIGHTS_DIR_P4, 'prefix': 'dqn_Enduro-v0_p4', 'var': 'dqn_p4'},
    'p5': {'dir': WEIGHTS_DIR_P5, 'prefix': 'dqn_Enduro-v0_p5', 'var': 'dqn_p5'},
    'p6': {'dir': WEIGHTS_DIR_P6, 'prefix': 'dqn_Enduro-v0_p6', 'var': 'dqn_p6'},
}

info = _info_por_propuesta[PROPUESTA_A_EVALUAR]

if info['var'] not in globals():
    print(f"No tienes '{info['var']}' en memoria todavía: ejecuta primero la celda "
          f"de la {PROPUESTA_A_EVALUAR.upper()} (aunque sea solo hasta que se cree el "
          f"agente, no falta que termine de entrenar) antes de correr este test.")
else:
    dqn_test = globals()[info['var']]
    # find_latest_checkpoint ya está definida más arriba (junto a ResumableModelIntervalCheckpoint)
    weights_filename, last_step = find_latest_checkpoint(info['dir'], info['prefix'])

    if weights_filename is None:
        print(f"No se encontró ningún checkpoint guardado todavía para {PROPUESTA_A_EVALUAR} "
              f"en {info['dir']}")
    else:
        print(f"Cargando pesos desde: {weights_filename}  (step {last_step})")
        dqn_test.load_weights(weights_filename)
        test_history = dqn_test.test(env, nb_episodes=100, visualize=False)

        mean_reward = np.mean(test_history.history['episode_reward'])
        std_reward = np.std(test_history.history['episode_reward'])
        print(f"\nRecompensa media en 100 episodios de test: {mean_reward:.2f} (+/- {std_reward:.2f})")
# Out:
# Cargando pesos desde: /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/p3_boltzmann/dqn_Enduro-v0_p3_weights_800000.h5f  (step 800000)
# Testing for 100 episodes ...
# Episode 1: reward: 0.000, steps: 4426
# Episode 2: reward: 0.000, steps: 4452
# Episode 3: reward: 0.000, steps: 4454
# Episode 4: reward: 0.000, steps: 4444
# Episode 5: reward: 0.000, steps: 4426
# Episode 6: reward: 0.000, steps: 4408
# Episode 7: reward: 0.000, steps: 4460
# Episode 8: reward: 0.000, steps: 4427
# Episode 9: reward: 0.000, steps: 4408
# Episode 10: reward: 0.000, steps: 4411
# Episode 11: reward: 0.000, steps: 4446
# Episode 12: reward: 0.000, steps: 4437
# Episode 13: reward: 0.000, steps: 4430
# Episode 14: reward: 0.000, steps: 4450
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-24-2764633556.py in <cell line: 0>()
#      38         print(f"Cargando pesos desde: {weights_filename}  (step {last_step})")
#      39         dqn_test.load_weights(weights_filename)
# ---> 40         test_history = dqn_test.test(env, nb_episodes=100, visualize=False)
#      41
#      42         mean_reward = np.mean(test_history.history['episode_reward'])
#
# /usr/local/lib/python3.11/dist-packages/rl/core.py in test(self, env, nb_episodes, action_repetition, callbacks, visualize, nb_max_episode_steps, nb_max_start_steps, start_step_policy, verbose)
#     339                 callbacks.on_step_begin(episode_step)
#     340
# --> 341                 action = self.forward(observation)
#     342                 if self.processor is not None:
#     343                     action = self.processor.process_action(action)
#
# /usr/local/lib/python3.11/dist-packages/rl/agents/dqn.py in forward(self, observation)
#     222         # Select an action.
#     223         state = self.memory.get_recent_state(observation)
# --> 224         q_values = self.compute_q_values(state)
#     225         if self.training:
#     226             action = self.policy.select_action(q_values=q_values)
#
# /usr/local/lib/python3.11/dist-packages/rl/agents/dqn.py in compute_q_values(self, state)
#      66
#      67     def compute_q_values(self, state):
# ---> 68         q_values = self.compute_batch_q_values([state]).flatten()
#      69         assert q_values.shape == (self.nb_actions,)
#      70         return q_values
#
# /usr/local/lib/python3.11/dist-packages/rl/agents/dqn.py in compute_batch_q_values(self, state_batch)
#      60
#      61     def compute_batch_q_values(self, state_batch):
# ---> 62         batch = self.process_state_batch(state_batch)
#      63         q_values = self.model.predict_on_batch(batch)
#      64         assert q_values.shape == (len(state_batch), self.nb_actions)
#
# /usr/local/lib/python3.11/dist-packages/rl/agents/dqn.py in process_state_batch(self, batch)
#      57         if self.processor is None:
#      58             return batch
# ---> 59         return self.processor.process_state_batch(batch)
#      60
#      61     def compute_batch_q_values(self, state_batch):
#
# /tmp/ipython-input-9-2035342856.py in process_state_batch(self, batch)
#      33
#      34     def process_state_batch(self, batch):
# ---> 35         processed_batch = batch.astype('float32') / 255.
#      36         return processed_batch
#      37
#
# KeyboardInterrupt:

# %%
model_p4 = build_model(nb_actions, input_shape)
memory_p4 = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)

policy_p4 = EpsGreedyQPolicy(eps=0.2)

dqn_p4 = build_dqn_agent(
    model=model_p4, nb_actions=nb_actions, memory=memory_p4,
    processor=AtariProcessor(), policy=policy_p4,
    nb_steps_warmup=10000, target_model_update=10000,
    enable_double_dqn=True, enable_dueling_network=False
)

# %%
# Testing part to calculate the mean reward
#
# NOTA: el objetivo del grupo es superar el primer día de carrera de Enduro
# durante 100 episodios consecutivos en modo test.
#
# Elige aquí qué propuesta quieres evaluar (no hace falta que haya
# terminado del todo: detecta automáticamente el ÚLTIMO checkpoint
# disponible en su carpeta, aunque el entrenamiento se haya interrummpido a
# medias). Solo necesitas tener en memoria el dqn_* de la propuesta que
# vayas a evaluar (no hace falta haber ejecutado las otras dos).

PROPUESTA_A_EVALUAR = 'p4'  # 'p1', 'p2', 'p3', 'p4', 'p5' o 'p6'

_info_por_propuesta = {
    'p1': {'dir': WEIGHTS_DIR_P1, 'prefix': 'dqn_Enduro-v0_p1', 'var': 'dqn_p1'},
    'p2': {'dir': WEIGHTS_DIR_P2, 'prefix': 'dqn_Enduro-v0_p2', 'var': 'dqn_p2'},
    'p3': {'dir': WEIGHTS_DIR_P3, 'prefix': 'dqn_Enduro-v0_p3', 'var': 'dqn_p3'},
    'p4': {'dir': WEIGHTS_DIR_P4, 'prefix': 'dqn_Enduro-v0_p4', 'var': 'dqn_p4'},
    'p5': {'dir': WEIGHTS_DIR_P5, 'prefix': 'dqn_Enduro-v0_p5', 'var': 'dqn_p5'},
    'p6': {'dir': WEIGHTS_DIR_P6, 'prefix': 'dqn_Enduro-v0_p6', 'var': 'dqn_p6'},
}

info = _info_por_propuesta[PROPUESTA_A_EVALUAR]

if info['var'] not in globals():
    print(f"No tienes '{info['var']}' en memoria todavía: ejecuta primero la celda "
          f"de la {PROPUESTA_A_EVALUAR.upper()} (aunque sea solo hasta que se cree el "
          f"agente, no falta que termine de entrenar) antes de correr este test.")
else:
    dqn_test = globals()[info['var']]
    # find_latest_checkpoint ya está definida más arriba (junto a ResumableModelIntervalCheckpoint)
    weights_filename, last_step = find_latest_checkpoint(info['dir'], info['prefix'])

    if weights_filename is None:
        print(f"No se encontró ningún checkpoint guardado todavía para {PROPUESTA_A_EVALUAR} "
              f"en {info['dir']}")
    else:
        print(f"Cargando pesos desde: {weights_filename}  (step {last_step})")
        dqn_test.load_weights(weights_filename)
        test_history = dqn_test.test(env, nb_episodes=100, visualize=False)

        mean_reward = np.mean(test_history.history['episode_reward'])
        std_reward = np.std(test_history.history['episode_reward'])
        print(f"\nRecompensa media en 100 episodios de test: {mean_reward:.2f} (+/- {std_reward:.2f})")
# Out:
# Cargando pesos desde: /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/p4_double_dqn/dqn_Enduro-v0_p4_weights_800000.h5f  (step 800000)
# Testing for 100 episodes ...
# Episode 1: reward: 163.000, steps: 4429
# Episode 2: reward: 169.000, steps: 4426
# Episode 3: reward: 190.000, steps: 4447
# Episode 4: reward: 196.000, steps: 4440
# Episode 5: reward: 192.000, steps: 4456
# Episode 6: reward: 188.000, steps: 4446
# Episode 7: reward: 146.000, steps: 4433
# Episode 8: reward: 187.000, steps: 4431
# Episode 9: reward: 158.000, steps: 4407
# Episode 10: reward: 133.000, steps: 4468
# Episode 11: reward: 154.000, steps: 4428
# Episode 12: reward: 197.000, steps: 4439
# Episode 13: reward: 154.000, steps: 4420
# Episode 14: reward: 185.000, steps: 4432
# Episode 15: reward: 180.000, steps: 4444
# Episode 16: reward: 184.000, steps: 4438
# Episode 17: reward: 358.000, steps: 8862
# Episode 18: reward: 191.000, steps: 4414
# Episode 19: reward: 377.000, steps: 8910
# Episode 20: reward: 295.000, steps: 8829
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-26-1692602780.py in <cell line: 0>()
#      38         print(f"Cargando pesos desde: {weights_filename}  (step {last_step})")
#      39         dqn_test.load_weights(weights_filename)
# ---> 40         test_history = dqn_test.test(env, nb_episodes=100, visualize=False)
#      41
#      42         mean_reward = np.mean(test_history.history['episode_reward'])
#
# /usr/local/lib/python3.11/dist-packages/rl/core.py in test(self, env, nb_episodes, action_repetition, callbacks, visualize, nb_max_episode_steps, nb_max_start_steps, start_step_policy, verbose)
#     339                 callbacks.on_step_begin(episode_step)
#     340
# --> 341                 action = self.forward(observation)
#     342                 if self.processor is not None:
#     343                     action = self.processor.process_action(action)
#
# /usr/local/lib/python3.11/dist-packages/rl/agents/dqn.py in forward(self, observation)
#     222         # Select an action.
#     223         state = self.memory.get_recent_state(observation)
# --> 224         q_values = self.compute_q_values(state)
#     225         if self.training:
#     226             action = self.policy.select_action(q_values=q_values)
#
# /usr/local/lib/python3.11/dist-packages/rl/agents/dqn.py in compute_q_values(self, state)
#      66
#      67     def compute_q_values(self, state):
# ---> 68         q_values = self.compute_batch_q_values([state]).flatten()
#      69         assert q_values.shape == (self.nb_actions,)
#      70         return q_values
#
# /usr/local/lib/python3.11/dist-packages/rl/agents/dqn.py in compute_batch_q_values(self, state_batch)
#      61     def compute_batch_q_values(self, state_batch):
#      62         batch = self.process_state_batch(state_batch)
# ---> 63         q_values = self.model.predict_on_batch(batch)
#      64         assert q_values.shape == (len(state_batch), self.nb_actions)
#      65         return q_values
#
# /usr/local/lib/python3.11/dist-packages/tf_keras/src/engine/training_v1.py in predict_on_batch(self, x)
#    1315
#    1316         self._make_predict_function()
# -> 1317         outputs = self.predict_function(inputs)
#    1318
#    1319         if len(outputs) == 1:
#
# /usr/local/lib/python3.11/dist-packages/tf_keras/src/backend.py in __call__(self, inputs)
#    4609         fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    4610         self._call_fetch_callbacks(fetched[-len(self._fetches) :])
# -> 4611         output_structure = tf.nest.pack_sequence_as(
#    4612             self._outputs_structure,
#    4613             fetched[: len(self.outputs)],
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/nest.py in pack_sequence_as(structure, flat_sequence, expand_composites)
#     535     TypeError: `structure` is or contains a dict with non-sortable keys.
#     536   """
# --> 537   return nest_util.pack_sequence_as(
#     538       nest_util.Modality.CORE, structure, flat_sequence, expand_composites
#     539   )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/nest_util.py in pack_sequence_as(modality, structure, flat_sequence, expand_composites, sequence_fn)
#     853   """
#     854   if modality == Modality.CORE:
# --> 855     return _tf_core_pack_sequence_as(
#     856         structure, flat_sequence, expand_composites, sequence_fn
#     857     )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/nest_util.py in _tf_core_pack_sequence_as(structure, flat_sequence, expand_composites, sequence_fn)
#     901
#     902   try:
# --> 903     final_index, packed = _tf_core_packed_nest_with_indices(
#     904         structure, flat_sequence, 0, is_nested_fn, sequence_fn
#     905     )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/nest_util.py in _tf_core_packed_nest_with_indices(structure, flat, index, is_nested_fn, sequence_fn)
#     569   packed = []
#     570   sequence_fn = sequence_fn or sequence_like
# --> 571   for s in _tf_core_yield_value(structure):
#     572     if is_nested_fn(s):
#     573       new_index, child = _tf_core_packed_nest_with_indices(
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/nest_util.py in _tf_core_yield_value(iterable)
#     308
#     309
# --> 310 def _tf_core_yield_value(iterable):
#     311   for _, v in _tf_core_yield_sorted_items(iterable):
#     312     yield v
#
# KeyboardInterrupt:

# %%
model_p5 = build_model_dueling_ready(nb_actions, input_shape)
memory_p5 = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)

policy_p5 = EpsGreedyQPolicy(eps=0.2)

dqn_p5 = build_dqn_agent(
    model=model_p5, nb_actions=nb_actions, memory=memory_p5,
    processor=AtariProcessor(), policy=policy_p5,
    nb_steps_warmup=10000, target_model_update=10000,
    enable_double_dqn=False, enable_dueling_network=True, dueling_type='avg'
)

# %%
# Testing part to calculate the mean reward
#
# NOTA: el objetivo del grupo es superar el primer día de carrera de Enduro
# durante 100 episodios consecutivos en modo test.
#
# Elige aquí qué propuesta quieres evaluar (no hace falta que haya
# terminado del todo: detecta automáticamente el ÚLTIMO checkpoint
# disponible en su carpeta, aunque el entrenamiento se haya interrummpido a
# medias). Solo necesitas tener en memoria el dqn_* de la propuesta que
# vayas a evaluar (no hace falta haber ejecutado las otras dos).

PROPUESTA_A_EVALUAR = 'p5'  # 'p1', 'p2', 'p3', 'p4', 'p5' o 'p6'

_info_por_propuesta = {
    'p1': {'dir': WEIGHTS_DIR_P1, 'prefix': 'dqn_Enduro-v0_p1', 'var': 'dqn_p1'},
    'p2': {'dir': WEIGHTS_DIR_P2, 'prefix': 'dqn_Enduro-v0_p2', 'var': 'dqn_p2'},
    'p3': {'dir': WEIGHTS_DIR_P3, 'prefix': 'dqn_Enduro-v0_p3', 'var': 'dqn_p3'},
    'p4': {'dir': WEIGHTS_DIR_P4, 'prefix': 'dqn_Enduro-v0_p4', 'var': 'dqn_p4'},
    'p5': {'dir': WEIGHTS_DIR_P5, 'prefix': 'dqn_Enduro-v0_p5', 'var': 'dqn_p5'},
    'p6': {'dir': WEIGHTS_DIR_P6, 'prefix': 'dqn_Enduro-v0_p6', 'var': 'dqn_p6'},
}

info = _info_por_propuesta[PROPUESTA_A_EVALUAR]

if info['var'] not in globals():
    print(f"No tienes '{info['var']}' en memoria todavía: ejecuta primero la celda "
          f"de la {PROPUESTA_A_EVALUAR.upper()} (aunque sea solo hasta que se cree el "
          f"agente, no falta que termine de entrenar) antes de correr este test.")
else:
    dqn_test = globals()[info['var']]
    # find_latest_checkpoint ya está definida más arriba (junto a ResumableModelIntervalCheckpoint)
    weights_filename, last_step = find_latest_checkpoint(info['dir'], info['prefix'])

    if weights_filename is None:
        print(f"No se encontró ningún checkpoint guardado todavía para {PROPUESTA_A_EVALUAR} "
              f"en {info['dir']}")
    else:
        print(f"Cargando pesos desde: {weights_filename}  (step {last_step})")
        dqn_test.load_weights(weights_filename)
        test_history = dqn_test.test(env, nb_episodes=100, visualize=False)

        mean_reward = np.mean(test_history.history['episode_reward'])
        std_reward = np.std(test_history.history['episode_reward'])
        print(f"\nRecompensa media en 100 episodios de test: {mean_reward:.2f} (+/- {std_reward:.2f})")
# Out:
# Cargando pesos desde: /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/p5_dueling_dqn/dqn_Enduro-v0_p5_weights_600000.h5f  (step 600000)
# Testing for 100 episodes ...
# Episode 1: reward: 171.000, steps: 4424
# Episode 2: reward: 195.000, steps: 4440
# Episode 3: reward: 193.000, steps: 4462
# Episode 4: reward: 373.000, steps: 8898
# Episode 5: reward: 382.000, steps: 8850
# Episode 6: reward: 180.000, steps: 4434
# Episode 7: reward: 455.000, steps: 8863
# Episode 8: reward: 372.000, steps: 8882
# Episode 9: reward: 195.000, steps: 4465
# Episode 10: reward: 308.000, steps: 8877
# Episode 11: reward: 396.000, steps: 8885
# Episode 12: reward: 358.000, steps: 8881
# Episode 13: reward: 373.000, steps: 8893
# Episode 14: reward: 387.000, steps: 8923
# Episode 15: reward: 436.000, steps: 8883
# Episode 16: reward: 172.000, steps: 4427
# Episode 17: reward: 199.000, steps: 4434
# Episode 18: reward: 388.000, steps: 8867
# Episode 19: reward: 374.000, steps: 8874
# Episode 20: reward: 419.000, steps: 8891
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-28-487675189.py in <cell line: 0>()
#      38         print(f"Cargando pesos desde: {weights_filename}  (step {last_step})")
#      39         dqn_test.load_weights(weights_filename)
# ---> 40         test_history = dqn_test.test(env, nb_episodes=100, visualize=False)
#      41
#      42         mean_reward = np.mean(test_history.history['episode_reward'])
#
# /usr/local/lib/python3.11/dist-packages/rl/core.py in test(self, env, nb_episodes, action_repetition, callbacks, visualize, nb_max_episode_steps, nb_max_start_steps, start_step_policy, verbose)
#     339                 callbacks.on_step_begin(episode_step)
#     340
# --> 341                 action = self.forward(observation)
#     342                 if self.processor is not None:
#     343                     action = self.processor.process_action(action)
#
# /usr/local/lib/python3.11/dist-packages/rl/agents/dqn.py in forward(self, observation)
#     222         # Select an action.
#     223         state = self.memory.get_recent_state(observation)
# --> 224         q_values = self.compute_q_values(state)
#     225         if self.training:
#     226             action = self.policy.select_action(q_values=q_values)
#
# /usr/local/lib/python3.11/dist-packages/rl/agents/dqn.py in compute_q_values(self, state)
#      66
#      67     def compute_q_values(self, state):
# ---> 68         q_values = self.compute_batch_q_values([state]).flatten()
#      69         assert q_values.shape == (self.nb_actions,)
#      70         return q_values
#
# /usr/local/lib/python3.11/dist-packages/rl/agents/dqn.py in compute_batch_q_values(self, state_batch)
#      61     def compute_batch_q_values(self, state_batch):
#      62         batch = self.process_state_batch(state_batch)
# ---> 63         q_values = self.model.predict_on_batch(batch)
#      64         assert q_values.shape == (len(state_batch), self.nb_actions)
#      65         return q_values
#
# /usr/local/lib/python3.11/dist-packages/tf_keras/src/engine/training_v1.py in predict_on_batch(self, x)
#    1288               expectations of the model.
#    1289         """
# -> 1290         self._check_call_args("predict_on_batch")
#    1291
#    1292         if (
#
# /usr/local/lib/python3.11/dist-packages/tf_keras/src/engine/training_v1.py in _check_call_args(self, method_name)
#    1433         )
#    1434
# -> 1435     def _check_call_args(self, method_name):
#    1436         """Check that `call` has only one positional arg."""
#    1437         # Always allow first arg, regardless of arg name.
#
# KeyboardInterrupt:

# %%
model_p6 = build_model_dueling_ready(nb_actions, input_shape)
memory_p6 = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)

policy_p6 = EpsGreedyQPolicy(eps=0.2)

dqn_p6 = build_dqn_agent(
    model=model_p6, nb_actions=nb_actions, memory=memory_p6,
    processor=AtariProcessor(), policy=policy_p6,
    nb_steps_warmup=10000, target_model_update=10000,
    enable_double_dqn=True, enable_dueling_network=True, dueling_type='avg'
)

# %%
# Testing part to calculate the mean reward
#
# NOTA: el objetivo del grupo es superar el primer día de carrera de Enduro
# durante 100 episodios consecutivos en modo test.
#
# Elige aquí qué propuesta quieres evaluar (no hace falta que haya
# terminado del todo: detecta automáticamente el ÚLTIMO checkpoint
# disponible en su carpeta, aunque el entrenamiento se haya interrummpido a
# medias). Solo necesitas tener en memoria el dqn_* de la propuesta que
# vayas a evaluar (no hace falta haber ejecutado las otras dos).

PROPUESTA_A_EVALUAR = 'p6'  # 'p1', 'p2', 'p3', 'p4', 'p5' o 'p6'

_info_por_propuesta = {
    'p1': {'dir': WEIGHTS_DIR_P1, 'prefix': 'dqn_Enduro-v0_p1', 'var': 'dqn_p1'},
    'p2': {'dir': WEIGHTS_DIR_P2, 'prefix': 'dqn_Enduro-v0_p2', 'var': 'dqn_p2'},
    'p3': {'dir': WEIGHTS_DIR_P3, 'prefix': 'dqn_Enduro-v0_p3', 'var': 'dqn_p3'},
    'p4': {'dir': WEIGHTS_DIR_P4, 'prefix': 'dqn_Enduro-v0_p4', 'var': 'dqn_p4'},
    'p5': {'dir': WEIGHTS_DIR_P5, 'prefix': 'dqn_Enduro-v0_p5', 'var': 'dqn_p5'},
    'p6': {'dir': WEIGHTS_DIR_P6, 'prefix': 'dqn_Enduro-v0_p6', 'var': 'dqn_p6'},
}

info = _info_por_propuesta[PROPUESTA_A_EVALUAR]

if info['var'] not in globals():
    print(f"No tienes '{info['var']}' en memoria todavía: ejecuta primero la celda "
          f"de la {PROPUESTA_A_EVALUAR.upper()} (aunque sea solo hasta que se cree el "
          f"agente, no falta que termine de entrenar) antes de correr este test.")
else:
    dqn_test = globals()[info['var']]
    # find_latest_checkpoint ya está definida más arriba (junto a ResumableModelIntervalCheckpoint)
    weights_filename, last_step = find_latest_checkpoint(info['dir'], info['prefix'])

    if weights_filename is None:
        print(f"No se encontró ningún checkpoint guardado todavía para {PROPUESTA_A_EVALUAR} "
              f"en {info['dir']}")
    else:
        print(f"Cargando pesos desde: {weights_filename}  (step {last_step})")
        dqn_test.load_weights(weights_filename)
        test_history = dqn_test.test(env, nb_episodes=100, visualize=False)

        mean_reward = np.mean(test_history.history['episode_reward'])
        std_reward = np.std(test_history.history['episode_reward'])
        print(f"\nRecompensa media en 100 episodios de test: {mean_reward:.2f} (+/- {std_reward:.2f})")
# Out:
# Cargando pesos desde: /content/gdrive/My Drive/VIU_Apr_por_Refuerzo_Grupo_17_2025_2026/checkpoints/p6_double_dueling/dqn_Enduro-v0_p6_weights_400000.h5f  (step 400000)
# Testing for 100 episodes ...
# Episode 1: reward: 126.000, steps: 4434
# Episode 2: reward: 105.000, steps: 4422
# Episode 3: reward: 58.000, steps: 4440
# Episode 4: reward: 131.000, steps: 4445
# Episode 5: reward: 103.000, steps: 4421
# Episode 6: reward: 56.000, steps: 4414
# Episode 7: reward: 102.000, steps: 4477
# Episode 8: reward: 106.000, steps: 4456
# Episode 9: reward: 92.000, steps: 4432
# Episode 10: reward: 115.000, steps: 4433
# Episode 11: reward: 101.000, steps: 4438
# Episode 12: reward: 119.000, steps: 4426
# Episode 13: reward: 129.000, steps: 4413
# Episode 14: reward: 122.000, steps: 4400
# Episode 15: reward: 45.000, steps: 4444
# Episode 16: reward: 166.000, steps: 4450
# Episode 17: reward: 92.000, steps: 4436
# Episode 18: reward: 98.000, steps: 4435
# Episode 19: reward: 100.000, steps: 4465
# Episode 20: reward: 105.000, steps: 4425
# Episode 21: reward: 103.000, steps: 4419
# Episode 22: reward: 110.000, steps: 4419
# Episode 23: reward: 53.000, steps: 4421
# Episode 24: reward: 119.000, steps: 4443
# Episode 25: reward: 123.000, steps: 4452
# Episode 26: reward: 115.000, steps: 4428
# Episode 27: reward: 127.000, steps: 4445
# Episode 28: reward: 71.000, steps: 4415
# Episode 29: reward: 93.000, steps: 4430
# Episode 30: reward: 131.000, steps: 4406
# Episode 31: reward: 100.000, steps: 4418
# Episode 32: reward: 120.000, steps: 4417
# Episode 33: reward: 140.000, steps: 4446
# Episode 34: reward: 111.000, steps: 4424
# Episode 35: reward: 107.000, steps: 4427
# Episode 36: reward: 125.000, steps: 4426
# Episode 37: reward: 104.000, steps: 4427
# Episode 38: reward: 106.000, steps: 4425
# Episode 39: reward: 104.000, steps: 4464
# Episode 40: reward: 115.000, steps: 4427
# Failed to restart the Kernel.
#
# Invalid response: 404 Not Found.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ##### Empaquetar la entrega (notebook + pesos del mejor modelo)

# %%
# El enunciado pide entregar el notebook junto con los pesos del MEJOR
# modelo en un .zip. Generamos ese .zip directamente dentro de Drive,
# para que solo tengas que descargarlo desde drive.google.com a tu PC
# cuando termine el entrenamiento.
#
# Usa los pesos del último checkpoint evaluado en la celda de test de
# arriba (variables weights_filename y weights_dir, de la propuesta que
# hayas puesto en PROPUESTA_A_EVALUAR). Si quieres empaquetar otra
# propuesta distinta a la que evaluaste por última vez, vuelve a ejecutar
# la celda de test con PROPUESTA_A_EVALUAR ajustada antes de esta celda.

import shutil
import glob

ENTREGA_DIR = os.path.join(RESULTS_DIR, 'entrega_final')
os.makedirs(ENTREGA_DIR, exist_ok=True)

# Copiamos el notebook actual y los pesos del mejor modelo (.index +
# .data-*) a la carpeta de entrega.
notebook_candidates = glob.glob(os.path.join(WORK_DIR, '*.ipynb'))
for nb_path in notebook_candidates:
    shutil.copy(nb_path, ENTREGA_DIR)

for f in glob.glob(weights_filename + '*'):
    shutil.copy(f, ENTREGA_DIR)

# Creamos el .zip final dentro de Drive
zip_path_base = os.path.join(RESULTS_DIR, 'entrega_final')
zip_path = shutil.make_archive(zip_path_base, 'zip', ENTREGA_DIR)

print("Entrega empaquetada en Drive:")
print(" ", zip_path)
print("\nContenido incluido:")
for f in os.listdir(ENTREGA_DIR):
    print("  -", f)
print("\nDescárgalo desde drive.google.com (o sincronízalo con Google Drive "
      "for Desktop) a tu PC, por ejemplo a:")
print("  C:\\Users\\willi\\Desktop\\Apr.x.Ref")

# %% [markdown]
# ##### Comparación gráfica de las 3 propuestas

# %%
# ----------------------------------------------------------------------
# PARTE 3: Carga de logs de entrenamiento para comparar las 3 propuestas
# ----------------------------------------------------------------------
import json
import matplotlib.pyplot as plt


def load_log(filename):
    with open(filename, 'r') as f:
        data = json.load(f)
    return data


log_p1 = load_log(log_filename_p1)
log_p2 = load_log(log_filename_p2)
log_p3 = load_log(log_filename_p3)

logs = {
    'Propuesta 1 (EpsGreedy fijo)': log_p1,
    'Propuesta 2 (Annealed EpsGreedy)': log_p2,
    'Propuesta 3 (Boltzmann)': log_p3,
}

# %%
# Gráfica 1: evolución de la recompensa media por episodio durante el entrenamiento
plt.figure(figsize=(10, 6))
for label, log in logs.items():
    plt.plot(log['nb_steps'], log['episode_reward'], label=label, alpha=0.7)
plt.xlabel('Steps de entrenamiento')
plt.ylabel('Reward por episodio')
plt.title('Evolución del reward durante el entrenamiento (Enduro)')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %%
# Gráfica 2: media móvil del reward para suavizar la varianza episodio a episodio
import pandas as pd

plt.figure(figsize=(10, 6))
WINDOW = 50
for label, log in logs.items():
    rewards = pd.Series(log['episode_reward'])
    rolling = rewards.rolling(WINDOW, min_periods=1).mean()
    plt.plot(log['nb_steps'], rolling, label=label)
plt.xlabel('Steps de entrenamiento')
plt.ylabel(f'Reward medio (media móvil, ventana={WINDOW})')
plt.title('Comparación de velocidad de aprendizaje entre propuestas')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %%
# Gráfica 3: duración media de los episodios (nb_episode_steps) como proxy de
# cuánto tiempo sobrevive / avanza el coche antes de terminar el episodio
plt.figure(figsize=(10, 6))
for label, log in logs.items():
    plt.plot(log['nb_steps'], log['nb_episode_steps'], label=label, alpha=0.7)
plt.xlabel('Steps de entrenamiento')
plt.ylabel('Steps por episodio')
plt.title('Duración de los episodios durante el entrenamiento')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %%
# Gráfica 4 (extra): comparación final de medias de test entre las 3 propuestas
# Útil para justificar de forma visual cuál propuesta cumple mejor el
# objetivo (superar el primer día de Enduro en modo test).
final_means = {
    'Propuesta 1\n(EpsGreedy fijo)': np.mean(log_p1['episode_reward'][-50:]),
    'Propuesta 2\n(Annealed)': np.mean(log_p2['episode_reward'][-50:]),
    'Propuesta 3\n(Boltzmann)': np.mean(log_p3['episode_reward'][-50:]),
}

plt.figure(figsize=(8, 6))
plt.bar(final_means.keys(), final_means.values(),
        color=['#4C72B0', '#55A868', '#C44E52'])
plt.ylabel('Reward medio (últimos 50 episodios de entrenamiento)')
plt.title('Comparación final entre las 3 propuestas')
plt.grid(alpha=0.3, axis='y')
plt.show()

# %% [markdown]
# 3. Justificación de los parámetros seleccionados y de los resultados obtenidos

# %%
"""
### 3. Justificación de los parámetros seleccionados y de los resultados obtenidos

(Plantilla a completar con los resultados reales una vez entrenadas las 3
propuestas; sustituir los X.XX por los valores obtenidos)

**Resumen de hiperparámetros comparados**

| Propuesta | Política | nb_steps_warmup | target_model_update | Annealing |
|---|---|---|---|---|
| 1 | EpsGreedy fijo (eps=0.2) | 10 000 | 10 000 | No |
| 2 | LinearAnnealed EpsGreedy | 10 000 | 10 000 | 1.0 → 0.1 en 300k steps |
| 3 | Boltzmann (tau=1.0) | 10 000 | 10 000 | No (exploración implícita) |

**Resultados de test (100 episodios, criterio: superar el primer día de
Enduro de forma consecutiva)**

- Propuesta 1: reward medio = X.XX, episodios que superan el día 1 = XX/100
- Propuesta 2: reward medio = X.XX, episodios que superan el día 1 = XX/100
- Propuesta 3: reward medio = X.XX, episodios que superan el día 1 = XX/100

**Discusión**

- ¿Qué propuesta aprendió más rápido en las primeras fases (gráfica 2)? ¿Es
  coherente con la hipótesis de que un annealing más agresivo ayuda a
  explotar antes una señal de reward tan dispersa como la de Enduro?
- ¿La política Boltzmann generó políticas con menos varianza entre episodios
  (gráfica 1) que el EpsGreedy fijo? ¿Por qué cabría esperar eso dado que la
  exploración depende de los propios valores Q en lugar de un parámetro fijo?
- ¿Alguna propuesta no llegó a despegar (reward estancado en 0 durante
  muchos steps)? Relacionar con el diagnóstico inicial sobre lo disperso del
  reward y la necesidad de "descubrir" la acción de acelerar.
- Relación entre duración de episodio (gráfica 3) y reward: en Enduro, vivir
  más tiempo no garantiza más reward si el coche no acelera; comentar si se
  observa este patrón en los resultados (episodios largos con reward bajo
  estarían indicando elusión del choque sin progreso real).
- Concluir cuál de las 3 propuestas se considera la mejor solución final y
  por qué, indicando si se alcanzó o no el objetivo mínimo del grupo.
"""

# %% [markdown]
# ---
