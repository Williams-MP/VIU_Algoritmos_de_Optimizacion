# %% [markdown]
# # **Código Dado**

# %%
# !pip uninstall -y tensorflow tensorflow-cpu tensorflow-text keras keras-hub keras-nlp tf-keras protobuf
# !pip install -U pip
# !pip install "tensorflow==2.20.0" "tensorflow-text==2.20.1" "keras==3.13.0" "keras-hub==0.29.0"


import numpy as np
import requests
import matplotlib.pyplot as plt
from PIL import Image
import keras_hub

# !pip -q install -U ultralytics
from ultralytics import YOLO
# !pip -q install -U keras keras-cv tensorflow matplotlib
import os
os.environ["KERAS_BACKEND"] = "tensorflow"
import numpy as np
import keras
import keras_cv
import matplotlib.pyplot as plt


img_yolo = "https://patitasco.com/img/ybc_blog/post/perros-marrones-portada-patitasco.jpg"


url = "http://images.cocodataset.org/val2017/000000077595.jpg"
image = Image.open(requests.get(url, stream=True).raw).convert("RGB")
image = image.resize((256, 256))
image_np = np.array(image).astype("float32")
# Out:
# Found existing installation: keras 3.14.0
# Uninstalling keras-3.14.0:
#   Successfully uninstalled keras-3.14.0
# Found existing installation: protobuf 5.29.6
# Uninstalling protobuf-5.29.6:
#   Successfully uninstalled protobuf-5.29.6
# WARNING: Skipping tensorflow as it is not installed.
# WARNING: Skipping tensorflow-cpu as it is not installed.
# WARNING: Skipping tensorflow-text as it is not installed.
# WARNING: Skipping keras-hub as it is not installed.
# WARNING: Skipping keras-nlp as it is not installed.
# WARNING: Skipping tf-keras as it is not installed.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.8 MB 3.8 MB/s eta 0:00:01
# ...

# %% [markdown]
# ---
#
# # YOLO

# %% [markdown]
# ---
#
# # SAM

# %% [markdown]
# # **MNIST con autoencoder**

# %% [markdown]
# Encoder

# %% [markdown]
# Decoder

# %% [markdown]
# Autoencoder completo

# %% [markdown]
# Entrenamiento

# %% [markdown]
# # **MNIST con VAE**
