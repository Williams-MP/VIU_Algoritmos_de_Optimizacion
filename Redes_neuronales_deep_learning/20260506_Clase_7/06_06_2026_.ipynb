# %% [markdown]
# ## Código dado

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print("TensorFlow:", tf.__version__)
print("Keras:", keras.__version__ if hasattr(keras, "__version__") else "tf.keras")
# Out:
# TensorFlow: 2.20.0
# Keras: 3.13.1

# %% [markdown]
# ## Dataset CIFAR-10

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
class_names = np.array([
    "airplane",
    "automobile",
    "bird",
    "cat",
    "deer",
    "dog",
    "frog",
    "horse",
    "ship",
    "truck"
])
x_train= x_train[:1000].astype("float32")/255.0
y_train= y_train[:1000].astype("float32")/255.0

x_test= x_test[:1000].astype("float32")/255.0
y_test= y_test[:1000].astype("float32")/255.0

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (1000, 32, 32, 3) (1000, 1)
# (1000, 32, 32, 3) (1000, 1)

# %%
def make_class(images, labels, batch_size = 64, training=True):
    tf.data.Dataset.from_tensor_slices((images, labels))
    if training:
        ds = ds.shuffle(4*batch_size)
    return ds

train_ds = make_class(x_train, y_train, training=True)
test_ds = make_class(x_test, y_test, training=False)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[6], line 7
#       4         ds = ds.shuffle(4*batch_size)
#       5     return ds
# ----> 7 train_ds = make_class(x_train, y_train, training=True)
#       8 test_ds = make_class(x_test, y_test, training=False)
#
# Cell In[6], line 4, in make_class(images, labels, batch_size, training)
#       2 tf.data.Dataset.from_tensor_slices((images, labels))
#       3 if training:
# ----> 4     ds = ds.shuffle(4*batch_size)
#       5 return ds
#
# UnboundLocalError: cannot access local variable 'ds' where it is not associated with a value

# %%
---->
entrada ||| [bloque1] [bloque2] [bloque3] [bloque4] ||| [bloque1] [bloque2] [bloque3] [bloque4]
    _______________________|  _______________________|

# %% [markdown]
# # **Arquitectura resnet a mano**

# %% [markdown]
# ## Definimos los bloques

# %%
def conv_relu(x, filters, kernel_size=3, stride=1):
    x = layers.Conv2D(
        filters=filters,
        kernel_size= kernel_size,
        strides=stride,
        padding="same",
        kernel_initializer="he_normal"
    )(x)

    x=layers.BatchNormalization()(x)
    x=layers.Activation("relu")(x)

    return x

def resid_block(x, filters, stride, projection):
    x_atajo = x
    x = layers.Conv2D(
        filters=filters,
        kernel_size=3,
        strides=stride,
        padding="same",
        kernel_initializer="he_normal"
    )(x)
    x=layers.BatchNormalization()(x)

    if projection:
        x_atajo = layers.Conv2D(
            filters=filters,
            kernel_size=1,
            strides=stride,
            padding="same",
            kernel_initializer="he_normal"
        )(x_atajo)

        x_atajo=layers.BatchNormalization()(x_atajo)

    x=layers.Add()([x, x_atajo])
    x=layers.Activation("relu")(x)

    return x

# %% [markdown]
# ## ResNet pequeña
#
# 3 bloques con 16f -> 3 bloques 32f/2-> 3 bloques 64f/2 -> GlobalAveragePooling2D -> Dense(10)

# %%
def build_block(inout_shape, num_classes, filter, block):
    input = keras.Input(shape(input_shape))
    x = conv_relu(input, filters=filter[0], kernel_size=3, stride=1)

    for _, (filters, n_blocks) in enumerate(zip(filter, blocks), start=0):
        for indice_bloque in range(n_blocks):
            is_first_block = indice_bloque==0
            is_first_block_network = indice_stage==0

            strides = 1 if (is_first_block or not is_first_block_network) else 2
            use_projection = (not is_first_block and is_first_block_network)

            x = resid_block(x, filters, stride, use_projection)

    x = layers.GlobalAveragePooling2D()(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
        
nuestra_red_resnet = build_block((32,32,3), 10, (16,32,64), (3,3,3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 18
#      15     x = layers.GlobalAveragePooling2D()(x)
#      16     outputs = layers.Dense(num_classes, activation="softmax")(x)
# ---> 18 nuestra_red_resnet = build_block((32,32,3), 10, (32,32,64), (3,3,3))
#
# Cell In[17], line 2, in build_block(inout_shape, num_classes, filter, block)
#       1 def build_block(inout_shape, num_classes, filter, block):
# ----> 2     input = keras.Input(shape(input_shape))
#       3     x = conv_relu(input, filters=filter[0], kernel_size=3, stride=1)
#       5     for _, (filters, n_blocks) in enumerate(zip(filter, blocks), start=0):
#
# NameError: name 'shape' is not defined

# %% [markdown]
# ## Resnet keras

# %% [markdown]
# # Transfer learning con ResNet50

# %% [markdown]
# ## Preparar datos para ResNet50

# %% [markdown]
# ## Transfer learning

# %% [markdown]
# Feature Extraction

# %% [markdown]
# ## Fine tuning

# %% [markdown]
# ## Comparación final
