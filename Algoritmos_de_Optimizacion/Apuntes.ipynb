# %% [markdown]
# # Títulos: Usa # para el título principal,
# ## para subtítulos se usar ##, etc..
# - **Negritas**: ** texto ** o __ texto __.
# - *Cursivas*: * texto * o _ texto _.
# - Listas: Usa - (guión y espacio) para listas con viñetas.
# - Imágenes: ![Texto alternativo](URL_de_la_imagen).
# - LaTeX (Ecuaciones): Usa $ para texto en línea o $$ para bloques de ecuaciones.

# %% [markdown]
# ## Tipos de Algoritmos
# - Atendiendo a la forma en la que calculan la solución:
#     - **Algoritmos deterministas**: Siempre la misma solución para los mismos datos de entrada (instancia).
#     - **Algoritmos probabilistas**: Pueden generar soluciones diferentes para los mismos datos de entrada (instancia).
# - Atendiendo al tipo de solución que proporcionan:
#     - **Algoritmos exactos**: Proporcionanla solución óptima.
#     - **Algoritmos aproximados**:Proporcionanbuenas soluciones con un grado de aproximación al optimo
#     - **Algoritmos heurísticos**: Proporcionan buenas soluciones pero no podemos determinar si es la óptima.

# %% [markdown]
# # Algoritmos exactos

# %% [markdown]
# ## Algoritmos de ordenación

# %% [markdown]
# ### Ordenación por inserción

# %% [markdown]
# ### Ordenación de burbuja

# %% [markdown]
# ### Ordenación por selección

# %% [markdown]
# ### Ordenación por mezcla

# %% [markdown]
# ### Ordenación por montículos

# %% [markdown]
# ### Ordenación rápida o quick sort

# %% [markdown]
# ### Ordenación por residuos

# %% [markdown]
# ## Algoritmos de búsqueda

# %% [markdown]
# ### Búsqueda en amplitud

# %% [markdown]
# ### Búsqueda en profundidad

# %% [markdown]
# ### Ramificación y poda

# %% [markdown]
# ## Técnicas generales

# %% [markdown]
# ### Algoritmos voraces

# %% [markdown]
# #### Técnica voraz - Greedy algorithms
# Algoritmo de Prim
# - Elige arista de menor coste
# - Y se continua uno nuevo
# - COmplejidad $O(n^2)$
# - Si hay muchas aristas es mejor.
# Algoritmo Kruskal
# - Ordena las aristas por orden decreciente.
# - Complejidad $O(a \cdot log(n))$
# - Si hay pocas aristas es mejor.

# %% [markdown]
# ### Algoritmos de vuelta atrás (backtracking)

# %% [markdown]
# - Para problemas discretos
# - $O(2^n)$

# %% [markdown]
# ### Divide y vencerás

# %% [markdown]
# - Inserción
#     - $O(n)$ best case
#     - $O(n^2)$ worst case
# - Burbuja
# - Selección
#     - $O(n^2)$ siempre independiente de disposición.
# - Mezcla (Merge Sort)
#     - $O(n \cdot log(n))$ siempre
# - Quick Sort
#     - $O(n \cdot log(n))$ best case
#     - $O(n^2)$ worst case
# - Sucesión de Fibonacci
#     - $O(2^n)$ a través de recurrencia
#     - $O(n)$ por técnica iterativa (almacenando los valores intermedios)

# %% [markdown]
# ### Programación dinámica

# %% [markdown]
# ### Programación lineal

# %% [markdown]
# ### Descenso del gradiente

# %% [markdown]
# # Algoritmos heurísticos

# %%
A=[1,2,6,7,12,13,15] 
B=[2,3,4,7,13]

salida = []

for i in A:
    for k in B:
        if i==k:
            salida.append(i)
print(salida)
# Out:
# [2, 7, 13]

# %% [markdown]
# ## VC02

# %%
# Factorial
def factorial(n):
    if n==1:
        return n
    else:
        return  n * factorial(n-1)
factorial(5)
# Out:
# 120

# %% [markdown]
# ### Programación dinámica

# %% [markdown]
# # VC03

# %% [markdown]
# # Clases de Complejidad: P vs NP
#
# En ciencias de la computación, clasificamos los problemas según qué tan "difíciles" son para un ordenador.
#
# ---
#
# ### 1. Clase P (Polinómicos)
# Son los problemas que un ordenador puede **resolver** de forma eficiente en un tiempo razonable.
# * **Definición:** El tiempo de ejecución crece según un polinomio ($n, n^2, n^3$, etc.).
# * **Ejemplo:** Buscar un elemento en una lista, ordenar nombres alfabéticamente o el código de tu ejemplo ($O(n^2)$).
# * **Veredicto:** Son problemas **tratables** (fáciles de manejar).
#
# ### 2. Clase NP (Polinómico No determinista)
# Son problemas que son muy difíciles de resolver, pero muy **fáciles de verificar**.
# * **Definición:** Si alguien te da una "solución candidata", puedes comprobar si es correcta en un tiempo eficiente (P). Sin embargo, encontrar esa solución puede llevar eones.
# * **Ejemplo:** Resolver un Sudoku, encontrar los factores primos de un número gigante (base de la criptografía) o el "Problema del Viajante".
# * **Veredicto:** Son problemas que hoy consideramos **intrínsecamente difíciles**.
#
# ---
#
# ### El dilema: ¿P = NP?
# Es el problema más importante de la informática actual.
# * **Si P ≠ NP (Creencia mayoritaria):** Existen problemas cuya solución es fácil de comprobar pero imposible de encontrar rápidamente. La seguridad en internet se basa en esta premisa.
# * **Si P = NP:** Significaría que existe un "atajo" para todos los problemas NP que aún no hemos descubierto. Si se demostrara, ninguna contraseña actual sería segura.

# %% [markdown]
# ## Programación lineal

# %% [markdown]
# ### Simplex
# Uno de los vertices sera el punto óptimo.

# %% [markdown]
# ## Programación lineal entera

# %% [markdown]
# Tipos puros y mixtos.
# - Puros: todas las variables deben ser enteras
# - Mixtos: algunas variables pueden ser enteras
#
# Resolución:
# - Algoritmos de búsqueda con Ramificación y Poda
# - Algortimos heurísticos

# %% [markdown]
# Problema del agente viajero (TSP)
# - $2^n$ restricciones
# - y $n^2$ restricciones
# - Resolución:
#     - Fuerza bruta
#     - Métodos exactos
#     - Métodos heurísticos

# %% [markdown]
# Problema del camino mas corto
# - No es igual que el TSP
# - Algoritmos
#     - Dijkstra
#     - Bellman-Ford
#     - Búsqueda A+
#     - Floy-Warshall

# %% [markdown]
# Problema de la mochila
# El KP (knapsack problem)
# Problema difícil de resolver para datos grandes
# - Resolución:
#     - PLE
#     - Programación Dinámica y vuelta atrás con $O(2^n)$ de complejidad
#     - Métodos heurísticos
#     - Técnica Voraz no funciona.

# %% [markdown]
# Problema del enrutamiento
# VRP (vehicle routing problem)
# - Resolución:
#     - mismos que en TSP
#     -

# %% [markdown]
# Otros Problemas
# Problema de la dieta
# Problema de satisfacibilidad booleana (SAT)
# Problema de asignación
# Coloreado de Grafos
# Compendio de problemas NP

# %% [markdown]
# ### Algoritmos de Búsqueda.
#
# - Técnicas principales:
#  - Búsqueda en amplitud o anchura
#  - Busqueda en profundidad
#  - Ramificación y Poda

# %% [markdown]
# # Algoritmos de Recorrido de Grafos: BFS vs DFS
#
# Existen dos estrategias principales para explorar nodos en un grafo o árbol. La elección depende de si queremos buscar "a lo ancho" o "a lo profundo".
#
# ---
#
# ## 1. BFS (Breadth-First Search) - Búsqueda en Amplitud
# El BFS explora el grafo como una **onda expansiva**. Visita primero todos los nodos vecinos directos antes de pasar al siguiente nivel de distancia.
#
# * **Estrategia:** Horizontal (Nivel por nivel).
# * **Estructura de datos:** Usa una **Cola (Queue)** (Sistema FIFO: el primero en entrar es el primero en salir).
# * **Complejidad:** $O(V + E)$, donde $V$ es vértices y $E$ aristas.
# * **Uso ideal:** * Encontrar la **ruta más corta** (en grafos sin pesos).
#     * Redes sociales (amigos de 1er, 2º y 3er grado).
#     * Sistemas de navegación GPS.
#
# ---
#
# ## 2. DFS (Depth-First Search) - Búsqueda en Profundidad
# El DFS actúa como un explorador en un laberinto. Elige un camino y llega **hasta el fondo** antes de retroceder (backtracking) para intentar otra ruta.
#
# * **Estrategia:** Vertical (Hacia lo profundo).
# * **Estructura de datos:** Usa una **Pila (Stack)** o **Recursividad** (Sistema LIFO: el último en entrar es el primero en salir).
# * **Complejidad:** $O(V + E)$.
# * **Uso ideal:**
#     * Detección de **ciclos** en un grafo.
#     * Resolución de puzzles o laberintos (probar todas las opciones).
#     * Ordenamiento topológico (programación de tareas dependientes).
#
# ---
#
# ## 3. Tabla Comparativa
#
# | Característica | BFS (Amplitud) | DFS (Profundidad) |
# | :--- | :--- | :--- |
# | **Movimiento** | Por niveles (vecinos primero) | Por ramas (hijos primero) |
# | **Estructura** | Cola (`Queue`) | Pila (`Stack`) o Recursión |
# | **Memoria** | Consume más en grafos muy anchos | Consume más en grafos muy profundos |
# | **Objetivo** | Encontrar lo más cercano / corto | Explorar todas las posibilidades |
#
# ---
#
# ## Ejemplo Visual
# Si tenemos un nodo raíz **A** conectado a **B** y **C**, y estos a su vez tienen hijos:
#
# 1.  **BFS visitaría:** A → [B, C] → [Hijos de B] → [Hijos de C].
# 2.  **DFS visitaría:** A → B → [Hijo de B] → [Nieto de B] ... y luego vuelve para ir a C.

# %% [markdown]
# Algoritmo A*

# %% [markdown]
# Ascenso de colina (hill climbing)

# %% [markdown]
# ## Técnicas de Ramificación y Poda

# %% [markdown]
# Algortimos de Búsqueda
#
# MinMax(*). Juegos con adversario

# %% [markdown]
# # VC04

# %% [markdown]
# ### Descenso de Gradiente
